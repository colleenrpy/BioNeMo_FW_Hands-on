# %% [markdown]
# # 必要な計算環境

# %% [markdown]
# * Linux OS
# * Pascal, Volta, Turing, 或いは NVIDIA Ampere 世代 GPU
# * Nvidia Driver
# * Docker

# %% [markdown]
# # 事前準備

# %% [markdown]
# * [NGC](https://catalog.ngc.nvidia.com/?filters=&orderBy=weightPopularDESC&query=&page=&pageSize=)の登録と[APIキー](https://org.ngc.nvidia.com/setup/api-key)の取得は済みましたか？
# * [Weights and Biases]((https://docs.wandb.ai/quickstart)) の登録と[APIキー](https://docs.wandb.ai/guides/track/public-api-guide#authentication)の取得は済みましたか？

# %% [markdown]
# ### NGC のセットアップ
# NGCからモデルをダウンロードしたい場合は、APIキーが必要になりますので、取得してください。
# ### Weights and Biases のセットアップ
# モデルのトレーニング進行状況やチャートは、 [Weights and Biases](https://docs.wandb.ai/quickstart) を通じて可視化できます。ログを有効にするために、 [API キー](https://docs.wandb.ai/guides/track/public-api-guide#authentication)を設定してください。

# %% [markdown]
# # GPUの確認

# %%
# !nvidia-smi
# Out:
# Tue May 14 15:35:49 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.129.03             Driver Version: 535.129.03   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A100-SXM4-80GB          On  | 00000000:07:00.0 Off |                    0 |
# | N/A   37C    P0              80W / 400W |    871MiB / 81920MiB |    100%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
# |   1  NVIDIA A100-SXM4-80GB          On  | 00000000:0F:00.0 Off |                    0 |
# | N/A   37C    P0              86W / 400W |  13947MiB / 81920MiB |    100%      Default |
# |                                         |                      |             Disabled |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    1   N/A  N/A      4725      C   /usr/bin/python                               0MiB |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# # データの前処理

# %% [markdown]
# ESM-2nv のトレーニング中には 2 つのデータセットを使用します。Uniref50 はトレーニング、検証、テスト用に分割されています。データのサイズと多様性を増加させるために、トレーニング中に Uniref50 のミニバッチがサンプリングされますが、このバッチの各シーケンスは、対応する Uniref90 クラスターのシーケンスに置き換えられます。詳細は「Language models of protein sequences at the scale of evolution enable accurate structure prediction (進化の規模でのタンパク質配列の言語モデルが正確な構造予測を実現)」を参照してください。Uniref90 はトレーニング時にのみ使用され、検証やテストには使用されません。

# %% [markdown]
# データの前処理を行う前に、以下のコマンドでサンプルデータを解凍してください。

# %%
cd /workspace/bionemo/examples/tests/test_data/
# Out:
# /workspace/bionemo/examples/tests/test_data

# %%
# !unzip uniref202104_esm2_qc_test200_val200.zip
# Out:
# Archive:  uniref202104_esm2_qc_test200_val200.zip
#    creating: uniref202104_esm2_qc_test200_val200/
#   inflating: uniref202104_esm2_qc_test200_val200/README.md
#   inflating: uniref202104_esm2_qc_test200_val200/mapping.tsv
#    creating: uniref202104_esm2_qc_test200_val200/uf50/
#    creating: uniref202104_esm2_qc_test200_val200/uf50/test/
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/counts.mmap
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/starts.mmap
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x000.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x001.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x002.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x003.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x004.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x005.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x006.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x007.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x008.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x009.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x010.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x011.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x012.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x013.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x014.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x015.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x016.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x017.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x018.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x019.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x020.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x021.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x022.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x023.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x024.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x025.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x026.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x027.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x028.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x029.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x030.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x031.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x032.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x033.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x034.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x035.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x036.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x037.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x038.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x039.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x040.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x041.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x042.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x043.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x044.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x045.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x046.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x047.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x048.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/test/x049.csv
#    creating: uniref202104_esm2_qc_test200_val200/uf50/train/
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/counts.mmap
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/starts.mmap
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x000.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x001.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x002.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x003.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x004.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x005.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x006.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x007.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x008.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x009.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x010.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x011.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x012.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x013.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x014.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x015.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x016.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x017.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x018.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x019.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x020.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x021.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x022.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x023.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x024.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x025.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x026.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x027.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x028.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x029.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x030.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x031.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x032.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x033.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x034.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x035.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x036.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x037.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x038.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x039.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x040.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x041.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x042.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x043.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x044.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x045.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x046.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x047.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x048.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/train/x049.csv
#    creating: uniref202104_esm2_qc_test200_val200/uf50/val/
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/counts.mmap
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/starts.mmap
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x000.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x001.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x002.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x003.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x004.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x005.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x006.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x007.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x008.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x009.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x010.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x011.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x012.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x013.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x014.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x015.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x016.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x017.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x018.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x019.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x020.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x021.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x022.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x023.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x024.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x025.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x026.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x027.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x028.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x029.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x030.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x031.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x032.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x033.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x034.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x035.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x036.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x037.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x038.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x039.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x040.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x041.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x042.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x043.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x044.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x045.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x046.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x047.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x048.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf50/val/x049.csv
#    creating: uniref202104_esm2_qc_test200_val200/uf90/
#    creating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/
#    creating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/
#    creating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/
#    creating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/
#    creating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/
#    creating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/
#    creating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/
#    creating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/
#    creating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x000.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x000.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x001.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x001.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x002.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x002.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x003.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x003.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x004.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x004.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x005.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x005.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x006.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x006.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x007.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x007.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x008.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x008.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x009.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x009.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x010.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x010.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x011.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x011.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x012.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x012.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x013.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x013.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x014.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x014.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x015.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x015.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x016.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x016.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x017.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x017.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x018.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x018.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x019.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x019.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x020.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x020.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x021.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x021.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x022.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x022.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x023.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x023.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x024.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x024.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x025.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x025.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x026.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x026.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x027.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x027.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x028.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x028.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x029.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x029.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x030.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x030.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x031.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x031.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x032.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x032.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x033.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x033.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x034.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x034.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x035.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x035.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x036.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x036.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x037.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x037.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x038.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x038.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x039.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x039.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x040.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x040.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x041.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x041.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x042.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x042.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x043.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x043.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x044.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x044.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x045.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x045.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x046.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x046.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x047.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x047.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x048.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x048.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x049.csv.idx.info
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc/uf90/uf90_csvs/x049.csv.idx.npy
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x000.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x001.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x002.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x003.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x004.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x005.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x006.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x007.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x008.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x009.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x010.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x011.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x012.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x013.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x014.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x015.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x016.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x017.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x018.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x019.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x020.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x021.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x022.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x023.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x024.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x025.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x026.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x027.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x028.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x029.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x030.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x031.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x032.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x033.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x034.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x035.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x036.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x037.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x038.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x039.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x040.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x041.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x042.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x043.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x044.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x045.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x046.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x047.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x048.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uf90/uf90_csvs/x049.csv
#   inflating: uniref202104_esm2_qc_test200_val200/uniref50_train_filt.fasta
#   inflating: uniref202104_esm2_qc_test200_val200/uniref50_train_filt.fasta.fxi
#   inflating: uniref202104_esm2_qc_test200_val200/uniref50_valid_reduced.fasta
#   inflating: uniref202104_esm2_qc_test200_val200/ur90_ur50_sampler.fasta
#   inflating: uniref202104_esm2_qc_test200_val200/ur90_ur50_sampler.fasta.fxi

# %% [markdown]
# 次に、下記の場所にあるコードを実行してデータの前処理を行いますが、その前に、データのパスを設定する必要があります。
#
# /workspace/bionemo/examples/protein/esm2nv/pretrain.py

# %% [markdown]
# データのパスを正しく設定するために、下記のYAML設定ファイルを変更するか、データの前処理やモデルトレーニングを行う際にコマンドの一部としてそれらのパラメータを更新することができます。

# %% [markdown]
# /workspace/bionemo/examples/protein/esm2nv/conf/base_config.yaml

# %% [markdown]
# では、以下のコマンドでデータの前処理を行います。

# %%
cd /workspace/bionemo
# Out:
# /workspace/bionemo

# %%
# !python examples/protein/esm2nv/pretrain.py\
 --config-path=conf\
 --config-name=pretrain_esm2_650M\
 ++do_training=False\
 ++model.data.val_size=500\
 ++model.data.test_size=100\
 ++model.data.uf50_datapath=/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uniref50_train_filt.fasta\
 ++model.data.uf90_datapath=/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc_test200_val200/ur90_ur50_sampler.fasta\
 ++model.data.cluster_mapping_tsv=/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc_test200_val200/mapping.tsv\
  ++model.data.dataset_path=/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50\
 ++model.data.uf90.uniref90_path=/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf90\
 ++model.data.train.uf50_datapath=/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uniref50_train_filt.fasta\
  ++model.data.train.uf90_datapath=/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc_test200_val200/ur90_ur50_sampler.fasta\
  ++model.data.train.cluster_mapping_tsv=/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc_test200_val200/mapping.tsv\
 ++model.data.val.uf50_datapath=/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uniref50_train_filt.fasta\
 ++model.data.test.uf50_datapath=/workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uniref50_train_filt.fasta
# Out:
# [NeMo I 2024-05-15 05:53:02 megatron_hiddens:110] Registered hidden transform sampled_var_cond_gaussian at bionemo.model.core.hiddens_support.SampledVarGaussianHiddenTransform
# [NeMo I 2024-05-15 05:53:02 megatron_hiddens:110] Registered hidden transform interp_var_cond_gaussian at bionemo.model.core.hiddens_support.InterpVarGaussianHiddenTransform
# [NeMo W 2024-05-15 05:53:03 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/hydra/_internal/defaults_list.py:251: UserWarning: In 'pretrain_esm2_650M': Defaults list is missing `_self_`. See https://hydra.cc/docs/1.2/upgrades/1.0_to_1.1/default_composition_order for more information
#       warnings.warn(msg, UserWarning)
#
# [NeMo W 2024-05-15 05:53:03 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
#     See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#       ret = run_job(
#
# [NeMo I 2024-05-15 05:53:03 pretrain:41]
#
#     ************** Experiment configuration ***********
# [NeMo I 2024-05-15 05:53:03 pretrain:42]
#     name: esm2-650M
#     do_training: false
#     do_testing: false
#     restore_from_path: null
#     trainer:
#       devices: 1
#       num_nodes: 1
#       accelerator: gpu
#       precision: 32
#       logger: false
#       enable_checkpointing: false
#       use_distributed_sampler: false
#       max_epochs: null
#       log_every_n_steps: 10
#       val_check_interval: 1500
#       limit_val_batches: 1.0
#       limit_test_batches: 1.0
#       accumulate_grad_batches: 1
#       gradient_clip_val: 1.0
#       benchmark: false
#       max_steps: 500000
#     exp_manager:
#       name: ${name}
#       exp_dir: ${oc.env:BIONEMO_HOME}/results/nemo_experiments/${.name}/${.wandb_logger_kwargs.name}
#       explicit_log_dir: ${.exp_dir}
#       create_wandb_logger: true
#       create_tensorboard_logger: true
#       wandb_logger_kwargs:
#         project: ${name}_pretraining
#         name: ${name}_pretraining
#         group: ${name}
#         job_type: Localhost_nodes_${trainer.num_nodes}_gpus_${trainer.devices}
#         notes: 'date: ${now:%y%m%d-%H%M%S}'
#         tags:
#         - ${name}
#         offline: true
#       resume_if_exists: true
#       resume_ignore_no_checkpoint: true
#       create_checkpoint_callback: true
#       checkpoint_callback_params:
#         monitor: val_loss
#         save_top_k: 10
#         mode: min
#         always_save_nemo: false
#         filename: megatron_bert--{val_loss:.2f}-{step}-{consumed_samples}
#         model_parallel_size: ${multiply:${model.tensor_model_parallel_size}, ${model.pipeline_model_parallel_size}}
#     model:
#       drop_last: true
#       micro_batch_size: 2
#       seq_length: 1024
#       num_layers: 33
#       hidden_size: 1280
#       ffn_hidden_size: ${multiply:${model.hidden_size}, 4}
#       num_attention_heads: 20
#       megatron_legacy: false
#       position_embedding_type: rope
#       hidden_dropout: 0
#       embedding_use_attention_mask: true
#       embedding_token_dropout: true
#       mask_token_id: ${.tokenizer.mask_id}
#       attention_dropout: 0.0
#       normalize_attention_scores: false
#       tensor_model_parallel_size: 1
#       pipeline_model_parallel_size: 1
#       bias_gelu_fusion: false
#       use_esm_attention: true
#       esm_gelu: true
#       use_pt_layernorm: false
#       use_pt_mlp_out: false
#       max_position_embeddings: ${.seq_length}
#       encoder_seq_length: ${.seq_length}
#       optim:
#         name: fused_adam
#         lr: 0.0004
#         weight_decay: 0.01
#         betas:
#         - 0.9
#         - 0.98
#         sched:
#           name: WarmupAnnealDecayHold
#           warmup_steps: 2000
#           min_lr: 4.0e-05
#           max_lr: 0.0004
#           max_steps: 500000
#           anneal_percentage: 0.1
#       init_method_std: 0.02
#       kv_channels: null
#       apply_query_key_layer_scaling: true
#       layernorm_epsilon: 1.0e-05
#       make_vocab_size_divisible_by: 128
#       pre_process: true
#       post_process: true
#       bert_binary_head: false
#       resume_from_checkpoint: null
#       masked_softmax_fusion: true
#       tokenizer:
#         library: huggingface
#         type: BertWordPieceLowerCase
#         model_name: facebook/esm2_t33_650M_UR50D
#         mask_id: 32
#         model: null
#         vocab_file: null
#         merge_file: null
#       native_amp_init_scale: 4294967296
#       native_amp_growth_interval: 1000
#       fp32_residual_connection: false
#       fp16_lm_cross_entropy: false
#       seed: 1234
#       use_cpu_initialization: false
#       onnx_safe: false
#       activations_checkpoint_method: null
#       activations_checkpoint_num_layers: 1
#       data:
#         ngc_registry_target: uniref50_2022_05
#         ngc_registry_version: v23.06
#         data_prefix: ''
#         num_workers: 8
#         dataloader_type: single
#         reset_position_ids: false
#         reset_attention_mask: false
#         eod_mask_loss: false
#         masked_lm_prob: 0.15
#         short_seq_prob: 0.1
#         skip_lines: 0
#         drop_last: false
#         pin_memory: false
#         dynamic_padding: false
#         force_regen_sample_mapping: false
#         dataset_path: /workspace/bionemo/examples/tests/test_data/uf50
#         index_mapping_dir: ${model.data.dataset_path}
#         preprocessing:
#           num_preprocess_workers: 16
#         train:
#           data_impl: csv_mmap
#           data_impl_kwargs:
#             csv_mmap:
#               data_col: 1
#               header_lines: 1
#           use_upsampling: true
#           range: x[000..049]
#           sample_from_map: true
#           uf50_datapath: /workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uniref50_train_filt.fasta
#           uf90_datapath: /workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc_test200_val200/ur90_ur50_sampler.fasta
#           cluster_mapping_tsv: /workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc_test200_val200/mapping.tsv
#           dataset_path: ${model.data.dataset_path}/uf50
#           sort_fastas: true
#           num_workers: ${model.data.num_workers}
#           uf90:
#             uniref90_path: ${model.data.dataset_path}/uf90
#             dataset:
#               uf90_csvs: x[000..049]
#             data_impl: csv_fields_mmap
#             data_impl_kwargs:
#               csv_fields_mmap:
#                 header_lines: 1
#                 newline_int: 10
#                 workers: ${model.data.train.num_workers}
#                 sort_dataset_paths: true
#                 data_sep: ','
#                 data_fields:
#                   sequence: 3
#                   sequence_id: 1
#             index_mapping_dir: ${model.data.index_mapping_dir}
#           index_mapping_dir: ${model.data.index_mapping_dir}
#           max_seq_length: ${model.seq_length}
#           seed: ${model.seed}
#         val:
#           use_upsampling: false
#           range: x[000..049]
#           uf50_datapath: /workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uniref50_train_filt.fasta
#           dataset_path: ${model.data.dataset_path}/uf50
#           data_impl: csv_fields_mmap
#           num_workers: ${model.data.num_workers}
#           data_impl_kwargs:
#             csv_fields_mmap:
#               header_lines: 1
#               newline_int: 10
#               workers: ${model.data.val.num_workers}
#               sort_dataset_paths: true
#               data_sep: ','
#               data_fields:
#                 sequence: 3
#                 sequence_id: 1
#           index_mapping_dir: ${model.data.index_mapping_dir}
#           max_seq_length: ${model.seq_length}
#           seed: ${model.seed}
#         test:
#           use_upsampling: false
#           range: x[000..049]
#           uf50_datapath: /workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uniref50_train_filt.fasta
#           dataset_path: ${model.data.dataset_path}/uf50
#           data_impl: csv_fields_mmap
#           num_workers: ${model.data.num_workers}
#           data_impl_kwargs:
#             csv_fields_mmap:
#               header_lines: 1
#               newline_int: 10
#               workers: ${model.data.test.num_workers}
#               sort_dataset_paths: true
#               data_sep: ','
#               data_fields:
#                 sequence: 3
#                 sequence_id: 1
#           index_mapping_dir: ${model.data.index_mapping_dir}
#           max_seq_length: ${model.seq_length}
#           seed: ${model.seed}
#         modify_percent: 0.1
#         perturb_percent: 0.5
#         val_size: 500
#         test_size: 100
#         uf50_datapath: /workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uniref50_train_filt.fasta
#         uf90_datapath: /workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc_test200_val200/ur90_ur50_sampler.fasta
#         cluster_mapping_tsv: /workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc_test200_val200/mapping.tsv
#         uf90:
#           uniref90_path: /workspace/bionemo/examples/tests/test_data/uf90
#       dwnstr_task_validation:
#         enabled: false
#         dataset:
#           class: bionemo.model.core.dwnstr_task_callbacks.PerTokenPredictionCallback
#           task_type: token-level-classification
#           infer_target: bionemo.model.protein.esm1nv.infer.ESM1nvInference
#           max_seq_length: ${model.seq_length}
#           emb_batch_size: 128
#           batch_size: 128
#           num_epochs: 10
#           shuffle: true
#           num_workers: 8
#           task_name: secondary_structure
#           dataset_path: ${oc.env:BIONEMO_HOME}/data/FLIP/${model.dwnstr_task_validation.dataset.task_name}
#           dataset:
#             train: x000
#             test: x000
#           sequence_column: sequence
#           target_column:
#           - 3state
#           target_sizes:
#           - 3
#           mask_column:
#           - resolved
#           random_seed: 1234
#           optim:
#             name: adam
#             lr: 0.0001
#             betas:
#             - 0.9
#             - 0.999
#             eps: 1.0e-08
#             weight_decay: 0.01
#             sched:
#               name: WarmupAnnealing
#               min_lr: 1.0e-05
#               last_epoch: -1
#               warmup_ratio: 0.01
#               max_steps: 1000
#
# [NeMo I 2024-05-15 05:53:03 pretrain:59] ************** Starting Preprocessing ***********
# [NeMo I 2024-05-15 05:53:03 preprocess:384] Indexing UniRef50 dataset.
# [NeMo I 2024-05-15 05:53:03 preprocess:392] Indexing UniRef90 dataset.
# [NeMo I 2024-05-15 05:53:03 preprocess:395] Creating cluster mapping
# 5002it [00:00, 854648.39it/s]
# [NeMo I 2024-05-15 05:53:03 preprocess:499] Sorting fasta files in temporary file: new_uf50_fn='/tmp/tmpfjpoa3uk' new_uf90_fn='/tmp/tmp9mihrikv'
# 5001it [00:00, 27568.83it/s]
# [NeMo I 2024-05-15 05:53:03 preprocess:408] Loading sorted fasta files
# [NeMo I 2024-05-15 05:53:03 preprocess:420] Writing processed uf50 train dataset files to /workspace/bionemo/examples/tests/test_data/uf50/uf50...
# [NeMo I 2024-05-15 05:53:04 preprocess:384] Indexing UniRef50 dataset.
# [NeMo I 2024-05-15 05:53:04 preprocess:395] Creating cluster mapping
# [NeMo I 2024-05-15 05:53:04 preprocess:408] Loading sorted fasta files
# [NeMo I 2024-05-15 05:53:04 preprocess:420] Writing processed uf50 val dataset files to /workspace/bionemo/examples/tests/test_data/uf50/uf50...
# [NeMo I 2024-05-15 05:53:04 preprocess:384] Indexing UniRef50 dataset.
# [NeMo I 2024-05-15 05:53:04 preprocess:395] Creating cluster mapping
# [NeMo I 2024-05-15 05:53:04 preprocess:408] Loading sorted fasta files
# [NeMo I 2024-05-15 05:53:04 preprocess:420] Writing processed uf50 test dataset files to /workspace/bionemo/examples/tests/test_data/uf50/uf50...

# %% [markdown]
# -- で始まるパラメータは、コマンドライン引数として pretrain.py に渡されます。例えば、 config-path と config-name は、設定 YAML ファイルのフォルダとyaml ファイル名を指定します。このパスは pretrain.py に対して相対的です。conf はexamples/protein/esm2nv/confを指し、pretrain_esm2_650M はexamples/protein/esm2nv/conf/pretrain_esm2_650M.yaml を指します。
#
#
# ++ で始まるパラメータは、YAML ファイルで設定可能です。 例えば、base_config.yaml から継承された pretrain_esm2_650M.yaml では、以下のパラメータを見つけることができます：
#
# * do_training: データの前処理のみを行い、トレーニングは行わないように False に設定します。
# * model.data.val_size と model.data.test_size: 検証およびテストデータセットのサイズを指定します。
# * model.data.uf50_datapath: uniref50 fasta ファイルへのパスを指定します。
# * model.data.uf90_datapath: uniref90 fasta ファイルへのパスを指定します。
# * model.data.cluster_mapping_tsv: uniref50 クラスターを uniref90 シーケンスにマッピングするファイルへのパスを指定します。
# * model.data.dataset_path: 前処理された uniref50 データの出力ディレクトリへのパスを指定します。このフォルダはトレイン、検証、テストの分割を含むことになります。
# * model.data.uf90.uniref90_path: 前処理されたuniref90 データの出力ディレクトリへのパスを指定します。このフォルダは u90_csvs というフォルダのみを持ち、uniref90 はトレーニングでのみ使用されるため、トレイン/テスト/検証の分割は持ちません。
# * model.data.train.uf50_datapath: uniref50 fasta ファイルへのパスを指定します。
# * model.data.train.uf90_datapath: uniref90 fasta ファイルへのパスを指定します。
# * model.data.train.cluster_mapping_tsv: uniref50 クラスターを uniref90 シーケンスにマッピングするファイルへのパスを指定します。
# * model.data.val.uf50_datapath: uniref50 fasta ファイルへのパスを指定します。
# * model.data.test.uf50_datapath: uniref50 fasta ファイルへのパスを指定します。
#
# また、上記のようにコマンドラインを通じて引数を上書きするのではなく、直接 YAML ファイルを変更することもできます。処理が完了すると、前処理されたデータは /workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/ にあります。
#
# もし独自のデータを利用して事前学習、ファインチューニングや推論をしたい場合は、パスを/workspace/bionemo/mydata/ に指定してください。ただし、データの構造やフォーマットをサンプルデータに揃える必要があります。

# %% [markdown]
# # モデルの事前学習

# %% [markdown]
# 今回の例で UniRef50 と UniRef90 のサブセットの前処理が完了したので、ESM-2nv モデルの事前学習を開始することができます。BioNeMo Framework では、事前学習されたモデルのチェックポイントが提供されています。例えば、ESM-1nv、ESM-2nv（650m、3b、15b）、ProtT5nv、MegaMolBART などです。これらのモデルの重みは NVIDIA の NGC からダウンロードできます。すでにモデルのチェックポイントを持っている場合は、事前学習を再開することも可能です。

# %% [markdown]
# では、以下のコマンドでモデルを事前学習します。

# %%
cd /workspace/bionemo
# Out:
# /workspace/bionemo

# %%
# !python examples/protein/esm2nv/pretrain.py \
 --config-path=conf \
 --config-name=pretrain_esm2_650M \
 ++do_training=True \
 ++do_testing=False \
 ++model.data.dataset_path=examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50 \
 ++model.data.uf90.uniref90_path=examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf90 \
 ++trainer.devices=2 \
 ++model.tensor_model_parallel_size=2 \
 ++model.micro_batch_size=8 \
 ++trainer.max_steps=50 \
 ++trainer.val_check_interval=5 \
 ++exp_manager.create_wandb_logger=True \
 ++exp_manager.checkpoint_callback_params.save_top_k=5
# Out:
# [NeMo I 2024-05-14 15:41:12 megatron_hiddens:110] Registered hidden transform sampled_var_cond_gaussian at bionemo.model.core.hiddens_support.SampledVarGaussianHiddenTransform
# [NeMo I 2024-05-14 15:41:12 megatron_hiddens:110] Registered hidden transform interp_var_cond_gaussian at bionemo.model.core.hiddens_support.InterpVarGaussianHiddenTransform
# [NeMo W 2024-05-14 15:41:12 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/hydra/_internal/defaults_list.py:251: UserWarning: In 'pretrain_esm2_650M': Defaults list is missing `_self_`. See https://hydra.cc/docs/1.2/upgrades/1.0_to_1.1/default_composition_order for more information
#       warnings.warn(msg, UserWarning)
#
# [NeMo W 2024-05-14 15:41:12 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
#     See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#       ret = run_job(
#
# [NeMo I 2024-05-14 15:41:12 pretrain:41]
#
#     ************** Experiment configuration ***********
# [NeMo I 2024-05-14 15:41:12 pretrain:42]
#     name: esm2-650M
#     do_training: true
#     do_testing: false
#     restore_from_path: null
#     trainer:
#       devices: 2
#       num_nodes: 1
#       accelerator: gpu
#       precision: 32
#       logger: false
#       enable_checkpointing: false
#       use_distributed_sampler: false
#       max_epochs: null
#       log_every_n_steps: 10
#       val_check_interval: 5
#       limit_val_batches: 1.0
#       limit_test_batches: 1.0
#       accumulate_grad_batches: 1
#       gradient_clip_val: 1.0
#       benchmark: false
#       max_steps: 30
#     exp_manager:
#       name: ${name}
#       exp_dir: ${oc.env:BIONEMO_HOME}/results/nemo_experiments/${.name}/${.wandb_logger_kwargs.name}
#       explicit_log_dir: ${.exp_dir}
#       create_wandb_logger: true
#       create_tensorboard_logger: true
#       wandb_logger_kwargs:
#         project: ${name}_pretraining
#         name: ${name}_pretraining
#         group: ${name}
#         job_type: Localhost_nodes_${trainer.num_nodes}_gpus_${trainer.devices}
#         notes: 'date: ${now:%y%m%d-%H%M%S}'
#         tags:
#         - ${name}
#         offline: true
#       resume_if_exists: true
#       resume_ignore_no_checkpoint: true
#       create_checkpoint_callback: true
#       checkpoint_callback_params:
#         monitor: val_loss
#         save_top_k: 5
#         mode: min
#         always_save_nemo: false
#         filename: megatron_bert--{val_loss:.2f}-{step}-{consumed_samples}
#         model_parallel_size: ${multiply:${model.tensor_model_parallel_size}, ${model.pipeline_model_parallel_size}}
#     model:
#       drop_last: true
#       micro_batch_size: 1
#       seq_length: 1024
#       num_layers: 33
#       hidden_size: 1280
#       ffn_hidden_size: ${multiply:${model.hidden_size}, 4}
#       num_attention_heads: 20
#       megatron_legacy: false
#       position_embedding_type: rope
#       hidden_dropout: 0
#       embedding_use_attention_mask: true
#       embedding_token_dropout: true
#       mask_token_id: ${.tokenizer.mask_id}
#       attention_dropout: 0.0
#       normalize_attention_scores: false
#       tensor_model_parallel_size: 2
#       pipeline_model_parallel_size: 1
#       bias_gelu_fusion: false
#       use_esm_attention: true
#       esm_gelu: true
#       use_pt_layernorm: false
#       use_pt_mlp_out: false
#       max_position_embeddings: ${.seq_length}
#       encoder_seq_length: ${.seq_length}
#       optim:
#         name: fused_adam
#         lr: 0.0004
#         weight_decay: 0.01
#         betas:
#         - 0.9
#         - 0.98
#         sched:
#           name: WarmupAnnealDecayHold
#           warmup_steps: 2000
#           min_lr: 4.0e-05
#           max_lr: 0.0004
#           max_steps: 500000
#           anneal_percentage: 0.1
#       init_method_std: 0.02
#       kv_channels: null
#       apply_query_key_layer_scaling: true
#       layernorm_epsilon: 1.0e-05
#       make_vocab_size_divisible_by: 128
#       pre_process: true
#       post_process: true
#       bert_binary_head: false
#       resume_from_checkpoint: null
#       masked_softmax_fusion: true
#       tokenizer:
#         library: huggingface
#         type: BertWordPieceLowerCase
#         model_name: facebook/esm2_t33_650M_UR50D
#         mask_id: 32
#         model: null
#         vocab_file: null
#         merge_file: null
#       native_amp_init_scale: 4294967296
#       native_amp_growth_interval: 1000
#       fp32_residual_connection: false
#       fp16_lm_cross_entropy: false
#       seed: 1234
#       use_cpu_initialization: false
#       onnx_safe: false
#       activations_checkpoint_method: null
#       activations_checkpoint_num_layers: 1
#       data:
#         ngc_registry_target: uniref50_2022_05
#         ngc_registry_version: v23.06
#         data_prefix: ''
#         num_workers: 8
#         dataloader_type: single
#         reset_position_ids: false
#         reset_attention_mask: false
#         eod_mask_loss: false
#         masked_lm_prob: 0.15
#         short_seq_prob: 0.1
#         skip_lines: 0
#         drop_last: false
#         pin_memory: false
#         dynamic_padding: false
#         force_regen_sample_mapping: false
#         dataset_path: examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50
#         index_mapping_dir: ${model.data.dataset_path}
#         preprocessing:
#           num_preprocess_workers: 16
#         train:
#           data_impl: csv_mmap
#           data_impl_kwargs:
#             csv_mmap:
#               data_col: 1
#               header_lines: 1
#           use_upsampling: true
#           range: x[000..049]
#           sample_from_map: true
#           uf50_datapath: ${model.data.dataset_path}/uniref50_train_filt.fasta
#           uf90_datapath: ${model.data.dataset_path}/uniref90membersandreps_ur50trainfiltreps.fasta
#           cluster_mapping_tsv: ${model.data.dataset_path}/uniref50_mapper_to_uniref90clustermembers_andselfuniref50.tsv
#           dataset_path: ${model.data.dataset_path}/uf50
#           sort_fastas: true
#           num_workers: ${model.data.num_workers}
#           uf90:
#             uniref90_path: ${model.data.dataset_path}/uf90
#             dataset:
#               uf90_csvs: x[000..049]
#             data_impl: csv_fields_mmap
#             data_impl_kwargs:
#               csv_fields_mmap:
#                 header_lines: 1
#                 newline_int: 10
#                 workers: ${model.data.train.num_workers}
#                 sort_dataset_paths: true
#                 data_sep: ','
#                 data_fields:
#                   sequence: 3
#                   sequence_id: 1
#             index_mapping_dir: ${model.data.index_mapping_dir}
#           index_mapping_dir: ${model.data.index_mapping_dir}
#           max_seq_length: ${model.seq_length}
#           seed: ${model.seed}
#         val:
#           use_upsampling: false
#           range: x[000..049]
#           uf50_datapath: ${model.data.dataset_path}/uniref50_train_filt.fasta
#           dataset_path: ${model.data.dataset_path}/uf50
#           data_impl: csv_fields_mmap
#           num_workers: ${model.data.num_workers}
#           data_impl_kwargs:
#             csv_fields_mmap:
#               header_lines: 1
#               newline_int: 10
#               workers: ${model.data.val.num_workers}
#               sort_dataset_paths: true
#               data_sep: ','
#               data_fields:
#                 sequence: 3
#                 sequence_id: 1
#           index_mapping_dir: ${model.data.index_mapping_dir}
#           max_seq_length: ${model.seq_length}
#           seed: ${model.seed}
#         test:
#           use_upsampling: false
#           range: x[000..049]
#           uf50_datapath: ${model.data.dataset_path}/uniref50_train_filt.fasta
#           dataset_path: ${model.data.dataset_path}/uf50
#           data_impl: csv_fields_mmap
#           num_workers: ${model.data.num_workers}
#           data_impl_kwargs:
#             csv_fields_mmap:
#               header_lines: 1
#               newline_int: 10
#               workers: ${model.data.test.num_workers}
#               sort_dataset_paths: true
#               data_sep: ','
#               data_fields:
#                 sequence: 3
#                 sequence_id: 1
#           index_mapping_dir: ${model.data.index_mapping_dir}
#           max_seq_length: ${model.seq_length}
#           seed: ${model.seed}
#         modify_percent: 0.1
#         perturb_percent: 0.5
#         uf90:
#           uniref90_path: examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf90
#       dwnstr_task_validation:
#         enabled: false
#         dataset:
#           class: bionemo.model.core.dwnstr_task_callbacks.PerTokenPredictionCallback
#           task_type: token-level-classification
#           infer_target: bionemo.model.protein.esm1nv.infer.ESM1nvInference
#           max_seq_length: ${model.seq_length}
#           emb_batch_size: 128
#           batch_size: 128
#           num_epochs: 10
#           shuffle: true
#           num_workers: 8
#           task_name: secondary_structure
#           dataset_path: ${oc.env:BIONEMO_HOME}/data/FLIP/${model.dwnstr_task_validation.dataset.task_name}
#           dataset:
#             train: x000
#             test: x000
#           sequence_column: sequence
#           target_column:
#           - 3state
#           target_sizes:
#           - 3
#           mask_column:
#           - resolved
#           random_seed: 1234
#           optim:
#             name: adam
#             lr: 0.0001
#             betas:
#             - 0.9
#             - 0.999
#             eps: 1.0e-08
#             weight_decay: 0.01
#             sched:
#               name: WarmupAnnealing
#               min_lr: 1.0e-05
#               last_epoch: -1
#               warmup_ratio: 0.01
#               max_steps: 1000
#
# [NeMo I 2024-05-14 15:41:12 utils:230] Selected Callbacks: [<class 'pytorch_lightning.callbacks.model_summary.ModelSummary'>]
# Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer(limit_val_batches=1.0)` was configured so 100% of the batches will be used..
# `Trainer(limit_test_batches=1.0)` was configured so 100% of the batches will be used..
# [NeMo E 2024-05-14 15:41:13 exp_manager:684] exp_manager received explicit_log_dir: /workspace/bionemo/results/nemo_experiments/esm2-650M/esm2-650M_pretraining and at least one of exp_dir: /workspace/bionemo/results/nemo_experiments/esm2-650M/esm2-650M_pretraining, or version: None. Please note that exp_dir, name, and version will be ignored.
# [NeMo W 2024-05-14 15:41:13 exp_manager:689] Exp_manager is logging to /workspace/bionemo/results/nemo_experiments/esm2-650M/esm2-650M_pretraining, but it already exists.
# [NeMo I 2024-05-14 15:41:13 exp_manager:639] Resuming training from checkpoint: /workspace/bionemo/results/nemo_experiments/esm2-650M/esm2-650M_pretraining/checkpoints/megatron_bert--val_loss=3.10-step=45-consumed_samples=45.0-last.ckpt
# [NeMo I 2024-05-14 15:41:13 exp_manager:394] Experiments will be logged at /workspace/bionemo/results/nemo_experiments/esm2-650M/esm2-650M_pretraining
# [NeMo I 2024-05-14 15:41:13 exp_manager:835] TensorboardLogger has been set up
# wandb: WARNING `resume` will be ignored since W&B syncing is set to `offline`. Starting a new run with run id yoh718j3.
# wandb: Tracking run with wandb version 0.15.6
# wandb: W&B syncing is set to `offline` in this directory.
# wandb: Run `wandb online` or set WANDB_MODE=online to enable cloud syncing.
# [NeMo I 2024-05-14 15:41:14 exp_manager:850] WandBLogger has been set up
# [NeMo W 2024-05-14 15:41:14 exp_manager:931] The checkpoint callback was told to monitor a validation value and trainer's max_steps was set to 30. Please ensure that max_steps will run for at least 1 epochs to ensure that checkpointing will not error out.
# [NeMo I 2024-05-14 15:41:14 utils:306]
#
#     ************** Trainer configuration ***********
# [NeMo I 2024-05-14 15:41:14 utils:307]
#     name: esm2-650M
#     do_training: true
#     do_testing: false
#     restore_from_path: null
#     trainer:
#       devices: 2
#       num_nodes: 1
#       accelerator: gpu
#       precision: 32
#       logger: false
#       enable_checkpointing: false
#       use_distributed_sampler: false
#       max_epochs: null
#       log_every_n_steps: 10
#       val_check_interval: 5
#       limit_val_batches: 1.0
#       limit_test_batches: 1.0
#       accumulate_grad_batches: 1
#       gradient_clip_val: 1.0
#       benchmark: false
#       max_steps: 30
#     exp_manager:
#       name: ${name}
#       exp_dir: ${oc.env:BIONEMO_HOME}/results/nemo_experiments/${.name}/${.wandb_logger_kwargs.name}
#       explicit_log_dir: ${.exp_dir}
#       create_wandb_logger: true
#       create_tensorboard_logger: true
#       wandb_logger_kwargs:
#         project: ${name}_pretraining
#         name: ${name}_pretraining
#         group: ${name}
#         job_type: Localhost_nodes_${trainer.num_nodes}_gpus_${trainer.devices}
#         notes: 'date: ${now:%y%m%d-%H%M%S}'
#         tags:
#         - ${name}
#         offline: true
#       resume_if_exists: true
#       resume_ignore_no_checkpoint: true
#       create_checkpoint_callback: true
#       checkpoint_callback_params:
#         monitor: val_loss
#         save_top_k: 5
#         mode: min
#         always_save_nemo: false
#         filename: megatron_bert--{val_loss:.2f}-{step}-{consumed_samples}
#         model_parallel_size: ${multiply:${model.tensor_model_parallel_size}, ${model.pipeline_model_parallel_size}}
#     model:
#       drop_last: true
#       micro_batch_size: 1
#       seq_length: 1024
#       num_layers: 33
#       hidden_size: 1280
#       ffn_hidden_size: ${multiply:${model.hidden_size}, 4}
#       num_attention_heads: 20
#       megatron_legacy: false
#       position_embedding_type: rope
#       hidden_dropout: 0
#       embedding_use_attention_mask: true
#       embedding_token_dropout: true
#       mask_token_id: ${.tokenizer.mask_id}
#       attention_dropout: 0.0
#       normalize_attention_scores: false
#       tensor_model_parallel_size: 2
#       pipeline_model_parallel_size: 1
#       bias_gelu_fusion: false
#       use_esm_attention: true
#       esm_gelu: true
#       use_pt_layernorm: false
#       use_pt_mlp_out: false
#       max_position_embeddings: ${.seq_length}
#       encoder_seq_length: ${.seq_length}
#       optim:
#         name: fused_adam
#         lr: 0.0004
#         weight_decay: 0.01
#         betas:
#         - 0.9
#         - 0.98
#         sched:
#           name: WarmupAnnealDecayHold
#           warmup_steps: 2000
#           min_lr: 4.0e-05
#           max_lr: 0.0004
#           max_steps: 500000
#           anneal_percentage: 0.1
#       init_method_std: 0.02
#       kv_channels: null
#       apply_query_key_layer_scaling: true
#       layernorm_epsilon: 1.0e-05
#       make_vocab_size_divisible_by: 128
#       pre_process: true
#       post_process: true
#       bert_binary_head: false
#       resume_from_checkpoint: null
#       masked_softmax_fusion: true
#       tokenizer:
#         library: huggingface
#         type: BertWordPieceLowerCase
#         model_name: facebook/esm2_t33_650M_UR50D
#         mask_id: 32
#         model: null
#         vocab_file: null
#         merge_file: null
#       native_amp_init_scale: 4294967296
#       native_amp_growth_interval: 1000
#       fp32_residual_connection: false
#       fp16_lm_cross_entropy: false
#       seed: 1234
#       use_cpu_initialization: false
#       onnx_safe: false
#       activations_checkpoint_method: null
#       activations_checkpoint_num_layers: 1
#       data:
#         ngc_registry_target: uniref50_2022_05
#         ngc_registry_version: v23.06
#         data_prefix: ''
#         num_workers: 8
#         dataloader_type: single
#         reset_position_ids: false
#         reset_attention_mask: false
#         eod_mask_loss: false
#         masked_lm_prob: 0.15
#         short_seq_prob: 0.1
#         skip_lines: 0
#         drop_last: false
#         pin_memory: false
#         dynamic_padding: false
#         force_regen_sample_mapping: false
#         dataset_path: examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50
#         index_mapping_dir: ${model.data.dataset_path}
#         preprocessing:
#           num_preprocess_workers: 16
#         train:
#           data_impl: csv_mmap
#           data_impl_kwargs:
#             csv_mmap:
#               data_col: 1
#               header_lines: 1
#           use_upsampling: true
#           range: x[000..049]
#           sample_from_map: true
#           uf50_datapath: ${model.data.dataset_path}/uniref50_train_filt.fasta
#           uf90_datapath: ${model.data.dataset_path}/uniref90membersandreps_ur50trainfiltreps.fasta
#           cluster_mapping_tsv: ${model.data.dataset_path}/uniref50_mapper_to_uniref90clustermembers_andselfuniref50.tsv
#           dataset_path: ${model.data.dataset_path}/uf50
#           sort_fastas: true
#           num_workers: ${model.data.num_workers}
#           uf90:
#             uniref90_path: ${model.data.dataset_path}/uf90
#             dataset:
#               uf90_csvs: x[000..049]
#             data_impl: csv_fields_mmap
#             data_impl_kwargs:
#               csv_fields_mmap:
#                 header_lines: 1
#                 newline_int: 10
#                 workers: ${model.data.train.num_workers}
#                 sort_dataset_paths: true
#                 data_sep: ','
#                 data_fields:
#                   sequence: 3
#                   sequence_id: 1
#             index_mapping_dir: ${model.data.index_mapping_dir}
#           index_mapping_dir: ${model.data.index_mapping_dir}
#           max_seq_length: ${model.seq_length}
#           seed: ${model.seed}
#         val:
#           use_upsampling: false
#           range: x[000..049]
#           uf50_datapath: ${model.data.dataset_path}/uniref50_train_filt.fasta
#           dataset_path: ${model.data.dataset_path}/uf50
#           data_impl: csv_fields_mmap
#           num_workers: ${model.data.num_workers}
#           data_impl_kwargs:
#             csv_fields_mmap:
#               header_lines: 1
#               newline_int: 10
#               workers: ${model.data.val.num_workers}
#               sort_dataset_paths: true
#               data_sep: ','
#               data_fields:
#                 sequence: 3
#                 sequence_id: 1
#           index_mapping_dir: ${model.data.index_mapping_dir}
#           max_seq_length: ${model.seq_length}
#           seed: ${model.seed}
#         test:
#           use_upsampling: false
#           range: x[000..049]
#           uf50_datapath: ${model.data.dataset_path}/uniref50_train_filt.fasta
#           dataset_path: ${model.data.dataset_path}/uf50
#           data_impl: csv_fields_mmap
#           num_workers: ${model.data.num_workers}
#           data_impl_kwargs:
#             csv_fields_mmap:
#               header_lines: 1
#               newline_int: 10
#               workers: ${model.data.test.num_workers}
#               sort_dataset_paths: true
#               data_sep: ','
#               data_fields:
#                 sequence: 3
#                 sequence_id: 1
#           index_mapping_dir: ${model.data.index_mapping_dir}
#           max_seq_length: ${model.seq_length}
#           seed: ${model.seed}
#         modify_percent: 0.1
#         perturb_percent: 0.5
#         uf90:
#           uniref90_path: examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf90
#       dwnstr_task_validation:
#         enabled: false
#         dataset:
#           class: bionemo.model.core.dwnstr_task_callbacks.PerTokenPredictionCallback
#           task_type: token-level-classification
#           infer_target: bionemo.model.protein.esm1nv.infer.ESM1nvInference
#           max_seq_length: ${model.seq_length}
#           emb_batch_size: 128
#           batch_size: 128
#           num_epochs: 10
#           shuffle: true
#           num_workers: 8
#           task_name: secondary_structure
#           dataset_path: ${oc.env:BIONEMO_HOME}/data/FLIP/${model.dwnstr_task_validation.dataset.task_name}
#           dataset:
#             train: x000
#             test: x000
#           sequence_column: sequence
#           target_column:
#           - 3state
#           target_sizes:
#           - 3
#           mask_column:
#           - resolved
#           random_seed: 1234
#           optim:
#             name: adam
#             lr: 0.0001
#             betas:
#             - 0.9
#             - 0.999
#             eps: 1.0e-08
#             weight_decay: 0.01
#             sched:
#               name: WarmupAnnealing
#               min_lr: 1.0e-05
#               last_epoch: -1
#               warmup_ratio: 0.01
#               max_steps: 1000
#       global_batch_size: 1
#       precision: 32
#
# [NeMo I 2024-05-14 15:41:14 pretrain:48] ************** Starting Training ***********
# [NeMo W 2024-05-14 15:41:14 megatron_base_model:821] The model: ESM2nvModel() does not have field.name: context_parallel_size in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-05-14 15:41:14 megatron_base_model:821] The model: ESM2nvModel() does not have field.name: virtual_pipeline_model_parallel_size in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-05-14 15:41:14 megatron_base_model:821] The model: ESM2nvModel() does not have field.name: sequence_parallel in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-05-14 15:41:14 megatron_base_model:821] The model: ESM2nvModel() does not have field.name: expert_model_parallel_size in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-05-14 15:41:14 megatron_base_model:821] The model: ESM2nvModel() does not have field.name: gradient_accumulation_fusion in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-05-14 15:41:14 megatron_base_model:821] The model: ESM2nvModel() does not have field.name: tp_comm_overlap in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-05-14 15:41:14 megatron_base_model:821] The model: ESM2nvModel() does not have field.name: tp_comm_split_ag in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-05-14 15:41:14 megatron_base_model:821] The model: ESM2nvModel() does not have field.name: tp_comm_split_rs in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-05-14 15:41:14 megatron_base_model:821] The model: ESM2nvModel() does not have field.name: tp_comm_bulk_wgrad in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-05-14 15:41:14 megatron_base_model:821] The model: ESM2nvModel() does not have field.name: tp_comm_bulk_dgrad in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-05-14 15:41:14 megatron_base_model:821] The model: ESM2nvModel() does not have field.name: finalize_model_grads_func in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-05-14 15:41:14 megatron_base_model:821] The model: ESM2nvModel() does not have field.name: overlap_p2p_comm in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-05-14 15:41:14 megatron_base_model:821] The model: ESM2nvModel() does not have field.name: batch_p2p_comm in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-05-14 15:41:14 megatron_base_model:821] The model: ESM2nvModel() does not have field.name: pipeline_model_parallel_split_rank in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-05-14 15:41:14 megatron_base_model:821] The model: ESM2nvModel() does not have field.name: barrier_with_L1_time in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo I 2024-05-14 15:41:14 megatron_init:234] Rank 0 has data parallel group: [0]
# [NeMo I 2024-05-14 15:41:14 megatron_init:237] All data parallel group ranks: [[0], [1]]
# [NeMo I 2024-05-14 15:41:14 megatron_init:238] Ranks 0 has data parallel rank: 0
# [NeMo I 2024-05-14 15:41:14 megatron_init:246] Rank 0 has model parallel group: [0, 1]
# [NeMo I 2024-05-14 15:41:14 megatron_init:247] All model parallel group ranks: [[0, 1]]
# [NeMo I 2024-05-14 15:41:14 megatron_init:257] Rank 0 has tensor model parallel group: [0, 1]
# [NeMo I 2024-05-14 15:41:14 megatron_init:261] All tensor model parallel group ranks: [[0, 1]]
# [NeMo I 2024-05-14 15:41:14 megatron_init:262] Rank 0 has tensor model parallel rank: 0
# [NeMo I 2024-05-14 15:41:14 megatron_init:276] Rank 0 has pipeline model parallel group: [0]
# [NeMo I 2024-05-14 15:41:14 megatron_init:288] Rank 0 has embedding group: [0]
# [NeMo I 2024-05-14 15:41:14 megatron_init:294] All pipeline model parallel group ranks: [[0], [1]]
# [NeMo I 2024-05-14 15:41:14 megatron_init:295] Rank 0 has pipeline model parallel rank 0
# [NeMo I 2024-05-14 15:41:14 megatron_init:296] All embedding group ranks: [[0], [1]]
# [NeMo I 2024-05-14 15:41:14 megatron_init:297] Rank 0 has embedding rank: 0
# 24-05-14 15:41:14 - PID:10330 - rank:(0, 0, 0, 0) - microbatches.py:39 - INFO - setting number of micro-batches to constant 1
# [NeMo W 2024-05-14 15:41:14 megatron_base_model:821] The model: ESM2nvModel() does not have field.name: context_parallel_size in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-05-14 15:41:14 megatron_base_model:821] The model: ESM2nvModel() does not have field.name: virtual_pipeline_model_parallel_size in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-05-14 15:41:14 megatron_base_model:821] The model: ESM2nvModel() does not have field.name: sequence_parallel in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-05-14 15:41:14 megatron_base_model:821] The model: ESM2nvModel() does not have field.name: expert_model_parallel_size in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-05-14 15:41:14 megatron_base_model:821] The model: ESM2nvModel() does not have field.name: gradient_accumulation_fusion in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-05-14 15:41:14 megatron_base_model:821] The model: ESM2nvModel() does not have field.name: tp_comm_overlap in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-05-14 15:41:14 megatron_base_model:821] The model: ESM2nvModel() does not have field.name: tp_comm_split_ag in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-05-14 15:41:14 megatron_base_model:821] The model: ESM2nvModel() does not have field.name: tp_comm_split_rs in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-05-14 15:41:14 megatron_base_model:821] The model: ESM2nvModel() does not have field.name: tp_comm_bulk_wgrad in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-05-14 15:41:14 megatron_base_model:821] The model: ESM2nvModel() does not have field.name: tp_comm_bulk_dgrad in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-05-14 15:41:14 megatron_base_model:821] The model: ESM2nvModel() does not have field.name: finalize_model_grads_func in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-05-14 15:41:14 megatron_base_model:821] The model: ESM2nvModel() does not have field.name: overlap_p2p_comm in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-05-14 15:41:14 megatron_base_model:821] The model: ESM2nvModel() does not have field.name: batch_p2p_comm in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-05-14 15:41:14 megatron_base_model:821] The model: ESM2nvModel() does not have field.name: pipeline_model_parallel_split_rank in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-05-14 15:41:14 megatron_base_model:821] The model: ESM2nvModel() does not have field.name: barrier_with_L1_time in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo I 2024-05-14 15:41:14 tokenizer_utils:182] Getting HuggingFace AutoTokenizer with pretrained_model_name: facebook/esm2_t33_650M_UR50D
# [NeMo I 2024-05-14 15:41:15 megatron_base_model:315] Padded vocab_size: 256, original vocab_size: 33, dummy tokens: 223.
# [NeMo W 2024-05-14 15:41:15 base:108] Using custom ESM2 Embeddings instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 attention:87] Using custom ESM2 attention instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 mlp:192] Using custom ESM2 GELU function instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 attention:87] Using custom ESM2 attention instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 mlp:192] Using custom ESM2 GELU function instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 attention:87] Using custom ESM2 attention instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 mlp:192] Using custom ESM2 GELU function instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 attention:87] Using custom ESM2 attention instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 mlp:192] Using custom ESM2 GELU function instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 attention:87] Using custom ESM2 attention instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 mlp:192] Using custom ESM2 GELU function instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 attention:87] Using custom ESM2 attention instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 mlp:192] Using custom ESM2 GELU function instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 attention:87] Using custom ESM2 attention instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 mlp:192] Using custom ESM2 GELU function instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 attention:87] Using custom ESM2 attention instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 mlp:192] Using custom ESM2 GELU function instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 attention:87] Using custom ESM2 attention instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 mlp:192] Using custom ESM2 GELU function instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 attention:87] Using custom ESM2 attention instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 mlp:192] Using custom ESM2 GELU function instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 attention:87] Using custom ESM2 attention instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 mlp:192] Using custom ESM2 GELU function instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 attention:87] Using custom ESM2 attention instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 mlp:192] Using custom ESM2 GELU function instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 attention:87] Using custom ESM2 attention instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 mlp:192] Using custom ESM2 GELU function instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 attention:87] Using custom ESM2 attention instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 mlp:192] Using custom ESM2 GELU function instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 attention:87] Using custom ESM2 attention instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 mlp:192] Using custom ESM2 GELU function instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 attention:87] Using custom ESM2 attention instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 mlp:192] Using custom ESM2 GELU function instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 attention:87] Using custom ESM2 attention instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 mlp:192] Using custom ESM2 GELU function instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 attention:87] Using custom ESM2 attention instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 mlp:192] Using custom ESM2 GELU function instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 attention:87] Using custom ESM2 attention instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 mlp:192] Using custom ESM2 GELU function instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 attention:87] Using custom ESM2 attention instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 mlp:192] Using custom ESM2 GELU function instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 attention:87] Using custom ESM2 attention instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 mlp:192] Using custom ESM2 GELU function instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 attention:87] Using custom ESM2 attention instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 mlp:192] Using custom ESM2 GELU function instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 attention:87] Using custom ESM2 attention instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 mlp:192] Using custom ESM2 GELU function instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 attention:87] Using custom ESM2 attention instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 mlp:192] Using custom ESM2 GELU function instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 attention:87] Using custom ESM2 attention instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 mlp:192] Using custom ESM2 GELU function instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 attention:87] Using custom ESM2 attention instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 mlp:192] Using custom ESM2 GELU function instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 attention:87] Using custom ESM2 attention instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 mlp:192] Using custom ESM2 GELU function instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 attention:87] Using custom ESM2 attention instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 mlp:192] Using custom ESM2 GELU function instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 attention:87] Using custom ESM2 attention instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 mlp:192] Using custom ESM2 GELU function instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 attention:87] Using custom ESM2 attention instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 mlp:192] Using custom ESM2 GELU function instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 attention:87] Using custom ESM2 attention instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 mlp:192] Using custom ESM2 GELU function instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 attention:87] Using custom ESM2 attention instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 mlp:192] Using custom ESM2 GELU function instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 attention:87] Using custom ESM2 attention instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 mlp:192] Using custom ESM2 GELU function instead of the default NeMo version
# [NeMo W 2024-05-14 15:41:15 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/configuration_validator.py:153: UserWarning: The `batch_idx` argument in `ESM2nvModel.on_train_batch_start` hook may not match with the actual batch index when using a `dataloader_iter` argument in your `training_step`.
#       rank_zero_warn(
#
# [NeMo W 2024-05-14 15:41:15 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/configuration_validator.py:153: UserWarning: The `batch_idx` argument in `ESM2nvModel.on_train_batch_end` hook may not match with the actual batch index when using a `dataloader_iter` argument in your `training_step`.
#       rank_zero_warn(
#
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/2
# Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/2
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 2 processes
# ----------------------------------------------------------------------------------------------------
#
# [NeMo W 2024-05-14 15:41:42 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/pytorch_lightning/callbacks/model_checkpoint.py:617: UserWarning: Checkpoint directory /workspace/bionemo/results/nemo_experiments/esm2-650M/esm2-650M_pretraining/checkpoints exists and is not empty.
#       rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
#
# Pipeline model parallel rank: 0, Tensor model parallel rank: 0, Number of model parameters on device: 3.27e+08. Total number of model parameters: 6.53e+08.
# Pipeline model parallel rank: 0, Tensor model parallel rank: 1, Number of model parameters on device: 3.27e+08. Total number of model parameters: 6.53e+08.
# Loading data from examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x000.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x001.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x002.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x003.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x004.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x005.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x006.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x007.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x008.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x009.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x010.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x011.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x012.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x013.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x014.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x015.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x016.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x017.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x018.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x019.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x020.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x021.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x022.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x023.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x024.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x025.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x026.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x027.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x028.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x029.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x030.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x031.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x032.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x033.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x034.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x035.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x036.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x037.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x038.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x039.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x040.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x041.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x042.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x043.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x044.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/u ...
# Loading data from examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x000.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x001.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x002.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x003.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x004.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x005.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x006.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x007.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x008.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x009.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x010.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x011.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x012.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x013.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x014.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x015.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x016.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x017.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x018.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x019.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x020.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x021.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x022.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x023.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x024.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x025.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x026.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x027.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x028.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x029.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x030.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x031.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x032.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x033.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x034.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x035.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x036.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x037.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x038.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x039.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x040.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x041.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x042.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x043.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x044.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/u ...
# [NeMo I 2024-05-14 15:41:43 text_memmap_dataset:116] Building data files
# [NeMo I 2024-05-14 15:41:43 text_memmap_dataset:525] Processing 50 data files using 127 workers
# [NeMo I 2024-05-14 15:41:46 text_memmap_dataset:535] Time building 0 / 50 mem-mapped files: 0:00:03.464624
# [NeMo I 2024-05-14 15:41:46 text_memmap_dataset:525] Processing 50 data files using 127 workers
# [NeMo I 2024-05-14 15:41:53 text_memmap_dataset:535] Time building 0 / 50 mem-mapped files: 0:00:06.548318
# [NeMo I 2024-05-14 15:41:53 text_memmap_dataset:158] Loading data files
# [NeMo I 2024-05-14 15:41:53 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x000.csv
# [NeMo I 2024-05-14 15:41:53 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x001.csv
# [NeMo I 2024-05-14 15:41:53 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x002.csv
# [NeMo I 2024-05-14 15:41:53 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x003.csv
# [NeMo I 2024-05-14 15:41:53 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x004.csv
# [NeMo I 2024-05-14 15:41:53 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x005.csv
# [NeMo I 2024-05-14 15:41:53 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x006.csv
# [NeMo I 2024-05-14 15:41:53 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x007.csv
# [NeMo I 2024-05-14 15:41:53 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x008.csv
# [NeMo I 2024-05-14 15:41:53 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x009.csv
# [NeMo I 2024-05-14 15:41:53 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x010.csv
# [NeMo I 2024-05-14 15:41:53 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x011.csv
# [NeMo I 2024-05-14 15:41:53 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x012.csv
# [NeMo I 2024-05-14 15:41:53 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/train/x013.csv
# ...
# [NeMo I 2024-05-14 15:41:55 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/val/x049.csv
# [NeMo I 2024-05-14 15:41:55 text_memmap_dataset:161] Time loading 50 mem-mapped files: 0:00:00.026753
# [NeMo I 2024-05-14 15:41:55 text_memmap_dataset:165] Computing global indices
# [NeMo I 2024-05-14 15:41:55 esm1nv_model:704] Length of val dataset: 5001
# Loading data from examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x000.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x001.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x002.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x003.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x004.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x005.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x006.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x007.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x008.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x009.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x010.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x011.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x012.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x013.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x014.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x015.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x016.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x017.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x018.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x019.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x020.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x021.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x022.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x023.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x024.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x025.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x026.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x027.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x028.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x029.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x030.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x031.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x032.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x033.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x034.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x035.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x036.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x037.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x038.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x039.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x040.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x041.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x042.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x043.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x044.csv, examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x045.csv, examples/tests/test_data/u ...
# [NeMo I 2024-05-14 15:41:55 text_memmap_dataset:116] Building data files
# [NeMo I 2024-05-14 15:41:55 text_memmap_dataset:525] Processing 50 data files using 8 workers
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:535] Time building 0 / 50 mem-mapped files: 0:00:00.439372
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:525] Processing 50 data files using 8 workers
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:535] Time building 0 / 50 mem-mapped files: 0:00:00.439599
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:158] Loading data files
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x000.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x001.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x002.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x003.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x004.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x005.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x006.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x007.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x008.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x009.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x010.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x011.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x012.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x013.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x014.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x015.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x016.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x017.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x018.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x019.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x020.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x021.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x022.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x023.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x024.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x025.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x026.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x027.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x028.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x029.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x030.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x031.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x032.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x033.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x034.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x035.csv
# Setting up train dataloader with len(len(self._train_ds)): 30 and consumed samples: 45
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x036.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x037.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x038.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x039.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x040.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x041.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x042.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x043.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x044.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x045.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x046.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x047.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x048.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:249] Loading examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/uf50/test/x049.csv
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:161] Time loading 50 mem-mapped files: 0:00:00.027567
# [NeMo I 2024-05-14 15:41:56 text_memmap_dataset:165] Computing global indices
# [NeMo I 2024-05-14 15:41:56 esm1nv_model:711] Length of test dataset: 5001
# Setting up train dataloader with len(len(self._train_ds)): 30 and consumed samples: 45
# [NeMo I 2024-05-14 15:41:56 data_samplers:76] Instantiating MegatronPretrainingSampler with total_samples: 30 and consumed_samples: 45
# [NeMo I 2024-05-14 15:41:56 data_samplers:76] Instantiating MegatronPretrainingSampler with total_samples: 5001 and consumed_samples: 0
# [NeMo I 2024-05-14 15:41:56 data_samplers:76] Instantiating MegatronPretrainingSampler with total_samples: 5001 and consumed_samples: 0
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1]
# [NeMo I 2024-05-14 15:41:56 nlp_overrides:150] Configuring DDP for model parallelism.
# [NeMo I 2024-05-14 15:41:56 modelPT:728] Optimizer config = FusedAdam (
#     Parameter Group 0
#         betas: [0.9, 0.98]
#         bias_correction: True
#         eps: 1e-08
#         lr: 0.0004
#         weight_decay: 0.01
#
#     Parameter Group 1
#         betas: [0.9, 0.98]
#         bias_correction: True
#         eps: 1e-08
#         lr: 0.0004
#         weight_decay: 0.0
#     )
# [NeMo I 2024-05-14 15:41:56 lr_scheduler:943] Scheduler "<nemo.core.optim.lr_scheduler.WarmupAnnealDecayHold object at 0x7ff94b509390>"
#     will be used during training (effective maximum steps = 30) -
#     Parameters :
#     (warmup_steps: 2000
#     min_lr: 4.0e-05
#     max_lr: 0.0004
#     max_steps: 30
#     anneal_percentage: 0.1
#     )
#
#   | Name                                | Type                          | Params
# --------------------------------------------------------------------------------------
# 0 | model                               | ESMnvBertModel                | 326 M
# 1 | model.language_model                | ESMnvTransformerLanguageModel | 324 M
# 2 | model.language_model.embedding      | ESMnvEmbedding                | 163 K
# 3 | model.language_model.rotary_pos_emb | RotaryEmbedding               | 0
# 4 | model.language_model.encoder        | ESMnvParallelTransformer      | 324 M
# 5 | model.lm_head                       | BertLMHead                    | 1.6 M
# 6 | model.lm_head.dense                 | Linear                        | 1.6 M
# 7 | model.lm_head.layernorm             | MixedFusedLayerNorm           | 2.6 K
# --------------------------------------------------------------------------------------
# 326 M     Trainable params
# 0         Non-trainable params
# 326 M     Total params
# 1,306.453 Total estimated model params size (MB)
# Restoring states from the checkpoint path at /workspace/bionemo/results/nemo_experiments/esm2-650M/esm2-650M_pretraining/checkpoints/megatron_bert--val_loss=3.10-step=45-consumed_samples=45.0-last.ckpt
# Restored all states from the checkpoint at /workspace/bionemo/results/nemo_experiments/esm2-650M/esm2-650M_pretraining/checkpoints/megatron_bert--val_loss=3.10-step=45-consumed_samples=45.0-last.ckpt
# `Trainer.fit` stopped: `max_steps=30` reached.
# [NeMo I 2024-05-14 15:42:02 pretrain:57] ************** Finished Training ***********
# wandb: Waiting for W&B process to finish... (success).
# wandb: You can sync this run to the cloud by running:
# wandb: wandb sync /workspace/bionemo/results/nemo_experiments/esm2-650M/esm2-650M_pretraining/wandb/offline-run-20240514_154114-yoh718j3
# wandb: Find logs at: ./results/nemo_experiments/esm2-650M/esm2-650M_pretraining/wandb/offline-run-20240514_154114-yoh718j3/logs

# %% [markdown]
# パラメータの説明：
# * do_training: モデルをトレーニングするために True に設定します。これはデータが前処理されたことを前提としています。
# * do_testing: テストをスキップするために False に設定します。
# * model.data.dataset_path: トレーニング/検証/テスト分割が含まれる前処理済みのuniref50データフォルダのパスを指定します。
# * model.data.uf90.uniref90_path: 前処理済みの uniref90 データのパスを指定します。このフォルダには u90_csvs という別のフォルダが含まれている必要があります。u90_csvs フォルダ内には、x000.csv から x049.csv のファイルが存在する必要があります。
# * trainer.devices: 使用するGPUの数を指定します。
# * model.tensor_model_parallel_size: テンソルモデル並列サイズを設定します。
# * model.micro_batch_size: バッチサイズを設定します。メモリエラーが発生しない限り、これをできるだけ増やします。
# * trainer.max_steps: トレーニングの最大ステップ数を指定します。デモのために 100 に設定しました。1 ステップ = 1 バッチの処理です。まず、total_batches = サンプル総数 / バッチサイズを計算します。N エポックでトレーニングしたい場合は、max_steps をN * total_batches に設定します。
# * trainer.val_check_interval: 検証セットを実行する間隔を指定します。
# * exp_manager.create_wandb_logger: wandb へのログ記録を無効にするために False に設定します。True の場合は、wandb API キーを提供する必要があります。
# * exp_manager.checkpoint_callback_params.save_top_k: 保存する最適のチェックポイントの数を指定します。
# トレーニングされた結果が /workspace/bionemo/results/nemo_experiments/ に保存されます。

# %% [markdown]
# # ファインチューニング

# %% [markdown]
# BioNemo Framework のサンプルコードは三つの下流タスクを提供しています。一つ目はタンパク質の 10 の細胞内局在部位を予測すること、二つ目はタンパク質の融解温度を予測すること、三つ目はタンパク質の 3 状態構造を予測することです。本記事では三つ目のタスクを例として説明します。具体的には、シーケンスの各アミノ酸について、それがヘリックス、シート、またはコイルのどれにあるかを予測します。
# サンプルデータは下記のフォルダにあります。
#
# /workspace/bionemo/examples/tests/test_data/protein/downstream/

# %% [markdown]
# 次に、事前学習済みモデルをダウンロードします。モデルをダウンロードするため、ngc をインストールして、ngc config を設定する必要があります。

# %%
# !wget -q -O /tmp/ngccli_linux.zip --content-disposition https://api.ngc.nvidia.com/v2/resources/nvidia/ngc-apps/ngc_cli/versions/3.38.0/files/ngccli_linux.zip && unzip -o /tmp/ngccli_linux.zip -d /tmp && chmod u+x /tmp/ngc-cli/ngc && rm /tmp/ngccli_linux.zip
# Out:
# Archive:  /tmp/ngccli_linux.zip
#   inflating: /tmp/ngc-cli/boto3/examples/s3.rst
#   inflating: /tmp/ngc-cli/boto3/examples/cloudfront.rst
#   inflating: /tmp/ngc-cli/boto3/data/dynamodb/2012-08-10/resources-1.json
#   inflating: /tmp/ngc-cli/boto3/data/sqs/2012-11-05/resources-1.json
#   inflating: /tmp/ngc-cli/boto3/data/opsworks/2013-02-18/resources-1.json
#   inflating: /tmp/ngc-cli/boto3/data/iam/2010-05-08/resources-1.json
#   inflating: /tmp/ngc-cli/boto3/data/ec2/2014-10-01/resources-1.json
#   inflating: /tmp/ngc-cli/boto3/data/ec2/2015-10-01/resources-1.json
#   inflating: /tmp/ngc-cli/boto3/data/ec2/2015-03-01/resources-1.json
#   inflating: /tmp/ngc-cli/boto3/data/ec2/2016-09-15/resources-1.json
#   inflating: /tmp/ngc-cli/boto3/data/ec2/2016-04-01/resources-1.json
#   inflating: /tmp/ngc-cli/boto3/data/ec2/2015-04-15/resources-1.json
#   inflating: /tmp/ngc-cli/boto3/data/ec2/2016-11-15/resources-1.json
#   inflating: /tmp/ngc-cli/boto3/data/s3/2006-03-01/resources-1.json
#   inflating: /tmp/ngc-cli/boto3/data/sns/2010-03-31/resources-1.json
#   inflating: /tmp/ngc-cli/boto3/data/cloudformation/2010-05-15/resources-1.json
#   inflating: /tmp/ngc-cli/boto3/data/cloudwatch/2010-08-01/resources-1.json
#   inflating: /tmp/ngc-cli/boto3/data/glacier/2012-06-01/resources-1.json
#   inflating: /tmp/ngc-cli/attrs-23.2.0.dist-info/RECORD
#   inflating: /tmp/ngc-cli/attrs-23.2.0.dist-info/METADATA
#   inflating: /tmp/ngc-cli/attrs-23.2.0.dist-info/WHEEL
#   inflating: /tmp/ngc-cli/attrs-23.2.0.dist-info/licenses/LICENSE
#  extracting: /tmp/ngc-cli/attrs-23.2.0.dist-info/INSTALLER
#   inflating: /tmp/ngc-cli/pycares/_cares.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/zipp-3.17.0.dist-info/RECORD
#   inflating: /tmp/ngc-cli/zipp-3.17.0.dist-info/LICENSE
#   inflating: /tmp/ngc-cli/zipp-3.17.0.dist-info/METADATA
#  extracting: /tmp/ngc-cli/zipp-3.17.0.dist-info/WHEEL
#  extracting: /tmp/ngc-cli/zipp-3.17.0.dist-info/INSTALLER
#  extracting: /tmp/ngc-cli/zipp-3.17.0.dist-info/top_level.txt
#   inflating: /tmp/ngc-cli/grpc/_cython/_credentials/roots.pem
#   inflating: /tmp/ngc-cli/grpc/_cython/cygrpc.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/libcrypto.so.10
#   inflating: /tmp/ngc-cli/wrapt-1.16.0.dist-info/RECORD
#   inflating: /tmp/ngc-cli/wrapt-1.16.0.dist-info/LICENSE
#   inflating: /tmp/ngc-cli/wrapt-1.16.0.dist-info/METADATA
#   inflating: /tmp/ngc-cli/wrapt-1.16.0.dist-info/WHEEL
#  extracting: /tmp/ngc-cli/wrapt-1.16.0.dist-info/INSTALLER
#  extracting: /tmp/ngc-cli/wrapt-1.16.0.dist-info/top_level.txt
#   inflating: /tmp/ngc-cli/main.so
#   inflating: /tmp/ngc-cli/opentelemetry_instrumentation-0.41b0.dist-info/RECORD
#   inflating: /tmp/ngc-cli/opentelemetry_instrumentation-0.41b0.dist-info/entry_points.txt
#   inflating: /tmp/ngc-cli/opentelemetry_instrumentation-0.41b0.dist-info/METADATA
#  extracting: /tmp/ngc-cli/opentelemetry_instrumentation-0.41b0.dist-info/WHEEL
#   inflating: /tmp/ngc-cli/opentelemetry_instrumentation-0.41b0.dist-info/licenses/LICENSE
#  extracting: /tmp/ngc-cli/opentelemetry_instrumentation-0.41b0.dist-info/INSTALLER
#   inflating: /tmp/ngc-cli/libkrb5support.so.0
#   inflating: /tmp/ngc-cli/wrapt/_wrappers.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/libcom_err.so.2
#   inflating: /tmp/ngc-cli/cryptography/hazmat/bindings/_rust.abi3.so
#   inflating: /tmp/ngc-cli/backoff-2.2.1.dist-info/RECORD
#   inflating: /tmp/ngc-cli/backoff-2.2.1.dist-info/LICENSE
#   inflating: /tmp/ngc-cli/backoff-2.2.1.dist-info/METADATA
#   inflating: /tmp/ngc-cli/backoff-2.2.1.dist-info/WHEEL
#  extracting: /tmp/ngc-cli/backoff-2.2.1.dist-info/INSTALLER
#   inflating: /tmp/ngc-cli/libpcre.so.1
#   inflating: /tmp/ngc-cli/libgssapi_krb5.so.2
#   inflating: /tmp/ngc-cli/grpcio-1.60.0.dist-info/RECORD
#   inflating: /tmp/ngc-cli/grpcio-1.60.0.dist-info/LICENSE
#   inflating: /tmp/ngc-cli/grpcio-1.60.0.dist-info/METADATA
#   inflating: /tmp/ngc-cli/grpcio-1.60.0.dist-info/WHEEL
#  extracting: /tmp/ngc-cli/grpcio-1.60.0.dist-info/INSTALLER
#  extracting: /tmp/ngc-cli/grpcio-1.60.0.dist-info/top_level.txt
#   inflating: /tmp/ngc-cli/opentelemetry_exporter_otlp_proto_grpc-1.22.0.dist-info/RECORD
#   inflating: /tmp/ngc-cli/opentelemetry_exporter_otlp_proto_grpc-1.22.0.dist-info/entry_points.txt
#   inflating: /tmp/ngc-cli/opentelemetry_exporter_otlp_proto_grpc-1.22.0.dist-info/METADATA
#  extracting: /tmp/ngc-cli/opentelemetry_exporter_otlp_proto_grpc-1.22.0.dist-info/WHEEL
#   inflating: /tmp/ngc-cli/opentelemetry_exporter_otlp_proto_grpc-1.22.0.dist-info/licenses/LICENSE
#  extracting: /tmp/ngc-cli/opentelemetry_exporter_otlp_proto_grpc-1.22.0.dist-info/INSTALLER
#   inflating: /tmp/ngc-cli/libgcc_s.so.1
#   inflating: /tmp/ngc-cli/opentelemetry/context/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/context/context.py
#   inflating: /tmp/ngc-cli/opentelemetry/context/__pycache__/context.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/context/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/context/contextvars_context.py
#   inflating: /tmp/ngc-cli/opentelemetry/instrumentation/distro.py
#   inflating: /tmp/ngc-cli/opentelemetry/instrumentation/utils.py
#   inflating: /tmp/ngc-cli/opentelemetry/instrumentation/environment_variables.py
#   inflating: /tmp/ngc-cli/opentelemetry/instrumentation/instrumentor.py
#   inflating: /tmp/ngc-cli/opentelemetry/instrumentation/auto_instrumentation/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/instrumentation/auto_instrumentation/_load.py
#   inflating: /tmp/ngc-cli/opentelemetry/instrumentation/auto_instrumentation/sitecustomize.py
#   inflating: /tmp/ngc-cli/opentelemetry/instrumentation/bootstrap_gen.py
#   inflating: /tmp/ngc-cli/opentelemetry/instrumentation/version.py
#   inflating: /tmp/ngc-cli/opentelemetry/instrumentation/sqlcommenter_utils.py
#   inflating: /tmp/ngc-cli/opentelemetry/instrumentation/bootstrap.py
#   inflating: /tmp/ngc-cli/opentelemetry/instrumentation/propagators.py
#   inflating: /tmp/ngc-cli/opentelemetry/instrumentation/dependencies.py
#  extracting: /tmp/ngc-cli/opentelemetry/instrumentation/py.typed
#   inflating: /tmp/ngc-cli/opentelemetry/util/re.py
#   inflating: /tmp/ngc-cli/opentelemetry/util/_importlib_metadata.py
#   inflating: /tmp/ngc-cli/opentelemetry/util/types.py
#   inflating: /tmp/ngc-cli/opentelemetry/util/_once.py
#   inflating: /tmp/ngc-cli/opentelemetry/util/_providers.py
#   inflating: /tmp/ngc-cli/opentelemetry/util/__pycache__/re.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/util/__pycache__/_once.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/util/__pycache__/types.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/util/__pycache__/_importlib_metadata.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/util/__pycache__/_providers.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/environment_variables.py
#   inflating: /tmp/ngc-cli/opentelemetry/attributes/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/attributes/__pycache__/__init__.cpython-39.pyc
#  extracting: /tmp/ngc-cli/opentelemetry/proto/resource/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/resource/v1/resource_pb2.pyi
#  extracting: /tmp/ngc-cli/opentelemetry/proto/resource/v1/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/resource/v1/resource_pb2.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/resource/v1/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/proto/resource/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/proto/logs/v1/logs_pb2.pyi
#   inflating: /tmp/ngc-cli/opentelemetry/proto/logs/v1/logs_pb2.py
#  extracting: /tmp/ngc-cli/opentelemetry/proto/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/collector/logs/v1/logs_service_pb2.pyi
#   inflating: /tmp/ngc-cli/opentelemetry/proto/collector/logs/v1/logs_service_pb2.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/collector/logs/v1/logs_service_pb2_grpc.py
#  extracting: /tmp/ngc-cli/opentelemetry/proto/collector/__init__.py
#  extracting: /tmp/ngc-cli/opentelemetry/proto/collector/metrics/__init__.py
#  extracting: /tmp/ngc-cli/opentelemetry/proto/collector/metrics/v1/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/collector/metrics/v1/metrics_service_pb2.pyi
#   inflating: /tmp/ngc-cli/opentelemetry/proto/collector/metrics/v1/metrics_service_pb2.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/collector/metrics/v1/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/proto/collector/metrics/v1/metrics_service_pb2_grpc.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/collector/metrics/__pycache__/__init__.cpython-39.pyc
#  extracting: /tmp/ngc-cli/opentelemetry/proto/collector/trace/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/collector/trace/v1/trace_service_pb2.pyi
#  extracting: /tmp/ngc-cli/opentelemetry/proto/collector/trace/v1/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/collector/trace/v1/trace_service_pb2_grpc.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/collector/trace/v1/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/proto/collector/trace/v1/trace_service_pb2.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/collector/trace/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/proto/collector/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/proto/version.py
#  extracting: /tmp/ngc-cli/opentelemetry/proto/metrics/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/metrics/v1/metrics_pb2.pyi
#  extracting: /tmp/ngc-cli/opentelemetry/proto/metrics/v1/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/metrics/v1/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/proto/metrics/v1/metrics_pb2.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/metrics/__pycache__/__init__.cpython-39.pyc
#  extracting: /tmp/ngc-cli/opentelemetry/proto/trace/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/trace/v1/trace_pb2.pyi
#   inflating: /tmp/ngc-cli/opentelemetry/proto/trace/v1/trace_pb2.py
#  extracting: /tmp/ngc-cli/opentelemetry/proto/trace/v1/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/trace/v1/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/proto/trace/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/proto/__pycache__/__init__.cpython-39.pyc
#  extracting: /tmp/ngc-cli/opentelemetry/proto/common/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/common/v1/common_pb2.py
#  extracting: /tmp/ngc-cli/opentelemetry/proto/common/v1/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/common/v1/common_pb2.pyi
#   inflating: /tmp/ngc-cli/opentelemetry/proto/common/v1/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/proto/common/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/propagators/__pycache__/composite.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/propagators/__pycache__/textmap.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/propagators/composite.py
#   inflating: /tmp/ngc-cli/opentelemetry/propagators/textmap.py
#   inflating: /tmp/ngc-cli/opentelemetry/version.py
#   inflating: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/grpc/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/grpc/trace_exporter/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/grpc/version.py
#  extracting: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/grpc/py.typed
#   inflating: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/grpc/metric_exporter/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/grpc/exporter.py
#   inflating: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/grpc/_log_exporter/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/common/_internal/trace_encoder/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/common/_internal/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/common/_internal/metrics_encoder/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/common/_internal/_log_encoder/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/common/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/common/version.py
#   inflating: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/common/trace_encoder.py
#   inflating: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/common/_log_encoder.py
#  extracting: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/common/py.typed
#   inflating: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/common/metrics_encoder.py
#   inflating: /tmp/ngc-cli/opentelemetry/semconv/resource/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/semconv/resource/__pycache__/__init__.cpython-39.pyc
#  extracting: /tmp/ngc-cli/opentelemetry/semconv/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/semconv/version.py
#   inflating: /tmp/ngc-cli/opentelemetry/semconv/metrics/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/semconv/metrics/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/semconv/trace/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/semconv/trace/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/semconv/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/baggage/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/baggage/propagation/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/baggage/propagation/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/baggage/__pycache__/__init__.cpython-39.pyc
#  extracting: /tmp/ngc-cli/opentelemetry/py.typed
#   inflating: /tmp/ngc-cli/opentelemetry/propagate/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/propagate/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/metrics/_internal/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/metrics/_internal/instrument.py
#   inflating: /tmp/ngc-cli/opentelemetry/metrics/_internal/__pycache__/observation.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/metrics/_internal/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/metrics/_internal/__pycache__/instrument.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/metrics/_internal/observation.py
#   inflating: /tmp/ngc-cli/opentelemetry/metrics/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/metrics/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/trace/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/trace/propagation/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/trace/propagation/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/trace/propagation/__pycache__/tracecontext.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/trace/propagation/tracecontext.py
#   inflating: /tmp/ngc-cli/opentelemetry/trace/status.py
#   inflating: /tmp/ngc-cli/opentelemetry/trace/span.py
#   inflating: /tmp/ngc-cli/opentelemetry/trace/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/trace/__pycache__/span.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/trace/__pycache__/status.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/__pycache__/environment_variables.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/__init__.pyi
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/util/__init__.pyi
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/util/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/util/instrumentation.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/environment_variables.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/_configuration/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/version.py
#  extracting: /tmp/ngc-cli/opentelemetry/sdk/py.typed
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/point.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/sdk_configuration.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/exponential_histogram/mapping/ieee_754.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/exponential_histogram/mapping/logarithm_mapping.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/exponential_histogram/mapping/exponent_mapping.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/exponential_histogram/mapping/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/exponential_histogram/mapping/errors.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/exponential_histogram/mapping/ieee_754.md
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/exponential_histogram/buckets.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/exceptions.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/measurement_consumer.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/export/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/metric_reader_storage.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/_view_instrument_match.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/aggregation.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/view.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/instrument.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/measurement.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/export/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/view/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/trace/export/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/trace/export/in_memory_span_exporter.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/trace/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/trace/id_generator.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/trace/sampling.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/resources/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/error_handler/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/_logs/_internal/export/in_memory_log_exporter.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/_logs/_internal/export/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/_logs/_internal/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/_logs/export/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/_logs/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/_logs/_internal/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/_logs/_internal/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/_logs/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/_logs/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/_logs/severity/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/_logs/severity/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/libpython3.9.so.1.0
#  extracting: /tmp/ngc-cli/certifi/py.typed
#   inflating: /tmp/ngc-cli/certifi/cacert.pem
#   inflating: /tmp/ngc-cli/frozenlist/_frozenlist.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/opentelemetry_api-1.22.0.dist-info/RECORD
#   inflating: /tmp/ngc-cli/opentelemetry_api-1.22.0.dist-info/entry_points.txt
#   inflating: /tmp/ngc-cli/opentelemetry_api-1.22.0.dist-info/METADATA
#  extracting: /tmp/ngc-cli/opentelemetry_api-1.22.0.dist-info/WHEEL
#   inflating: /tmp/ngc-cli/opentelemetry_api-1.22.0.dist-info/licenses/LICENSE
#  extracting: /tmp/ngc-cli/opentelemetry_api-1.22.0.dist-info/INSTALLER
#   inflating: /tmp/ngc-cli/opentelemetry_proto-1.22.0.dist-info/RECORD
#   inflating: /tmp/ngc-cli/opentelemetry_proto-1.22.0.dist-info/METADATA
#  extracting: /tmp/ngc-cli/opentelemetry_proto-1.22.0.dist-info/WHEEL
#   inflating: /tmp/ngc-cli/opentelemetry_proto-1.22.0.dist-info/licenses/LICENSE
#  extracting: /tmp/ngc-cli/opentelemetry_proto-1.22.0.dist-info/INSTALLER
#   inflating: /tmp/ngc-cli/libfreebl3.so
#   inflating: /tmp/ngc-cli/protobuf-3.20.3.dist-info/RECORD
#   inflating: /tmp/ngc-cli/protobuf-3.20.3.dist-info/METADATA
#  extracting: /tmp/ngc-cli/protobuf-3.20.3.dist-info/namespace_packages.txt
#   inflating: /tmp/ngc-cli/protobuf-3.20.3.dist-info/WHEEL
#  extracting: /tmp/ngc-cli/protobuf-3.20.3.dist-info/INSTALLER
#  extracting: /tmp/ngc-cli/protobuf-3.20.3.dist-info/top_level.txt
#   inflating: /tmp/ngc-cli/multidict/_multidict.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/libkrb5.so.3
#   inflating: /tmp/ngc-cli/opentelemetry_exporter_otlp_proto_common-1.22.0.dist-info/RECORD
#   inflating: /tmp/ngc-cli/opentelemetry_exporter_otlp_proto_common-1.22.0.dist-info/METADATA
#  extracting: /tmp/ngc-cli/opentelemetry_exporter_otlp_proto_common-1.22.0.dist-info/WHEEL
#   inflating: /tmp/ngc-cli/opentelemetry_exporter_otlp_proto_common-1.22.0.dist-info/licenses/LICENSE
#  extracting: /tmp/ngc-cli/opentelemetry_exporter_otlp_proto_common-1.22.0.dist-info/INSTALLER
#   inflating: /tmp/ngc-cli/yarl/_quoting_c.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/cryptography-41.0.7.dist-info/RECORD
#   inflating: /tmp/ngc-cli/cryptography-41.0.7.dist-info/LICENSE.BSD
#   inflating: /tmp/ngc-cli/cryptography-41.0.7.dist-info/LICENSE
#   inflating: /tmp/ngc-cli/cryptography-41.0.7.dist-info/METADATA
#   inflating: /tmp/ngc-cli/cryptography-41.0.7.dist-info/LICENSE.APACHE
#   inflating: /tmp/ngc-cli/cryptography-41.0.7.dist-info/WHEEL
#  extracting: /tmp/ngc-cli/cryptography-41.0.7.dist-info/INSTALLER
#  extracting: /tmp/ngc-cli/cryptography-41.0.7.dist-info/top_level.txt
#   inflating: /tmp/ngc-cli/googleapis_common_protos-1.62.0.dist-info/RECORD
#   inflating: /tmp/ngc-cli/googleapis_common_protos-1.62.0.dist-info/LICENSE
#   inflating: /tmp/ngc-cli/googleapis_common_protos-1.62.0.dist-info/METADATA
#   inflating: /tmp/ngc-cli/googleapis_common_protos-1.62.0.dist-info/WHEEL
#  extracting: /tmp/ngc-cli/googleapis_common_protos-1.62.0.dist-info/INSTALLER
#  extracting: /tmp/ngc-cli/googleapis_common_protos-1.62.0.dist-info/top_level.txt
#   inflating: /tmp/ngc-cli/opentelemetry_semantic_conventions-0.43b0.dist-info/RECORD
#   inflating: /tmp/ngc-cli/opentelemetry_semantic_conventions-0.43b0.dist-info/METADATA
#  extracting: /tmp/ngc-cli/opentelemetry_semantic_conventions-0.43b0.dist-info/WHEEL
#   inflating: /tmp/ngc-cli/opentelemetry_semantic_conventions-0.43b0.dist-info/licenses/LICENSE
#  extracting: /tmp/ngc-cli/opentelemetry_semantic_conventions-0.43b0.dist-info/INSTALLER
#   inflating: /tmp/ngc-cli/ngc
#   inflating: /tmp/ngc-cli/libstdc++.so.6
#   inflating: /tmp/ngc-cli/opentelemetry_sdk-1.22.0.dist-info/RECORD
#   inflating: /tmp/ngc-cli/opentelemetry_sdk-1.22.0.dist-info/entry_points.txt
#   inflating: /tmp/ngc-cli/opentelemetry_sdk-1.22.0.dist-info/METADATA
#  extracting: /tmp/ngc-cli/opentelemetry_sdk-1.22.0.dist-info/WHEEL
#   inflating: /tmp/ngc-cli/opentelemetry_sdk-1.22.0.dist-info/licenses/LICENSE
#  extracting: /tmp/ngc-cli/opentelemetry_sdk-1.22.0.dist-info/INSTALLER
#   inflating: /tmp/ngc-cli/libk5crypto.so.3
#   inflating: /tmp/ngc-cli/lib-dynload/_codecs_tw.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/termios.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_decimal.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_datetime.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/grp.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_bisect.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_elementtree.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_sha512.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/fcntl.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_codecs_iso2022.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_multibytecodec.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/binascii.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_csv.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_posixsubprocess.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_sha256.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_codecs_hk.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_multiprocessing.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/select.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_asyncio.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/unicodedata.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_codecs_kr.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_ctypes.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_posixshmem.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/array.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_blake2.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/resource.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_ssl.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/pyexpat.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_codecs_jp.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_queue.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_opcode.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_socket.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_pickle.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/math.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_hashlib.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_codecs_cn.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_statistics.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/zlib.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_sha1.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_sha3.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_struct.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_md5.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/mmap.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_contextvars.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_heapq.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_random.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_json.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/libssl.so.10
#   inflating: /tmp/ngc-cli/libselinux.so.1
#  extracting: /tmp/ngc-cli/base_library.zip
#   inflating: /tmp/ngc-cli/libz.so.1
#   inflating: /tmp/ngc-cli/charset_normalizer/md__mypyc.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/charset_normalizer/md.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/google/protobuf/internal/_api_implementation.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/google/protobuf/pyext/_message.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/importlib_metadata-6.11.0.dist-info/RECORD
#   inflating: /tmp/ngc-cli/importlib_metadata-6.11.0.dist-info/LICENSE
#   inflating: /tmp/ngc-cli/importlib_metadata-6.11.0.dist-info/METADATA
#  extracting: /tmp/ngc-cli/importlib_metadata-6.11.0.dist-info/WHEEL
#  extracting: /tmp/ngc-cli/importlib_metadata-6.11.0.dist-info/INSTALLER
#  extracting: /tmp/ngc-cli/importlib_metadata-6.11.0.dist-info/top_level.txt
#   inflating: /tmp/ngc-cli/botocore/data/b2bi/2022-06-23/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/b2bi/2022-06-23/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/b2bi/2022-06-23/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/autoscaling/2011-01-01/paginators-1.json
#   inflating: /tmp/ngc-cli/botocore/data/autoscaling/2011-01-01/paginators-1.sdk-extras.json
#  extracting: /tmp/ngc-cli/botocore/data/autoscaling/2011-01-01/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/autoscaling/2011-01-01/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/autoscaling/2011-01-01/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/apigatewayv2/2018-11-29/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/apigatewayv2/2018-11-29/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/apigatewayv2/2018-11-29/service-2.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/synthetics/2017-10-11/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/synthetics/2017-10-11/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/synthetics/2017-10-11/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/synthetics/2017-10-11/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/applicationcostprofiler/2020-09-10/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/applicationcostprofiler/2020-09-10/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/applicationcostprofiler/2020-09-10/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/applicationcostprofiler/2020-09-10/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/datasync/2018-11-09/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/datasync/2018-11-09/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/datasync/2018-11-09/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/datasync/2018-11-09/examples-1.json
#  extracting: /tmp/ngc-cli/botocore/data/sso-oidc/2019-06-10/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/sso-oidc/2019-06-10/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/sso-oidc/2019-06-10/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/sso-oidc/2019-06-10/examples-1.json
#  extracting: /tmp/ngc-cli/botocore/data/iotdeviceadvisor/2020-09-18/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/iotdeviceadvisor/2020-09-18/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/iotdeviceadvisor/2020-09-18/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/iotdeviceadvisor/2020-09-18/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/medialive/2017-10-14/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/medialive/2017-10-14/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/medialive/2017-10-14/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/medialive/2017-10-14/service-2.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/marketplace-agreement/2020-03-01/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/marketplace-agreement/2020-03-01/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/marketplace-agreement/2020-03-01/service-2.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/wellarchitected/2020-03-31/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/wellarchitected/2020-03-31/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/wellarchitected/2020-03-31/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/wellarchitected/2020-03-31/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/codeguru-security/2018-05-10/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/codeguru-security/2018-05-10/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/codeguru-security/2018-05-10/service-2.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/waf-regional/2016-11-28/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/waf-regional/2016-11-28/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/waf-regional/2016-11-28/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/waf-regional/2016-11-28/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/privatenetworks/2021-12-03/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/privatenetworks/2021-12-03/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/privatenetworks/2021-12-03/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/route53domains/2014-05-15/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/route53domains/2014-05-15/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/route53domains/2014-05-15/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/route53domains/2014-05-15/examples-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cognito-sync/2014-06-30/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cognito-sync/2014-06-30/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/cognito-sync/2014-06-30/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cognito-sync/2014-06-30/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/autoscaling-plans/2018-01-06/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/autoscaling-plans/2018-01-06/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/autoscaling-plans/2018-01-06/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/autoscaling-plans/2018-01-06/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/secretsmanager/2017-10-17/paginators-1.json
#   inflating: /tmp/ngc-cli/botocore/data/secretsmanager/2017-10-17/service-2.sdk-extras.json
#  extracting: /tmp/ngc-cli/botocore/data/secretsmanager/2017-10-17/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/secretsmanager/2017-10-17/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/secretsmanager/2017-10-17/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cloud9/2017-09-23/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloud9/2017-09-23/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/cloud9/2017-09-23/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloud9/2017-09-23/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/ses/2010-12-01/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/ses/2010-12-01/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/ses/2010-12-01/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/ses/2010-12-01/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/ses/2010-12-01/examples-1.json
#  extracting: /tmp/ngc-cli/botocore/data/sagemaker-edge/2020-09-23/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/sagemaker-edge/2020-09-23/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/sagemaker-edge/2020-09-23/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/sagemaker-edge/2020-09-23/examples-1.json
#  extracting: /tmp/ngc-cli/botocore/data/ce/2017-10-25/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/ce/2017-10-25/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/ce/2017-10-25/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/ce/2017-10-25/examples-1.json
#  extracting: /tmp/ngc-cli/botocore/data/workmailmessageflow/2019-05-01/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/workmailmessageflow/2019-05-01/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/workmailmessageflow/2019-05-01/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/workmailmessageflow/2019-05-01/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/location/2020-11-19/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/location/2020-11-19/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/location/2020-11-19/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/location/2020-11-19/examples-1.json
#  extracting: /tmp/ngc-cli/botocore/data/healthlake/2017-07-01/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/healthlake/2017-07-01/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/healthlake/2017-07-01/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/healthlake/2017-07-01/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/ssm-incidents/2018-05-10/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/ssm-incidents/2018-05-10/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/ssm-incidents/2018-05-10/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/ssm-incidents/2018-05-10/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/ssm-incidents/2018-05-10/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/license-manager-user-subscriptions/2018-05-10/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/license-manager-user-subscriptions/2018-05-10/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/license-manager-user-subscriptions/2018-05-10/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudhsmv2/2017-04-28/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudhsmv2/2017-04-28/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/cloudhsmv2/2017-04-28/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudhsmv2/2017-04-28/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/workspaces/2015-04-08/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/workspaces/2015-04-08/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/workspaces/2015-04-08/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/workspaces/2015-04-08/examples-1.json
#  extracting: /tmp/ngc-cli/botocore/data/frauddetector/2019-11-15/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/frauddetector/2019-11-15/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/frauddetector/2019-11-15/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/frauddetector/2019-11-15/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront-keyvaluestore/2022-07-26/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront-keyvaluestore/2022-07-26/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront-keyvaluestore/2022-07-26/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/elb/2012-06-01/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/elb/2012-06-01/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/elb/2012-06-01/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/elb/2012-06-01/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/elb/2012-06-01/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/ecr-public/2020-10-30/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/ecr-public/2020-10-30/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/ecr-public/2020-10-30/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/ecr-public/2020-10-30/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/lightsail/2016-11-28/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/lightsail/2016-11-28/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/lightsail/2016-11-28/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/lightsail/2016-11-28/examples-1.json
#  extracting: /tmp/ngc-cli/botocore/data/iotevents-data/2018-10-23/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/iotevents-data/2018-10-23/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/iotevents-data/2018-10-23/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/iotevents-data/2018-10-23/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/migration-hub-refactor-spaces/2021-10-26/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/migration-hub-refactor-spaces/2021-10-26/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/migration-hub-refactor-spaces/2021-10-26/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/migration-hub-refactor-spaces/2021-10-26/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/clouddirectory/2016-05-10/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/clouddirectory/2016-05-10/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/clouddirectory/2016-05-10/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/clouddirectory/2016-05-10/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/clouddirectory/2017-01-11/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/clouddirectory/2017-01-11/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/clouddirectory/2017-01-11/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/clouddirectory/2017-01-11/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/logs/2014-03-28/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/logs/2014-03-28/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/logs/2014-03-28/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/logs/2014-03-28/examples-1.json
#  extracting: /tmp/ngc-cli/botocore/data/inspector-scan/2023-08-08/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/inspector-scan/2023-08-08/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/inspector-scan/2023-08-08/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/bedrock-agent/2023-06-05/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/bedrock-agent/2023-06-05/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/bedrock-agent/2023-06-05/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/qbusiness/2023-11-27/paginators-1.json
#   inflating: /tmp/ngc-cli/botocore/data/qbusiness/2023-11-27/paginators-1.sdk-extras.json
#  extracting: /tmp/ngc-cli/botocore/data/qbusiness/2023-11-27/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/qbusiness/2023-11-27/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/ecs/2014-11-13/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/ecs/2014-11-13/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/ecs/2014-11-13/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/ecs/2014-11-13/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/ecs/2014-11-13/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cur/2017-01-06/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cur/2017-01-06/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/cur/2017-01-06/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cur/2017-01-06/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/tnb/2008-10-21/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/tnb/2008-10-21/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/tnb/2008-10-21/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/m2/2021-04-28/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/m2/2021-04-28/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/m2/2021-04-28/service-2.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/savingsplans/2019-06-28/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/savingsplans/2019-06-28/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/savingsplans/2019-06-28/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/savingsplans/2019-06-28/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/codeartifact/2018-09-22/paginators-1.json
#   inflating: /tmp/ngc-cli/botocore/data/codeartifact/2018-09-22/paginators-1.sdk-extras.json
#  extracting: /tmp/ngc-cli/botocore/data/codeartifact/2018-09-22/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/codeartifact/2018-09-22/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/codeartifact/2018-09-22/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/devops-guru/2020-12-01/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/devops-guru/2020-12-01/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/devops-guru/2020-12-01/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/devops-guru/2020-12-01/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/sagemaker/2017-07-24/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/sagemaker/2017-07-24/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/sagemaker/2017-07-24/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/sagemaker/2017-07-24/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/sagemaker/2017-07-24/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/amplify/2017-07-25/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/amplify/2017-07-25/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/amplify/2017-07-25/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/amplify/2017-07-25/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/finspace-data/2020-07-13/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/finspace-data/2020-07-13/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/finspace-data/2020-07-13/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/finspace-data/2020-07-13/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/textract/2018-06-27/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/textract/2018-06-27/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/textract/2018-06-27/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/textract/2018-06-27/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudhsm/2014-05-30/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudhsm/2014-05-30/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/cloudhsm/2014-05-30/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudhsm/2014-05-30/examples-1.json
#  extracting: /tmp/ngc-cli/botocore/data/chime-sdk-media-pipelines/2021-07-15/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/chime-sdk-media-pipelines/2021-07-15/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/chime-sdk-media-pipelines/2021-07-15/service-2.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/kendra-ranking/2022-10-19/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/kendra-ranking/2022-10-19/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/kendra-ranking/2022-10-19/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/timestream-query/2018-11-01/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/timestream-query/2018-11-01/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/timestream-query/2018-11-01/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/timestream-query/2018-11-01/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/config/2014-11-12/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/config/2014-11-12/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/config/2014-11-12/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/config/2014-11-12/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/opsworkscm/2016-11-01/waiters-2.json
# ...
#   inflating: /tmp/ngc-cli/botocore/data/docdb-elastic/2022-11-28/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/docdb-elastic/2022-11-28/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/docdb-elastic/2022-11-28/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/serverlessrepo/2017-09-08/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/serverlessrepo/2017-09-08/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/serverlessrepo/2017-09-08/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/compute-optimizer/2019-11-01/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/compute-optimizer/2019-11-01/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/compute-optimizer/2019-11-01/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/compute-optimizer/2019-11-01/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudcontrol/2021-09-30/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudcontrol/2021-09-30/paginators-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudcontrol/2021-09-30/paginators-1.sdk-extras.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudcontrol/2021-09-30/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/cloudcontrol/2021-09-30/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudcontrol/2021-09-30/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/batch/2016-08-10/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/batch/2016-08-10/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/batch/2016-08-10/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/batch/2016-08-10/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/controltower/2018-05-10/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/controltower/2018-05-10/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/controltower/2018-05-10/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cognito-idp/2016-04-18/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cognito-idp/2016-04-18/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cognito-idp/2016-04-18/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cognito-idp/2016-04-18/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/importexport/2010-06-01/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/importexport/2010-06-01/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/importexport/2010-06-01/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/dataexchange/2017-07-25/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/dataexchange/2017-07-25/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/dataexchange/2017-07-25/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/dataexchange/2017-07-25/service-2.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/resiliencehub/2020-04-30/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/resiliencehub/2020-04-30/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/resiliencehub/2020-04-30/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/resiliencehub/2020-04-30/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/memorydb/2021-01-01/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/memorydb/2021-01-01/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/memorydb/2021-01-01/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/memorydb/2021-01-01/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-01-13/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-01-13/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2016-01-13/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2016-01-13/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-08-20/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-08-20/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2016-08-20/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-08-20/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2020-05-31/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2020-05-31/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2020-05-31/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2020-05-31/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2020-05-31/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-09-29/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-09-29/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2016-09-29/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2016-09-29/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-09-29/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2015-04-17/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2015-04-17/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2015-04-17/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2015-04-17/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2014-05-31/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2014-05-31/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2014-05-31/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2014-05-31/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2014-10-21/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2014-10-21/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2014-10-21/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2014-10-21/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2017-10-30/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2017-10-30/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2017-10-30/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2017-10-30/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2017-10-30/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2017-03-25/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2017-03-25/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2017-03-25/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2017-03-25/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-08-01/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-08-01/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2016-08-01/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2016-08-01/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-08-01/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-09-07/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-09-07/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2016-09-07/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-09-07/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-09-07/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2018-06-18/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2018-06-18/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2018-06-18/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2018-06-18/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2018-06-18/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2018-11-05/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2018-11-05/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2018-11-05/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2018-11-05/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2018-11-05/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-01-28/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-01-28/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2016-01-28/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2016-01-28/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-01-28/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2019-03-26/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2019-03-26/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2019-03-26/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2019-03-26/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2019-03-26/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2015-09-17/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2015-09-17/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2015-09-17/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2015-09-17/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2014-11-06/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2014-11-06/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2014-11-06/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2014-11-06/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-11-25/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-11-25/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2016-11-25/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2016-11-25/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-11-25/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2015-07-27/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2015-07-27/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2015-07-27/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2015-07-27/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/mgn/2020-02-26/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/mgn/2020-02-26/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/mgn/2020-02-26/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/mgn/2020-02-26/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/bedrock-runtime/2023-09-30/waiters-2.json
#  extracting: /tmp/ngc-cli/botocore/data/bedrock-runtime/2023-09-30/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/bedrock-runtime/2023-09-30/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/bedrock-runtime/2023-09-30/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/codestar/2017-04-19/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/codestar/2017-04-19/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/codestar/2017-04-19/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/codestar/2017-04-19/examples-1.json
#  extracting: /tmp/ngc-cli/botocore/data/imagebuilder/2019-12-02/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/imagebuilder/2019-12-02/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/imagebuilder/2019-12-02/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/imagebuilder/2019-12-02/examples-1.json
#  extracting: /tmp/ngc-cli/botocore/data/timestream-write/2018-11-01/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/timestream-write/2018-11-01/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/timestream-write/2018-11-01/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/timestream-write/2018-11-01/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/arc-zonal-shift/2022-10-30/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/arc-zonal-shift/2022-10-30/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/arc-zonal-shift/2022-10-30/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/rekognition/2016-06-27/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/rekognition/2016-06-27/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/rekognition/2016-06-27/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/rekognition/2016-06-27/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/rekognition/2016-06-27/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/braket/2019-09-01/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/braket/2019-09-01/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/braket/2019-09-01/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/braket/2019-09-01/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/cacert.pem
#   inflating: /tmp/ngc-cli/prettytable-2.0.0.dist-info/RECORD
#   inflating: /tmp/ngc-cli/prettytable-2.0.0.dist-info/COPYING
#   inflating: /tmp/ngc-cli/prettytable-2.0.0.dist-info/METADATA
#  extracting: /tmp/ngc-cli/prettytable-2.0.0.dist-info/WHEEL
#  extracting: /tmp/ngc-cli/prettytable-2.0.0.dist-info/INSTALLER
#  extracting: /tmp/ngc-cli/prettytable-2.0.0.dist-info/top_level.txt
#   inflating: /tmp/ngc-cli/aiohttp/_http_writer.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/aiohttp/_http_parser.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/aiohttp/_helpers.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/aiohttp/_websocket.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/libkeyutils.so.1
#   inflating: /tmp/ngc-cli/typing_extensions-4.9.0.dist-info/RECORD
#   inflating: /tmp/ngc-cli/typing_extensions-4.9.0.dist-info/LICENSE
#   inflating: /tmp/ngc-cli/typing_extensions-4.9.0.dist-info/METADATA
#  extracting: /tmp/ngc-cli/typing_extensions-4.9.0.dist-info/WHEEL
#  extracting: /tmp/ngc-cli/typing_extensions-4.9.0.dist-info/INSTALLER
#   inflating: /tmp/ngc-cli/_cffi_backend.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/psutil/_psutil_linux.abi3.so
#   inflating: /tmp/ngc-cli/psutil/_psutil_posix.abi3.so
#   inflating: /tmp/ngc-cli/libffi.so.6
#   inflating: /tmp/ngc-cli/setuptools-49.6.0.dist-info/RECORD
#   inflating: /tmp/ngc-cli/setuptools-49.6.0.dist-info/entry_points.txt
#   inflating: /tmp/ngc-cli/setuptools-49.6.0.dist-info/LICENSE
#   inflating: /tmp/ngc-cli/setuptools-49.6.0.dist-info/dependency_links.txt
#   inflating: /tmp/ngc-cli/setuptools-49.6.0.dist-info/METADATA
#  extracting: /tmp/ngc-cli/setuptools-49.6.0.dist-info/WHEEL
#  extracting: /tmp/ngc-cli/setuptools-49.6.0.dist-info/zip-safe
#  extracting: /tmp/ngc-cli/setuptools-49.6.0.dist-info/INSTALLER
#   inflating: /tmp/ngc-cli/setuptools-49.6.0.dist-info/top_level.txt
#   inflating: /tmp/ngc-cli/markupsafe/_speedups.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/Deprecated-1.2.14.dist-info/RECORD
#   inflating: /tmp/ngc-cli/Deprecated-1.2.14.dist-info/METADATA
#   inflating: /tmp/ngc-cli/Deprecated-1.2.14.dist-info/LICENSE.rst
#   inflating: /tmp/ngc-cli/Deprecated-1.2.14.dist-info/WHEEL
#  extracting: /tmp/ngc-cli/Deprecated-1.2.14.dist-info/INSTALLER
#  extracting: /tmp/ngc-cli/Deprecated-1.2.14.dist-info/top_level.txt
#  extracting: /tmp/ngc-cli.md5

# %% [markdown]
# そして、ターミナルを開いて、下記のコマンドを入力して、 ngc config set をしてください。

# %% [markdown]
# /tmp/ngc-cli/ngc config set
#
# <順番にAPI キー、CLI output format, org, team, aceを入力してください。API キーはNGCのAPIキーを入力してください。Org は ’no-org’ 以外のものを選択して、その他は「Enter」でデフォルト値を入力すれば大丈夫です>

# %% [markdown]
# 最後に、下記のコマンドを入力すれば、モデルをダウンロードできます。

# %%
# !python download_models.py --download_dir /workspace/bionemo/models esm2nv_650m
# Out:
# Running command: ngc --version
#
# /bin/dash: 1: ngc: not found
#
# Installing NGC CLI to /tmp
# Running command: wget -q -O /tmp/ngccli_linux.zip --content-disposition https://api.ngc.nvidia.com/v2/resources/nvidia/ngc-apps/ngc_cli/versions/3.38.0/files/ngccli_linux.zip && unzip -o /tmp/ngccli_linux.zip -d /tmp && chmod u+x /tmp/ngc-cli/ngc && rm /tmp/ngccli_linux.zip
#
# Archive:  /tmp/ngccli_linux.zip
#   inflating: /tmp/ngc-cli/boto3/examples/s3.rst
#   inflating: /tmp/ngc-cli/boto3/examples/cloudfront.rst
#   inflating: /tmp/ngc-cli/boto3/data/dynamodb/2012-08-10/resources-1.json
#   inflating: /tmp/ngc-cli/boto3/data/sqs/2012-11-05/resources-1.json
#   inflating: /tmp/ngc-cli/boto3/data/opsworks/2013-02-18/resources-1.json
#   inflating: /tmp/ngc-cli/boto3/data/iam/2010-05-08/resources-1.json
#   inflating: /tmp/ngc-cli/boto3/data/ec2/2014-10-01/resources-1.json
#   inflating: /tmp/ngc-cli/boto3/data/ec2/2015-10-01/resources-1.json
#   inflating: /tmp/ngc-cli/boto3/data/ec2/2015-03-01/resources-1.json
#   inflating: /tmp/ngc-cli/boto3/data/ec2/2016-09-15/resources-1.json
#   inflating: /tmp/ngc-cli/boto3/data/ec2/2016-04-01/resources-1.json
#   inflating: /tmp/ngc-cli/boto3/data/ec2/2015-04-15/resources-1.json
#   inflating: /tmp/ngc-cli/boto3/data/ec2/2016-11-15/resources-1.json
#   inflating: /tmp/ngc-cli/boto3/data/s3/2006-03-01/resources-1.json
#   inflating: /tmp/ngc-cli/boto3/data/sns/2010-03-31/resources-1.json
#   inflating: /tmp/ngc-cli/boto3/data/cloudformation/2010-05-15/resources-1.json
#   inflating: /tmp/ngc-cli/boto3/data/cloudwatch/2010-08-01/resources-1.json
#   inflating: /tmp/ngc-cli/boto3/data/glacier/2012-06-01/resources-1.json
#   inflating: /tmp/ngc-cli/attrs-23.2.0.dist-info/RECORD
#   inflating: /tmp/ngc-cli/attrs-23.2.0.dist-info/METADATA
#   inflating: /tmp/ngc-cli/attrs-23.2.0.dist-info/WHEEL
#   inflating: /tmp/ngc-cli/attrs-23.2.0.dist-info/licenses/LICENSE
#  extracting: /tmp/ngc-cli/attrs-23.2.0.dist-info/INSTALLER
#   inflating: /tmp/ngc-cli/pycares/_cares.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/zipp-3.17.0.dist-info/RECORD
#   inflating: /tmp/ngc-cli/zipp-3.17.0.dist-info/LICENSE
#   inflating: /tmp/ngc-cli/zipp-3.17.0.dist-info/METADATA
#  extracting: /tmp/ngc-cli/zipp-3.17.0.dist-info/WHEEL
#  extracting: /tmp/ngc-cli/zipp-3.17.0.dist-info/INSTALLER
#  extracting: /tmp/ngc-cli/zipp-3.17.0.dist-info/top_level.txt
#   inflating: /tmp/ngc-cli/grpc/_cython/_credentials/roots.pem
#   inflating: /tmp/ngc-cli/grpc/_cython/cygrpc.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/libcrypto.so.10
#   inflating: /tmp/ngc-cli/wrapt-1.16.0.dist-info/RECORD
#   inflating: /tmp/ngc-cli/wrapt-1.16.0.dist-info/LICENSE
#   inflating: /tmp/ngc-cli/wrapt-1.16.0.dist-info/METADATA
#   inflating: /tmp/ngc-cli/wrapt-1.16.0.dist-info/WHEEL
#  extracting: /tmp/ngc-cli/wrapt-1.16.0.dist-info/INSTALLER
#  extracting: /tmp/ngc-cli/wrapt-1.16.0.dist-info/top_level.txt
#   inflating: /tmp/ngc-cli/main.so
#   inflating: /tmp/ngc-cli/opentelemetry_instrumentation-0.41b0.dist-info/RECORD
#   inflating: /tmp/ngc-cli/opentelemetry_instrumentation-0.41b0.dist-info/entry_points.txt
#   inflating: /tmp/ngc-cli/opentelemetry_instrumentation-0.41b0.dist-info/METADATA
#  extracting: /tmp/ngc-cli/opentelemetry_instrumentation-0.41b0.dist-info/WHEEL
#   inflating: /tmp/ngc-cli/opentelemetry_instrumentation-0.41b0.dist-info/licenses/LICENSE
#  extracting: /tmp/ngc-cli/opentelemetry_instrumentation-0.41b0.dist-info/INSTALLER
#   inflating: /tmp/ngc-cli/libkrb5support.so.0
#   inflating: /tmp/ngc-cli/wrapt/_wrappers.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/libcom_err.so.2
#   inflating: /tmp/ngc-cli/cryptography/hazmat/bindings/_rust.abi3.so
#   inflating: /tmp/ngc-cli/backoff-2.2.1.dist-info/RECORD
#   inflating: /tmp/ngc-cli/backoff-2.2.1.dist-info/LICENSE
#   inflating: /tmp/ngc-cli/backoff-2.2.1.dist-info/METADATA
#   inflating: /tmp/ngc-cli/backoff-2.2.1.dist-info/WHEEL
#  extracting: /tmp/ngc-cli/backoff-2.2.1.dist-info/INSTALLER
#   inflating: /tmp/ngc-cli/libpcre.so.1
#   inflating: /tmp/ngc-cli/libgssapi_krb5.so.2
#   inflating: /tmp/ngc-cli/grpcio-1.60.0.dist-info/RECORD
#   inflating: /tmp/ngc-cli/grpcio-1.60.0.dist-info/LICENSE
#   inflating: /tmp/ngc-cli/grpcio-1.60.0.dist-info/METADATA
#   inflating: /tmp/ngc-cli/grpcio-1.60.0.dist-info/WHEEL
#  extracting: /tmp/ngc-cli/grpcio-1.60.0.dist-info/INSTALLER
#  extracting: /tmp/ngc-cli/grpcio-1.60.0.dist-info/top_level.txt
#   inflating: /tmp/ngc-cli/opentelemetry_exporter_otlp_proto_grpc-1.22.0.dist-info/RECORD
#   inflating: /tmp/ngc-cli/opentelemetry_exporter_otlp_proto_grpc-1.22.0.dist-info/entry_points.txt
#   inflating: /tmp/ngc-cli/opentelemetry_exporter_otlp_proto_grpc-1.22.0.dist-info/METADATA
#  extracting: /tmp/ngc-cli/opentelemetry_exporter_otlp_proto_grpc-1.22.0.dist-info/WHEEL
#   inflating: /tmp/ngc-cli/opentelemetry_exporter_otlp_proto_grpc-1.22.0.dist-info/licenses/LICENSE
#  extracting: /tmp/ngc-cli/opentelemetry_exporter_otlp_proto_grpc-1.22.0.dist-info/INSTALLER
#   inflating: /tmp/ngc-cli/libgcc_s.so.1
#   inflating: /tmp/ngc-cli/opentelemetry/context/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/context/context.py
#   inflating: /tmp/ngc-cli/opentelemetry/context/__pycache__/context.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/context/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/context/contextvars_context.py
#   inflating: /tmp/ngc-cli/opentelemetry/instrumentation/distro.py
#   inflating: /tmp/ngc-cli/opentelemetry/instrumentation/utils.py
#   inflating: /tmp/ngc-cli/opentelemetry/instrumentation/environment_variables.py
#   inflating: /tmp/ngc-cli/opentelemetry/instrumentation/instrumentor.py
#   inflating: /tmp/ngc-cli/opentelemetry/instrumentation/auto_instrumentation/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/instrumentation/auto_instrumentation/_load.py
#   inflating: /tmp/ngc-cli/opentelemetry/instrumentation/auto_instrumentation/sitecustomize.py
#   inflating: /tmp/ngc-cli/opentelemetry/instrumentation/bootstrap_gen.py
#   inflating: /tmp/ngc-cli/opentelemetry/instrumentation/version.py
#   inflating: /tmp/ngc-cli/opentelemetry/instrumentation/sqlcommenter_utils.py
#   inflating: /tmp/ngc-cli/opentelemetry/instrumentation/bootstrap.py
#   inflating: /tmp/ngc-cli/opentelemetry/instrumentation/propagators.py
#   inflating: /tmp/ngc-cli/opentelemetry/instrumentation/dependencies.py
#  extracting: /tmp/ngc-cli/opentelemetry/instrumentation/py.typed
#   inflating: /tmp/ngc-cli/opentelemetry/util/re.py
#   inflating: /tmp/ngc-cli/opentelemetry/util/_importlib_metadata.py
#   inflating: /tmp/ngc-cli/opentelemetry/util/types.py
#   inflating: /tmp/ngc-cli/opentelemetry/util/_once.py
#   inflating: /tmp/ngc-cli/opentelemetry/util/_providers.py
#   inflating: /tmp/ngc-cli/opentelemetry/util/__pycache__/re.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/util/__pycache__/_once.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/util/__pycache__/types.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/util/__pycache__/_importlib_metadata.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/util/__pycache__/_providers.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/environment_variables.py
#   inflating: /tmp/ngc-cli/opentelemetry/attributes/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/attributes/__pycache__/__init__.cpython-39.pyc
#  extracting: /tmp/ngc-cli/opentelemetry/proto/resource/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/resource/v1/resource_pb2.pyi
#  extracting: /tmp/ngc-cli/opentelemetry/proto/resource/v1/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/resource/v1/resource_pb2.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/resource/v1/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/proto/resource/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/proto/logs/v1/logs_pb2.pyi
#   inflating: /tmp/ngc-cli/opentelemetry/proto/logs/v1/logs_pb2.py
#  extracting: /tmp/ngc-cli/opentelemetry/proto/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/collector/logs/v1/logs_service_pb2.pyi
#   inflating: /tmp/ngc-cli/opentelemetry/proto/collector/logs/v1/logs_service_pb2.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/collector/logs/v1/logs_service_pb2_grpc.py
#  extracting: /tmp/ngc-cli/opentelemetry/proto/collector/__init__.py
#  extracting: /tmp/ngc-cli/opentelemetry/proto/collector/metrics/__init__.py
#  extracting: /tmp/ngc-cli/opentelemetry/proto/collector/metrics/v1/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/collector/metrics/v1/metrics_service_pb2.pyi
#   inflating: /tmp/ngc-cli/opentelemetry/proto/collector/metrics/v1/metrics_service_pb2.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/collector/metrics/v1/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/proto/collector/metrics/v1/metrics_service_pb2_grpc.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/collector/metrics/__pycache__/__init__.cpython-39.pyc
#  extracting: /tmp/ngc-cli/opentelemetry/proto/collector/trace/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/collector/trace/v1/trace_service_pb2.pyi
#  extracting: /tmp/ngc-cli/opentelemetry/proto/collector/trace/v1/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/collector/trace/v1/trace_service_pb2_grpc.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/collector/trace/v1/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/proto/collector/trace/v1/trace_service_pb2.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/collector/trace/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/proto/collector/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/proto/version.py
#  extracting: /tmp/ngc-cli/opentelemetry/proto/metrics/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/metrics/v1/metrics_pb2.pyi
#  extracting: /tmp/ngc-cli/opentelemetry/proto/metrics/v1/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/metrics/v1/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/proto/metrics/v1/metrics_pb2.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/metrics/__pycache__/__init__.cpython-39.pyc
#  extracting: /tmp/ngc-cli/opentelemetry/proto/trace/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/trace/v1/trace_pb2.pyi
#   inflating: /tmp/ngc-cli/opentelemetry/proto/trace/v1/trace_pb2.py
#  extracting: /tmp/ngc-cli/opentelemetry/proto/trace/v1/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/trace/v1/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/proto/trace/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/proto/__pycache__/__init__.cpython-39.pyc
#  extracting: /tmp/ngc-cli/opentelemetry/proto/common/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/common/v1/common_pb2.py
#  extracting: /tmp/ngc-cli/opentelemetry/proto/common/v1/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/proto/common/v1/common_pb2.pyi
#   inflating: /tmp/ngc-cli/opentelemetry/proto/common/v1/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/proto/common/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/propagators/__pycache__/composite.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/propagators/__pycache__/textmap.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/propagators/composite.py
#   inflating: /tmp/ngc-cli/opentelemetry/propagators/textmap.py
#   inflating: /tmp/ngc-cli/opentelemetry/version.py
#   inflating: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/grpc/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/grpc/trace_exporter/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/grpc/version.py
#  extracting: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/grpc/py.typed
#   inflating: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/grpc/metric_exporter/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/grpc/exporter.py
#   inflating: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/grpc/_log_exporter/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/common/_internal/trace_encoder/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/common/_internal/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/common/_internal/metrics_encoder/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/common/_internal/_log_encoder/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/common/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/common/version.py
#   inflating: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/common/trace_encoder.py
#   inflating: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/common/_log_encoder.py
#  extracting: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/common/py.typed
#   inflating: /tmp/ngc-cli/opentelemetry/exporter/otlp/proto/common/metrics_encoder.py
#   inflating: /tmp/ngc-cli/opentelemetry/semconv/resource/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/semconv/resource/__pycache__/__init__.cpython-39.pyc
#  extracting: /tmp/ngc-cli/opentelemetry/semconv/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/semconv/version.py
#   inflating: /tmp/ngc-cli/opentelemetry/semconv/metrics/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/semconv/metrics/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/semconv/trace/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/semconv/trace/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/semconv/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/baggage/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/baggage/propagation/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/baggage/propagation/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/baggage/__pycache__/__init__.cpython-39.pyc
#  extracting: /tmp/ngc-cli/opentelemetry/py.typed
#   inflating: /tmp/ngc-cli/opentelemetry/propagate/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/propagate/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/metrics/_internal/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/metrics/_internal/instrument.py
#   inflating: /tmp/ngc-cli/opentelemetry/metrics/_internal/__pycache__/observation.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/metrics/_internal/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/metrics/_internal/__pycache__/instrument.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/metrics/_internal/observation.py
#   inflating: /tmp/ngc-cli/opentelemetry/metrics/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/metrics/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/trace/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/trace/propagation/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/trace/propagation/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/trace/propagation/__pycache__/tracecontext.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/trace/propagation/tracecontext.py
#   inflating: /tmp/ngc-cli/opentelemetry/trace/status.py
#   inflating: /tmp/ngc-cli/opentelemetry/trace/span.py
#   inflating: /tmp/ngc-cli/opentelemetry/trace/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/trace/__pycache__/span.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/trace/__pycache__/status.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/__pycache__/environment_variables.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/__init__.pyi
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/util/__init__.pyi
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/util/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/util/instrumentation.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/environment_variables.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/_configuration/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/version.py
#  extracting: /tmp/ngc-cli/opentelemetry/sdk/py.typed
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/point.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/sdk_configuration.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/exponential_histogram/mapping/ieee_754.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/exponential_histogram/mapping/logarithm_mapping.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/exponential_histogram/mapping/exponent_mapping.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/exponential_histogram/mapping/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/exponential_histogram/mapping/errors.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/exponential_histogram/mapping/ieee_754.md
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/exponential_histogram/buckets.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/exceptions.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/measurement_consumer.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/export/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/metric_reader_storage.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/_view_instrument_match.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/aggregation.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/view.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/instrument.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/_internal/measurement.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/export/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/metrics/view/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/trace/export/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/trace/export/in_memory_span_exporter.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/trace/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/trace/id_generator.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/trace/sampling.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/resources/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/error_handler/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/_logs/_internal/export/in_memory_log_exporter.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/_logs/_internal/export/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/_logs/_internal/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/_logs/export/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/sdk/_logs/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/_logs/_internal/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/_logs/_internal/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/_logs/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/_logs/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/opentelemetry/_logs/severity/__init__.py
#   inflating: /tmp/ngc-cli/opentelemetry/_logs/severity/__pycache__/__init__.cpython-39.pyc
#   inflating: /tmp/ngc-cli/libpython3.9.so.1.0
#  extracting: /tmp/ngc-cli/certifi/py.typed
#   inflating: /tmp/ngc-cli/certifi/cacert.pem
#   inflating: /tmp/ngc-cli/frozenlist/_frozenlist.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/opentelemetry_api-1.22.0.dist-info/RECORD
#   inflating: /tmp/ngc-cli/opentelemetry_api-1.22.0.dist-info/entry_points.txt
#   inflating: /tmp/ngc-cli/opentelemetry_api-1.22.0.dist-info/METADATA
#  extracting: /tmp/ngc-cli/opentelemetry_api-1.22.0.dist-info/WHEEL
#   inflating: /tmp/ngc-cli/opentelemetry_api-1.22.0.dist-info/licenses/LICENSE
#  extracting: /tmp/ngc-cli/opentelemetry_api-1.22.0.dist-info/INSTALLER
#   inflating: /tmp/ngc-cli/opentelemetry_proto-1.22.0.dist-info/RECORD
#   inflating: /tmp/ngc-cli/opentelemetry_proto-1.22.0.dist-info/METADATA
#  extracting: /tmp/ngc-cli/opentelemetry_proto-1.22.0.dist-info/WHEEL
#   inflating: /tmp/ngc-cli/opentelemetry_proto-1.22.0.dist-info/licenses/LICENSE
#  extracting: /tmp/ngc-cli/opentelemetry_proto-1.22.0.dist-info/INSTALLER
#   inflating: /tmp/ngc-cli/libfreebl3.so
#   inflating: /tmp/ngc-cli/protobuf-3.20.3.dist-info/RECORD
#   inflating: /tmp/ngc-cli/protobuf-3.20.3.dist-info/METADATA
#  extracting: /tmp/ngc-cli/protobuf-3.20.3.dist-info/namespace_packages.txt
#   inflating: /tmp/ngc-cli/protobuf-3.20.3.dist-info/WHEEL
#  extracting: /tmp/ngc-cli/protobuf-3.20.3.dist-info/INSTALLER
#  extracting: /tmp/ngc-cli/protobuf-3.20.3.dist-info/top_level.txt
#   inflating: /tmp/ngc-cli/multidict/_multidict.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/libkrb5.so.3
#   inflating: /tmp/ngc-cli/opentelemetry_exporter_otlp_proto_common-1.22.0.dist-info/RECORD
#   inflating: /tmp/ngc-cli/opentelemetry_exporter_otlp_proto_common-1.22.0.dist-info/METADATA
#  extracting: /tmp/ngc-cli/opentelemetry_exporter_otlp_proto_common-1.22.0.dist-info/WHEEL
#   inflating: /tmp/ngc-cli/opentelemetry_exporter_otlp_proto_common-1.22.0.dist-info/licenses/LICENSE
#  extracting: /tmp/ngc-cli/opentelemetry_exporter_otlp_proto_common-1.22.0.dist-info/INSTALLER
#   inflating: /tmp/ngc-cli/yarl/_quoting_c.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/cryptography-41.0.7.dist-info/RECORD
#   inflating: /tmp/ngc-cli/cryptography-41.0.7.dist-info/LICENSE.BSD
#   inflating: /tmp/ngc-cli/cryptography-41.0.7.dist-info/LICENSE
#   inflating: /tmp/ngc-cli/cryptography-41.0.7.dist-info/METADATA
#   inflating: /tmp/ngc-cli/cryptography-41.0.7.dist-info/LICENSE.APACHE
#   inflating: /tmp/ngc-cli/cryptography-41.0.7.dist-info/WHEEL
#  extracting: /tmp/ngc-cli/cryptography-41.0.7.dist-info/INSTALLER
#  extracting: /tmp/ngc-cli/cryptography-41.0.7.dist-info/top_level.txt
#   inflating: /tmp/ngc-cli/googleapis_common_protos-1.62.0.dist-info/RECORD
#   inflating: /tmp/ngc-cli/googleapis_common_protos-1.62.0.dist-info/LICENSE
#   inflating: /tmp/ngc-cli/googleapis_common_protos-1.62.0.dist-info/METADATA
#   inflating: /tmp/ngc-cli/googleapis_common_protos-1.62.0.dist-info/WHEEL
#  extracting: /tmp/ngc-cli/googleapis_common_protos-1.62.0.dist-info/INSTALLER
#  extracting: /tmp/ngc-cli/googleapis_common_protos-1.62.0.dist-info/top_level.txt
#   inflating: /tmp/ngc-cli/opentelemetry_semantic_conventions-0.43b0.dist-info/RECORD
#   inflating: /tmp/ngc-cli/opentelemetry_semantic_conventions-0.43b0.dist-info/METADATA
#  extracting: /tmp/ngc-cli/opentelemetry_semantic_conventions-0.43b0.dist-info/WHEEL
#   inflating: /tmp/ngc-cli/opentelemetry_semantic_conventions-0.43b0.dist-info/licenses/LICENSE
#  extracting: /tmp/ngc-cli/opentelemetry_semantic_conventions-0.43b0.dist-info/INSTALLER
#   inflating: /tmp/ngc-cli/ngc
#   inflating: /tmp/ngc-cli/libstdc++.so.6
#   inflating: /tmp/ngc-cli/opentelemetry_sdk-1.22.0.dist-info/RECORD
#   inflating: /tmp/ngc-cli/opentelemetry_sdk-1.22.0.dist-info/entry_points.txt
#   inflating: /tmp/ngc-cli/opentelemetry_sdk-1.22.0.dist-info/METADATA
#  extracting: /tmp/ngc-cli/opentelemetry_sdk-1.22.0.dist-info/WHEEL
#   inflating: /tmp/ngc-cli/opentelemetry_sdk-1.22.0.dist-info/licenses/LICENSE
#  extracting: /tmp/ngc-cli/opentelemetry_sdk-1.22.0.dist-info/INSTALLER
#   inflating: /tmp/ngc-cli/libk5crypto.so.3
#   inflating: /tmp/ngc-cli/lib-dynload/_codecs_tw.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/termios.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_decimal.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_datetime.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/grp.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_bisect.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_elementtree.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_sha512.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/fcntl.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_codecs_iso2022.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_multibytecodec.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/binascii.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_csv.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_posixsubprocess.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_sha256.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_codecs_hk.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_multiprocessing.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/select.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_asyncio.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/unicodedata.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_codecs_kr.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_ctypes.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_posixshmem.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/array.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_blake2.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/resource.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_ssl.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/pyexpat.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_codecs_jp.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_queue.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_opcode.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_socket.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_pickle.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/math.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_hashlib.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_codecs_cn.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_statistics.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/zlib.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_sha1.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_sha3.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_struct.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_md5.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/mmap.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_contextvars.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_heapq.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_random.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/lib-dynload/_json.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/libssl.so.10
#   inflating: /tmp/ngc-cli/libselinux.so.1
#  extracting: /tmp/ngc-cli/base_library.zip
#   inflating: /tmp/ngc-cli/libz.so.1
#   inflating: /tmp/ngc-cli/charset_normalizer/md__mypyc.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/charset_normalizer/md.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/google/protobuf/internal/_api_implementation.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/google/protobuf/pyext/_message.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/importlib_metadata-6.11.0.dist-info/RECORD
#   inflating: /tmp/ngc-cli/importlib_metadata-6.11.0.dist-info/LICENSE
#   inflating: /tmp/ngc-cli/importlib_metadata-6.11.0.dist-info/METADATA
#  extracting: /tmp/ngc-cli/importlib_metadata-6.11.0.dist-info/WHEEL
#  extracting: /tmp/ngc-cli/importlib_metadata-6.11.0.dist-info/INSTALLER
#  extracting: /tmp/ngc-cli/importlib_metadata-6.11.0.dist-info/top_level.txt
#   inflating: /tmp/ngc-cli/botocore/data/b2bi/2022-06-23/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/b2bi/2022-06-23/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/b2bi/2022-06-23/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/autoscaling/2011-01-01/paginators-1.json
#   inflating: /tmp/ngc-cli/botocore/data/autoscaling/2011-01-01/paginators-1.sdk-extras.json
#  extracting: /tmp/ngc-cli/botocore/data/autoscaling/2011-01-01/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/autoscaling/2011-01-01/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/autoscaling/2011-01-01/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/apigatewayv2/2018-11-29/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/apigatewayv2/2018-11-29/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/apigatewayv2/2018-11-29/service-2.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/synthetics/2017-10-11/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/synthetics/2017-10-11/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/synthetics/2017-10-11/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/synthetics/2017-10-11/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/applicationcostprofiler/2020-09-10/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/applicationcostprofiler/2020-09-10/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/applicationcostprofiler/2020-09-10/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/applicationcostprofiler/2020-09-10/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/datasync/2018-11-09/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/datasync/2018-11-09/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/datasync/2018-11-09/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/datasync/2018-11-09/examples-1.json
#  extracting: /tmp/ngc-cli/botocore/data/sso-oidc/2019-06-10/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/sso-oidc/2019-06-10/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/sso-oidc/2019-06-10/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/sso-oidc/2019-06-10/examples-1.json
#  extracting: /tmp/ngc-cli/botocore/data/iotdeviceadvisor/2020-09-18/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/iotdeviceadvisor/2020-09-18/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/iotdeviceadvisor/2020-09-18/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/iotdeviceadvisor/2020-09-18/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/medialive/2017-10-14/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/medialive/2017-10-14/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/medialive/2017-10-14/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/medialive/2017-10-14/service-2.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/marketplace-agreement/2020-03-01/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/marketplace-agreement/2020-03-01/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/marketplace-agreement/2020-03-01/service-2.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/wellarchitected/2020-03-31/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/wellarchitected/2020-03-31/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/wellarchitected/2020-03-31/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/wellarchitected/2020-03-31/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/codeguru-security/2018-05-10/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/codeguru-security/2018-05-10/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/codeguru-security/2018-05-10/service-2.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/waf-regional/2016-11-28/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/waf-regional/2016-11-28/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/waf-regional/2016-11-28/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/waf-regional/2016-11-28/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/privatenetworks/2021-12-03/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/privatenetworks/2021-12-03/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/privatenetworks/2021-12-03/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/route53domains/2014-05-15/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/route53domains/2014-05-15/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/route53domains/2014-05-15/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/route53domains/2014-05-15/examples-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cognito-sync/2014-06-30/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cognito-sync/2014-06-30/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/cognito-sync/2014-06-30/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cognito-sync/2014-06-30/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/autoscaling-plans/2018-01-06/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/autoscaling-plans/2018-01-06/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/autoscaling-plans/2018-01-06/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/autoscaling-plans/2018-01-06/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/secretsmanager/2017-10-17/paginators-1.json
#   inflating: /tmp/ngc-cli/botocore/data/secretsmanager/2017-10-17/service-2.sdk-extras.json
#  extracting: /tmp/ngc-cli/botocore/data/secretsmanager/2017-10-17/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/secretsmanager/2017-10-17/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/secretsmanager/2017-10-17/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cloud9/2017-09-23/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloud9/2017-09-23/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/cloud9/2017-09-23/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloud9/2017-09-23/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/ses/2010-12-01/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/ses/2010-12-01/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/ses/2010-12-01/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/ses/2010-12-01/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/ses/2010-12-01/examples-1.json
#  extracting: /tmp/ngc-cli/botocore/data/sagemaker-edge/2020-09-23/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/sagemaker-edge/2020-09-23/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/sagemaker-edge/2020-09-23/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/sagemaker-edge/2020-09-23/examples-1.json
#  extracting: /tmp/ngc-cli/botocore/data/ce/2017-10-25/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/ce/2017-10-25/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/ce/2017-10-25/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/ce/2017-10-25/examples-1.json
#  extracting: /tmp/ngc-cli/botocore/data/workmailmessageflow/2019-05-01/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/workmailmessageflow/2019-05-01/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/workmailmessageflow/2019-05-01/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/workmailmessageflow/2019-05-01/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/location/2020-11-19/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/location/2020-11-19/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/location/2020-11-19/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/location/2020-11-19/examples-1.json
#  extracting: /tmp/ngc-cli/botocore/data/healthlake/2017-07-01/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/healthlake/2017-07-01/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/healthlake/2017-07-01/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/healthlake/2017-07-01/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/ssm-incidents/2018-05-10/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/ssm-incidents/2018-05-10/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/ssm-incidents/2018-05-10/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/ssm-incidents/2018-05-10/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/ssm-incidents/2018-05-10/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/license-manager-user-subscriptions/2018-05-10/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/license-manager-user-subscriptions/2018-05-10/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/license-manager-user-subscriptions/2018-05-10/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudhsmv2/2017-04-28/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudhsmv2/2017-04-28/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/cloudhsmv2/2017-04-28/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudhsmv2/2017-04-28/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/workspaces/2015-04-08/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/workspaces/2015-04-08/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/workspaces/2015-04-08/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/workspaces/2015-04-08/examples-1.json
#  extracting: /tmp/ngc-cli/botocore/data/frauddetector/2019-11-15/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/frauddetector/2019-11-15/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/frauddetector/2019-11-15/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/frauddetector/2019-11-15/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront-keyvaluestore/2022-07-26/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront-keyvaluestore/2022-07-26/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront-keyvaluestore/2022-07-26/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/elb/2012-06-01/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/elb/2012-06-01/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/elb/2012-06-01/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/elb/2012-06-01/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/elb/2012-06-01/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/ecr-public/2020-10-30/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/ecr-public/2020-10-30/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/ecr-public/2020-10-30/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/ecr-public/2020-10-30/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/lightsail/2016-11-28/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/lightsail/2016-11-28/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/lightsail/2016-11-28/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/lightsail/2016-11-28/examples-1.json
#  extracting: /tmp/ngc-cli/botocore/data/iotevents-data/2018-10-23/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/iotevents-data/2018-10-23/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/iotevents-data/2018-10-23/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/iotevents-data/2018-10-23/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/migration-hub-refactor-spaces/2021-10-26/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/migration-hub-refactor-spaces/2021-10-26/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/migration-hub-refactor-spaces/2021-10-26/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/migration-hub-refactor-spaces/2021-10-26/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/clouddirectory/2016-05-10/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/clouddirectory/2016-05-10/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/clouddirectory/2016-05-10/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/clouddirectory/2016-05-10/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/clouddirectory/2017-01-11/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/clouddirectory/2017-01-11/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/clouddirectory/2017-01-11/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/clouddirectory/2017-01-11/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/logs/2014-03-28/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/logs/2014-03-28/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/logs/2014-03-28/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/logs/2014-03-28/examples-1.json
#  extracting: /tmp/ngc-cli/botocore/data/inspector-scan/2023-08-08/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/inspector-scan/2023-08-08/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/inspector-scan/2023-08-08/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/bedrock-agent/2023-06-05/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/bedrock-agent/2023-06-05/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/bedrock-agent/2023-06-05/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/qbusiness/2023-11-27/paginators-1.json
#   inflating: /tmp/ngc-cli/botocore/data/qbusiness/2023-11-27/paginators-1.sdk-extras.json
#  extracting: /tmp/ngc-cli/botocore/data/qbusiness/2023-11-27/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/qbusiness/2023-11-27/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/ecs/2014-11-13/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/ecs/2014-11-13/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/ecs/2014-11-13/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/ecs/2014-11-13/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/ecs/2014-11-13/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cur/2017-01-06/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cur/2017-01-06/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/cur/2017-01-06/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cur/2017-01-06/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/tnb/2008-10-21/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/tnb/2008-10-21/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/tnb/2008-10-21/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/m2/2021-04-28/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/m2/2021-04-28/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/m2/2021-04-28/service-2.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/savingsplans/2019-06-28/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/savingsplans/2019-06-28/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/savingsplans/2019-06-28/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/savingsplans/2019-06-28/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/codeartifact/2018-09-22/paginators-1.json
#   inflating: /tmp/ngc-cli/botocore/data/codeartifact/2018-09-22/paginators-1.sdk-extras.json
#  extracting: /tmp/ngc-cli/botocore/data/codeartifact/2018-09-22/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/codeartifact/2018-09-22/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/codeartifact/2018-09-22/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/devops-guru/2020-12-01/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/devops-guru/2020-12-01/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/devops-guru/2020-12-01/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/devops-guru/2020-12-01/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/sagemaker/2017-07-24/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/sagemaker/2017-07-24/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/sagemaker/2017-07-24/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/sagemaker/2017-07-24/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/sagemaker/2017-07-24/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/amplify/2017-07-25/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/amplify/2017-07-25/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/amplify/2017-07-25/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/amplify/2017-07-25/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/finspace-data/2020-07-13/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/finspace-data/2020-07-13/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/finspace-data/2020-07-13/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/finspace-data/2020-07-13/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/textract/2018-06-27/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/textract/2018-06-27/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/textract/2018-06-27/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/textract/2018-06-27/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudhsm/2014-05-30/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudhsm/2014-05-30/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/cloudhsm/2014-05-30/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudhsm/2014-05-30/examples-1.json
#  extracting: /tmp/ngc-cli/botocore/data/chime-sdk-media-pipelines/2021-07-15/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/chime-sdk-media-pipelines/2021-07-15/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/chime-sdk-media-pipelines/2021-07-15/service-2.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/kendra-ranking/2022-10-19/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/kendra-ranking/2022-10-19/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/kendra-ranking/2022-10-19/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/timestream-query/2018-11-01/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/timestream-query/2018-11-01/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/timestream-query/2018-11-01/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/timestream-query/2018-11-01/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/config/2014-11-12/paginators-1.json
# ...
#   inflating: /tmp/ngc-cli/botocore/data/compute-optimizer/2019-11-01/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/compute-optimizer/2019-11-01/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/compute-optimizer/2019-11-01/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/compute-optimizer/2019-11-01/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudcontrol/2021-09-30/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudcontrol/2021-09-30/paginators-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudcontrol/2021-09-30/paginators-1.sdk-extras.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudcontrol/2021-09-30/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/cloudcontrol/2021-09-30/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudcontrol/2021-09-30/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/batch/2016-08-10/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/batch/2016-08-10/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/batch/2016-08-10/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/batch/2016-08-10/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/controltower/2018-05-10/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/controltower/2018-05-10/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/controltower/2018-05-10/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cognito-idp/2016-04-18/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cognito-idp/2016-04-18/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cognito-idp/2016-04-18/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cognito-idp/2016-04-18/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/importexport/2010-06-01/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/importexport/2010-06-01/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/importexport/2010-06-01/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/dataexchange/2017-07-25/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/dataexchange/2017-07-25/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/dataexchange/2017-07-25/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/dataexchange/2017-07-25/service-2.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/resiliencehub/2020-04-30/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/resiliencehub/2020-04-30/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/resiliencehub/2020-04-30/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/resiliencehub/2020-04-30/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/memorydb/2021-01-01/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/memorydb/2021-01-01/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/memorydb/2021-01-01/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/memorydb/2021-01-01/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-01-13/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-01-13/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2016-01-13/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2016-01-13/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-08-20/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-08-20/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2016-08-20/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-08-20/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2020-05-31/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2020-05-31/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2020-05-31/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2020-05-31/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2020-05-31/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-09-29/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-09-29/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2016-09-29/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2016-09-29/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-09-29/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2015-04-17/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2015-04-17/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2015-04-17/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2015-04-17/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2014-05-31/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2014-05-31/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2014-05-31/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2014-05-31/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2014-10-21/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2014-10-21/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2014-10-21/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2014-10-21/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2017-10-30/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2017-10-30/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2017-10-30/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2017-10-30/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2017-10-30/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2017-03-25/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2017-03-25/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2017-03-25/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2017-03-25/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-08-01/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-08-01/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2016-08-01/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2016-08-01/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-08-01/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-09-07/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-09-07/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2016-09-07/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-09-07/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-09-07/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2018-06-18/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2018-06-18/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2018-06-18/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2018-06-18/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2018-06-18/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2018-11-05/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2018-11-05/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2018-11-05/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2018-11-05/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2018-11-05/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-01-28/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-01-28/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2016-01-28/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2016-01-28/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-01-28/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2019-03-26/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2019-03-26/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2019-03-26/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2019-03-26/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2019-03-26/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2015-09-17/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2015-09-17/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2015-09-17/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2015-09-17/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2014-11-06/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2014-11-06/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2014-11-06/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2014-11-06/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-11-25/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-11-25/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2016-11-25/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2016-11-25/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2016-11-25/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2015-07-27/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/cloudfront/2015-07-27/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2015-07-27/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/cloudfront/2015-07-27/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/mgn/2020-02-26/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/mgn/2020-02-26/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/mgn/2020-02-26/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/mgn/2020-02-26/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/bedrock-runtime/2023-09-30/waiters-2.json
#  extracting: /tmp/ngc-cli/botocore/data/bedrock-runtime/2023-09-30/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/bedrock-runtime/2023-09-30/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/bedrock-runtime/2023-09-30/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/codestar/2017-04-19/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/codestar/2017-04-19/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/codestar/2017-04-19/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/codestar/2017-04-19/examples-1.json
#  extracting: /tmp/ngc-cli/botocore/data/imagebuilder/2019-12-02/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/imagebuilder/2019-12-02/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/imagebuilder/2019-12-02/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/imagebuilder/2019-12-02/examples-1.json
#  extracting: /tmp/ngc-cli/botocore/data/timestream-write/2018-11-01/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/timestream-write/2018-11-01/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/timestream-write/2018-11-01/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/timestream-write/2018-11-01/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/arc-zonal-shift/2022-10-30/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/arc-zonal-shift/2022-10-30/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/arc-zonal-shift/2022-10-30/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/rekognition/2016-06-27/waiters-2.json
#   inflating: /tmp/ngc-cli/botocore/data/rekognition/2016-06-27/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/rekognition/2016-06-27/endpoint-rule-set-1.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/rekognition/2016-06-27/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/rekognition/2016-06-27/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/data/braket/2019-09-01/paginators-1.json
#  extracting: /tmp/ngc-cli/botocore/data/braket/2019-09-01/endpoint-rule-set-1.json.gz
#  extracting: /tmp/ngc-cli/botocore/data/braket/2019-09-01/service-2.json.gz
#   inflating: /tmp/ngc-cli/botocore/data/braket/2019-09-01/examples-1.json
#   inflating: /tmp/ngc-cli/botocore/cacert.pem
#   inflating: /tmp/ngc-cli/prettytable-2.0.0.dist-info/RECORD
#   inflating: /tmp/ngc-cli/prettytable-2.0.0.dist-info/COPYING
#   inflating: /tmp/ngc-cli/prettytable-2.0.0.dist-info/METADATA
#  extracting: /tmp/ngc-cli/prettytable-2.0.0.dist-info/WHEEL
#  extracting: /tmp/ngc-cli/prettytable-2.0.0.dist-info/INSTALLER
#  extracting: /tmp/ngc-cli/prettytable-2.0.0.dist-info/top_level.txt
#   inflating: /tmp/ngc-cli/aiohttp/_http_writer.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/aiohttp/_http_parser.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/aiohttp/_helpers.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/aiohttp/_websocket.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/libkeyutils.so.1
#   inflating: /tmp/ngc-cli/typing_extensions-4.9.0.dist-info/RECORD
#   inflating: /tmp/ngc-cli/typing_extensions-4.9.0.dist-info/LICENSE
#   inflating: /tmp/ngc-cli/typing_extensions-4.9.0.dist-info/METADATA
#  extracting: /tmp/ngc-cli/typing_extensions-4.9.0.dist-info/WHEEL
#  extracting: /tmp/ngc-cli/typing_extensions-4.9.0.dist-info/INSTALLER
#   inflating: /tmp/ngc-cli/_cffi_backend.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/psutil/_psutil_linux.abi3.so
#   inflating: /tmp/ngc-cli/psutil/_psutil_posix.abi3.so
#   inflating: /tmp/ngc-cli/libffi.so.6
#   inflating: /tmp/ngc-cli/setuptools-49.6.0.dist-info/RECORD
#   inflating: /tmp/ngc-cli/setuptools-49.6.0.dist-info/entry_points.txt
#   inflating: /tmp/ngc-cli/setuptools-49.6.0.dist-info/LICENSE
#   inflating: /tmp/ngc-cli/setuptools-49.6.0.dist-info/dependency_links.txt
#   inflating: /tmp/ngc-cli/setuptools-49.6.0.dist-info/METADATA
#  extracting: /tmp/ngc-cli/setuptools-49.6.0.dist-info/WHEEL
#  extracting: /tmp/ngc-cli/setuptools-49.6.0.dist-info/zip-safe
#  extracting: /tmp/ngc-cli/setuptools-49.6.0.dist-info/INSTALLER
#   inflating: /tmp/ngc-cli/setuptools-49.6.0.dist-info/top_level.txt
#   inflating: /tmp/ngc-cli/markupsafe/_speedups.cpython-39-x86_64-linux-gnu.so
#   inflating: /tmp/ngc-cli/Deprecated-1.2.14.dist-info/RECORD
#   inflating: /tmp/ngc-cli/Deprecated-1.2.14.dist-info/METADATA
#   inflating: /tmp/ngc-cli/Deprecated-1.2.14.dist-info/LICENSE.rst
#   inflating: /tmp/ngc-cli/Deprecated-1.2.14.dist-info/WHEEL
#  extracting: /tmp/ngc-cli/Deprecated-1.2.14.dist-info/INSTALLER
#  extracting: /tmp/ngc-cli/Deprecated-1.2.14.dist-info/top_level.txt
#  extracting: /tmp/ngc-cli.md5
#
# Done.
# NGC CLI successfully installed.
# Running command: mkdir -p /workspace/bionemo/models && /tmp/ngc-cli/ngc registry model download-version nvidia/clara/esm2nv650m:1.0 --dest /workspace/bionemo/models && mv /workspace/bionemo/models/esm2nv650m_v1.0/* /workspace/bionemo/models/ && rm -d /workspace/bionemo/models/esm2nv650m_v1.0
#
#
# Done.
# Running command: mkdir -p /workspace/bionemo/models/protein/esm2nv && ln -sf ../../esm2nv_650M_converted.nemo /workspace/bionemo/models/protein/esm2nv/esm2nv_650M_converted.nemo
#
#
# Done.

# %% [markdown]
# ダウンロードされたモデルは .nemo というファイルで、 /workspace/bionemo/models に保存されます。
# そして、以下の YAML ファイルを開きます。
#
# /workspace/bionemo/examples/protein/esm2nv/conf/downstream_flip_sec_str.yaml

# %% [markdown]
# 以下のパラメータは必要に応じて設定してください。
#
# * restore_from_path: 事前学習済みのモデルのチェックポイントの .nemo ファイルのパスに設定します。
# * trainer.devices, trainer.num_nodes: 使用する GPU とノードの数に設定します。
# * trainer.max_epochs: トレーニングしたいエポック数に設定します。
# * trainer.val_check_interval: 検証を実行するステップ数に設定します。
# * model.micro_batch_size: トレーニングのマイクロバッチサイズに設定します。
# * data.task_name: 任意の名前を設定します。
# * data.task_type: 現在のオプションには、token-level-classification、classification (sequence level)、および regression (sequence level) があります。 preprocessed_data_path: dataset_path の親フォルダのパスに設定します。
# * dataset_path: train/val/testフォルダが含まれるフォルダのパスに設定します。例えば、上記のpath/to/data というパスに設定します。
# * dataset.train, dataset.val, dataset.test: CSV 名または範囲に設定します。
# * sequence_column: シーケンスを含む列の名前に設定します。例：sequence
# * target_column: ターゲットを含む列の名前に設定します。例：scl_label
# * target_size: 分類のための各ラベルのクラス数。
# * num_classes: target_size に設定します。

# %% [markdown]
# そして、下記のコマンドでファインチューニングを実行します。BioNemo Framework v1.4 は新たな機能として、LoRa というファインチューニングの手法追加しました。Lora は事前学習済み大規模言語モデルのすべての重みをファインチューニングするのではなく、大規模な重み行列を近似する二つの小規模な行列をファンチューニングする効率的なファインチューニングの手法です。

# %%
cd /workspace/bionemo
# Out:
# /workspace/bionemo

# %%
# !python examples/protein/downstream/downstream_flip.py\
 --config-path="../esm2nv/conf"\
 --config-name=downstream_sec_str_LORA\
 ++model.data.dataset_path=/workspace/bionemo/examples/tests/test_data/protein/downstream/
# Out:
# [NeMo I 2024-05-14 16:12:15 megatron_hiddens:110] Registered hidden transform sampled_var_cond_gaussian at bionemo.model.core.hiddens_support.SampledVarGaussianHiddenTransform
# [NeMo I 2024-05-14 16:12:15 megatron_hiddens:110] Registered hidden transform interp_var_cond_gaussian at bionemo.model.core.hiddens_support.InterpVarGaussianHiddenTransform
# [NeMo W 2024-05-14 16:12:15 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/hydra/_internal/defaults_list.py:251: UserWarning: In 'downstream_sec_str_LORA': Defaults list is missing `_self_`. See https://hydra.cc/docs/1.2/upgrades/1.0_to_1.1/default_composition_order for more information
#       warnings.warn(msg, UserWarning)
#
# [NeMo W 2024-05-14 16:12:15 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
#     See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#       ret = run_job(
#
# [NeMo I 2024-05-14 16:12:15 downstream_flip:28]
#
#     ************* Finetune config ****************
# [NeMo I 2024-05-14 16:12:15 downstream_flip:29]
#     name: esm2nv_flip
#     do_training: true
#     do_testing: true
#     restore_from_path: null
#     trainer:
#       devices: 1
#       num_nodes: 1
#       accelerator: gpu
#       precision: 32
#       logger: false
#       enable_checkpointing: false
#       use_distributed_sampler: false
#       max_epochs: 20
#       log_every_n_steps: 10
#       val_check_interval: 20
#       limit_val_batches: 1000
#       limit_test_batches: 1000
#       accumulate_grad_batches: 1
#       gradient_clip_val: 1.0
#       benchmark: false
#       max_steps: 500000
#     exp_manager:
#       name: ${name}
#       exp_dir: ${oc.env:BIONEMO_HOME}/results/nemo_experiments/${.name}/${.wandb_logger_kwargs.name}
#       explicit_log_dir: ${.exp_dir}
#       create_wandb_logger: true
#       create_tensorboard_logger: true
#       wandb_logger_kwargs:
#         project: ${name}_${model.data.task_name}_finetuning
#         name: ${name}_${model.data.task_name}_finetuning_encoder_frozen_${model.encoder_frozen}_${model.peft.peft_scheme}
#         group: ${name}
#         job_type: Localhost_nodes_${trainer.num_nodes}_gpus_${trainer.devices}
#         notes: 'date: ${now:%y%m%d-%H%M%S}'
#         tags:
#         - ${name}
#         offline: true
#       resume_if_exists: true
#       resume_ignore_no_checkpoint: true
#       create_checkpoint_callback: true
#       checkpoint_callback_params:
#         monitor: val_loss
#         save_top_k: 10
#         mode: min
#         always_save_nemo: false
#         filename: megatron_bert--{val_loss:.2f}-{step}-{consumed_samples}
#         model_parallel_size: ${multiply:${model.tensor_model_parallel_size}, ${model.pipeline_model_parallel_size}}
#     model:
#       drop_last: true
#       micro_batch_size: 2
#       seq_length: 1024
#       num_layers: 33
#       hidden_size: 1280
#       ffn_hidden_size: ${multiply:${model.hidden_size}, 4}
#       num_attention_heads: 20
#       megatron_legacy: false
#       position_embedding_type: rope
#       hidden_dropout: 0
#       embedding_use_attention_mask: true
#       embedding_token_dropout: true
#       mask_token_id: ${.tokenizer.mask_id}
#       attention_dropout: 0.0
#       normalize_attention_scores: false
#       tensor_model_parallel_size: 1
#       pipeline_model_parallel_size: 1
#       bias_gelu_fusion: false
#       use_esm_attention: true
#       esm_gelu: true
#       use_pt_layernorm: false
#       use_pt_mlp_out: false
#       max_position_embeddings: ${.seq_length}
#       encoder_seq_length: ${.seq_length}
#       optim:
#         name: fused_adam
#         lr: 0.0004
#         weight_decay: 0.01
#         betas:
#         - 0.9
#         - 0.98
#         sched:
#           name: WarmupAnnealDecayHold
#           warmup_steps: 2000
#           min_lr: 4.0e-05
#           max_lr: 0.0004
#           max_steps: 500000
#           anneal_percentage: 0.1
#       init_method_std: 0.02
#       kv_channels: null
#       apply_query_key_layer_scaling: true
#       layernorm_epsilon: 1.0e-05
#       make_vocab_size_divisible_by: 128
#       pre_process: true
#       post_process: false
#       bert_binary_head: false
#       resume_from_checkpoint: null
#       masked_softmax_fusion: true
#       tokenizer:
#         library: huggingface
#         type: BertWordPieceLowerCase
#         model_name: facebook/esm2_t33_650M_UR50D
#         mask_id: 32
#         model: null
#         vocab_file: null
#         merge_file: null
#       native_amp_init_scale: 4294967296
#       native_amp_growth_interval: 1000
#       fp32_residual_connection: false
#       fp16_lm_cross_entropy: false
#       seed: 1234
#       use_cpu_initialization: false
#       onnx_safe: false
#       activations_checkpoint_method: null
#       activations_checkpoint_num_layers: 1
#       data:
#         ngc_registry_target: uniref50_2022_05
#         ngc_registry_version: v23.06
#         data_prefix: ''
#         num_workers: 8
#         dataloader_type: single
#         reset_position_ids: false
#         reset_attention_mask: false
#         eod_mask_loss: false
#         masked_lm_prob: 0.15
#         short_seq_prob: 0.1
#         skip_lines: 0
#         drop_last: false
#         pin_memory: false
#         dynamic_padding: false
#         force_regen_sample_mapping: false
#         dataset_path: /workspace/bionemo/examples/tests/test_data/protein/downstream/
#         index_mapping_dir: ${model.data.dataset_path}
#         preprocessing:
#           num_preprocess_workers: 16
#         train:
#           data_impl: csv_mmap
#           data_impl_kwargs:
#             csv_mmap:
#               data_col: 1
#               header_lines: 1
#           use_upsampling: true
#           range: x[000..049]
#           sample_from_map: true
#           uf50_datapath: ${model.data.dataset_path}/uniref50_train_filt.fasta
#           uf90_datapath: ${model.data.dataset_path}/uniref90membersandreps_ur50trainfiltreps.fasta
#           cluster_mapping_tsv: ${model.data.dataset_path}/uniref50_mapper_to_uniref90clustermembers_andselfuniref50.tsv
#           dataset_path: ${model.data.dataset_path}/uf50
#           sort_fastas: true
#           num_workers: ${model.data.num_workers}
#           uf90:
#             uniref90_path: ${model.data.dataset_path}/uf90
#             dataset:
#               uf90_csvs: x[000..049]
#             data_impl: csv_fields_mmap
#             data_impl_kwargs:
#               csv_fields_mmap:
#                 header_lines: 1
#                 newline_int: 10
#                 workers: ${model.data.train.num_workers}
#                 sort_dataset_paths: true
#                 data_sep: ','
#                 data_fields:
#                   sequence: 3
#                   sequence_id: 1
#             index_mapping_dir: ${model.data.index_mapping_dir}
#           index_mapping_dir: ${model.data.index_mapping_dir}
#           max_seq_length: ${model.seq_length}
#           seed: ${model.seed}
#         val:
#           use_upsampling: false
#           range: x[000..049]
#           uf50_datapath: ${model.data.dataset_path}/uniref50_train_filt.fasta
#           dataset_path: ${model.data.dataset_path}/uf50
#           data_impl: csv_fields_mmap
#           num_workers: ${model.data.num_workers}
#           data_impl_kwargs:
#             csv_fields_mmap:
#               header_lines: 1
#               newline_int: 10
#               workers: ${model.data.val.num_workers}
#               sort_dataset_paths: true
#               data_sep: ','
#               data_fields:
#                 sequence: 3
#                 sequence_id: 1
#           index_mapping_dir: ${model.data.index_mapping_dir}
#           max_seq_length: ${model.seq_length}
#           seed: ${model.seed}
#         test:
#           use_upsampling: false
#           range: x[000..049]
#           uf50_datapath: ${model.data.dataset_path}/uniref50_train_filt.fasta
#           dataset_path: ${model.data.dataset_path}/uf50
#           data_impl: csv_fields_mmap
#           num_workers: ${model.data.num_workers}
#           data_impl_kwargs:
#             csv_fields_mmap:
#               header_lines: 1
#               newline_int: 10
#               workers: ${model.data.test.num_workers}
#               sort_dataset_paths: true
#               data_sep: ','
#               data_fields:
#                 sequence: 3
#                 sequence_id: 1
#           index_mapping_dir: ${model.data.index_mapping_dir}
#           max_seq_length: ${model.seq_length}
#           seed: ${model.seed}
#         modify_percent: 0.1
#         perturb_percent: 0.5
#         task_name: secondary_structure
#         task_type: token-level-classification
#         preprocessed_data_path: ${oc.env:BIONEMO_HOME}/data/FLIP
#         dataset:
#           train: x000
#           val: x000
#           test: x000
#         sequence_column: sequence
#         target_column:
#         - 3state
#         target_sizes:
#         - 3
#         mask_column:
#         - resolved
#         max_seq_length: ${model.seq_length}
#         emb_batch_size: ${model.micro_batch_size}
#       dwnstr_task_validation:
#         enabled: false
#         dataset:
#           class: bionemo.model.core.dwnstr_task_callbacks.PerTokenPredictionCallback
#           task_type: token-level-classification
#           infer_target: bionemo.model.protein.esm1nv.infer.ESM1nvInference
#           max_seq_length: ${model.seq_length}
#           emb_batch_size: 128
#           batch_size: 128
#           num_epochs: 10
#           shuffle: true
#           num_workers: 8
#           task_name: secondary_structure
#           dataset_path: ${oc.env:BIONEMO_HOME}/data/FLIP/${model.dwnstr_task_validation.dataset.task_name}
#           dataset:
#             train: x000
#             test: x000
#           sequence_column: sequence
#           target_column:
#           - 3state
#           target_sizes:
#           - 3
#           mask_column:
#           - resolved
#           random_seed: 1234
#           optim:
#             name: adam
#             lr: 0.0001
#             betas:
#             - 0.9
#             - 0.999
#             eps: 1.0e-08
#             weight_decay: 0.01
#             sched:
#               name: WarmupAnnealing
#               min_lr: 1.0e-05
#               last_epoch: -1
#               warmup_ratio: 0.01
#               max_steps: 1000
#       restore_encoder_path: ${oc.env:BIONEMO_HOME}/models/protein/esm2nv/esm2nv_650M_converted.nemo
#       encoder_frozen: false
#       global_batch_size: null
#       cnn_dim: 32
#       dropout_rate: 0.25
#       megatron_amp_O2: false
#       peft:
#         enabled: true
#         peft_scheme: lora
#         restore_from_path: null
#         lora_tuning:
#           adapter_dim: 32
#           adapter_dropout: 0.0
#           column_init_method: xavier
#           row_init_method: zero
#           layer_selection: null
#           weight_tying: false
#           position_embedding_strategy: null
#       finetuning_optim:
#         name: adam
#         lr: 0.0001
#         betas:
#         - 0.9
#         - 0.999
#         eps: 1.0e-08
#         weight_decay: 0.01
#         sched:
#           name: WarmupAnnealing
#           min_lr: 1.0e-05
#           last_epoch: -1
#           warmup_ratio: 10
#     do_preprocessing: false
#     target: bionemo.model.protein.esm1nv.ESM2nvLoRAModel
#     infer_target: bionemo.model.protein.esm1nv.infer.ESM1nvInference
#
# [NeMo I 2024-05-14 16:12:15 utils:230] Selected Callbacks: [<class 'pytorch_lightning.callbacks.model_summary.ModelSummary'>]
# Trainer already configured with model summary callbacks: [<class 'pytorch_lightning.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [NeMo E 2024-05-14 16:12:15 exp_manager:684] exp_manager received explicit_log_dir: /workspace/bionemo/results/nemo_experiments/esm2nv_flip/esm2nv_flip_secondary_structure_finetuning_encoder_frozen_False_lora and at least one of exp_dir: /workspace/bionemo/results/nemo_experiments/esm2nv_flip/esm2nv_flip_secondary_structure_finetuning_encoder_frozen_False_lora, or version: None. Please note that exp_dir, name, and version will be ignored.
# [NeMo W 2024-05-14 16:12:15 exp_manager:611] There were no checkpoints found in checkpoint_dir or no checkpoint folder at checkpoint_dir :/workspace/bionemo/results/nemo_experiments/esm2nv_flip/esm2nv_flip_secondary_structure_finetuning_encoder_frozen_False_lora/checkpoints. Training from scratch.
# [NeMo I 2024-05-14 16:12:15 exp_manager:394] Experiments will be logged at /workspace/bionemo/results/nemo_experiments/esm2nv_flip/esm2nv_flip_secondary_structure_finetuning_encoder_frozen_False_lora
# [NeMo I 2024-05-14 16:12:15 exp_manager:835] TensorboardLogger has been set up
# wandb: WARNING `resume` will be ignored since W&B syncing is set to `offline`. Starting a new run with run id 3vqbb4v1.
# wandb: Tracking run with wandb version 0.15.6
# wandb: W&B syncing is set to `offline` in this directory.
# wandb: Run `wandb online` or set WANDB_MODE=online to enable cloud syncing.
# [NeMo I 2024-05-14 16:12:17 exp_manager:850] WandBLogger has been set up
# [NeMo W 2024-05-14 16:12:17 exp_manager:931] The checkpoint callback was told to monitor a validation value and trainer's max_steps was set to 500000. Please ensure that max_steps will run for at least 1 epochs to ensure that checkpointing will not error out.
# [NeMo I 2024-05-14 16:12:17 utils:306]
#
#     ************** Trainer configuration ***********
# [NeMo I 2024-05-14 16:12:17 utils:307]
#     name: esm2nv_flip
#     do_training: true
#     do_testing: true
#     restore_from_path: null
#     trainer:
#       devices: 1
#       num_nodes: 1
#       accelerator: gpu
#       precision: 32
#       logger: false
#       enable_checkpointing: false
#       use_distributed_sampler: false
#       max_epochs: 20
#       log_every_n_steps: 10
#       val_check_interval: 20
#       limit_val_batches: 1000
#       limit_test_batches: 1000
#       accumulate_grad_batches: 1
#       gradient_clip_val: 1.0
#       benchmark: false
#       max_steps: 500000
#     exp_manager:
#       name: ${name}
#       exp_dir: ${oc.env:BIONEMO_HOME}/results/nemo_experiments/${.name}/${.wandb_logger_kwargs.name}
#       explicit_log_dir: ${.exp_dir}
#       create_wandb_logger: true
#       create_tensorboard_logger: true
#       wandb_logger_kwargs:
#         project: ${name}_${model.data.task_name}_finetuning
#         name: ${name}_${model.data.task_name}_finetuning_encoder_frozen_${model.encoder_frozen}_${model.peft.peft_scheme}
#         group: ${name}
#         job_type: Localhost_nodes_${trainer.num_nodes}_gpus_${trainer.devices}
#         notes: 'date: ${now:%y%m%d-%H%M%S}'
#         tags:
#         - ${name}
#         offline: true
#       resume_if_exists: true
#       resume_ignore_no_checkpoint: true
#       create_checkpoint_callback: true
#       checkpoint_callback_params:
#         monitor: val_loss
#         save_top_k: 10
#         mode: min
#         always_save_nemo: false
#         filename: megatron_bert--{val_loss:.2f}-{step}-{consumed_samples}
#         model_parallel_size: ${multiply:${model.tensor_model_parallel_size}, ${model.pipeline_model_parallel_size}}
#     model:
#       drop_last: true
#       micro_batch_size: 2
#       seq_length: 1024
#       num_layers: 33
#       hidden_size: 1280
#       ffn_hidden_size: ${multiply:${model.hidden_size}, 4}
#       num_attention_heads: 20
#       megatron_legacy: false
#       position_embedding_type: rope
#       hidden_dropout: 0
#       embedding_use_attention_mask: true
#       embedding_token_dropout: true
#       mask_token_id: ${.tokenizer.mask_id}
#       attention_dropout: 0.0
#       normalize_attention_scores: false
#       tensor_model_parallel_size: 1
#       pipeline_model_parallel_size: 1
#       bias_gelu_fusion: false
#       use_esm_attention: true
#       esm_gelu: true
#       use_pt_layernorm: false
#       use_pt_mlp_out: false
#       max_position_embeddings: ${.seq_length}
#       encoder_seq_length: ${.seq_length}
#       optim:
#         name: fused_adam
#         lr: 0.0004
#         weight_decay: 0.01
#         betas:
#         - 0.9
#         - 0.98
#         sched:
#           name: WarmupAnnealDecayHold
#           warmup_steps: 2000
#           min_lr: 4.0e-05
#           max_lr: 0.0004
#           max_steps: 500000
#           anneal_percentage: 0.1
#       init_method_std: 0.02
#       kv_channels: null
#       apply_query_key_layer_scaling: true
#       layernorm_epsilon: 1.0e-05
#       make_vocab_size_divisible_by: 128
#       pre_process: true
#       post_process: false
#       bert_binary_head: false
#       resume_from_checkpoint: null
#       masked_softmax_fusion: true
#       tokenizer:
#         library: huggingface
#         type: BertWordPieceLowerCase
#         model_name: facebook/esm2_t33_650M_UR50D
#         mask_id: 32
#         model: null
#         vocab_file: null
#         merge_file: null
#       native_amp_init_scale: 4294967296
#       native_amp_growth_interval: 1000
#       fp32_residual_connection: false
#       fp16_lm_cross_entropy: false
#       seed: 1234
#       use_cpu_initialization: false
#       onnx_safe: false
#       activations_checkpoint_method: null
#       activations_checkpoint_num_layers: 1
#       data:
#         ngc_registry_target: uniref50_2022_05
#         ngc_registry_version: v23.06
#         data_prefix: ''
#         num_workers: 8
#         dataloader_type: single
#         reset_position_ids: false
#         reset_attention_mask: false
#         eod_mask_loss: false
#         masked_lm_prob: 0.15
#         short_seq_prob: 0.1
#         skip_lines: 0
#         drop_last: false
#         pin_memory: false
#         dynamic_padding: false
#         force_regen_sample_mapping: false
#         dataset_path: /workspace/bionemo/examples/tests/test_data/protein/downstream/
#         index_mapping_dir: ${model.data.dataset_path}
#         preprocessing:
#           num_preprocess_workers: 16
#         train:
#           data_impl: csv_mmap
#           data_impl_kwargs:
#             csv_mmap:
#               data_col: 1
#               header_lines: 1
#           use_upsampling: true
#           range: x[000..049]
#           sample_from_map: true
#           uf50_datapath: ${model.data.dataset_path}/uniref50_train_filt.fasta
#           uf90_datapath: ${model.data.dataset_path}/uniref90membersandreps_ur50trainfiltreps.fasta
#           cluster_mapping_tsv: ${model.data.dataset_path}/uniref50_mapper_to_uniref90clustermembers_andselfuniref50.tsv
#           dataset_path: ${model.data.dataset_path}/uf50
#           sort_fastas: true
#           num_workers: ${model.data.num_workers}
#           uf90:
#             uniref90_path: ${model.data.dataset_path}/uf90
#             dataset:
#               uf90_csvs: x[000..049]
#             data_impl: csv_fields_mmap
#             data_impl_kwargs:
#               csv_fields_mmap:
#                 header_lines: 1
#                 newline_int: 10
#                 workers: ${model.data.train.num_workers}
#                 sort_dataset_paths: true
#                 data_sep: ','
#                 data_fields:
#                   sequence: 3
#                   sequence_id: 1
#             index_mapping_dir: ${model.data.index_mapping_dir}
#           index_mapping_dir: ${model.data.index_mapping_dir}
#           max_seq_length: ${model.seq_length}
#           seed: ${model.seed}
#         val:
#           use_upsampling: false
#           range: x[000..049]
#           uf50_datapath: ${model.data.dataset_path}/uniref50_train_filt.fasta
#           dataset_path: ${model.data.dataset_path}/uf50
#           data_impl: csv_fields_mmap
#           num_workers: ${model.data.num_workers}
#           data_impl_kwargs:
#             csv_fields_mmap:
#               header_lines: 1
#               newline_int: 10
#               workers: ${model.data.val.num_workers}
#               sort_dataset_paths: true
#               data_sep: ','
#               data_fields:
#                 sequence: 3
#                 sequence_id: 1
#           index_mapping_dir: ${model.data.index_mapping_dir}
#           max_seq_length: ${model.seq_length}
#           seed: ${model.seed}
#         test:
#           use_upsampling: false
#           range: x[000..049]
#           uf50_datapath: ${model.data.dataset_path}/uniref50_train_filt.fasta
#           dataset_path: ${model.data.dataset_path}/uf50
#           data_impl: csv_fields_mmap
#           num_workers: ${model.data.num_workers}
#           data_impl_kwargs:
#             csv_fields_mmap:
#               header_lines: 1
#               newline_int: 10
#               workers: ${model.data.test.num_workers}
#               sort_dataset_paths: true
#               data_sep: ','
#               data_fields:
#                 sequence: 3
#                 sequence_id: 1
#           index_mapping_dir: ${model.data.index_mapping_dir}
#           max_seq_length: ${model.seq_length}
#           seed: ${model.seed}
#         modify_percent: 0.1
#         perturb_percent: 0.5
#         task_name: secondary_structure
#         task_type: token-level-classification
#         preprocessed_data_path: ${oc.env:BIONEMO_HOME}/data/FLIP
#         dataset:
#           train: x000
#           val: x000
#           test: x000
#         sequence_column: sequence
#         target_column:
#         - 3state
#         target_sizes:
#         - 3
#         mask_column:
#         - resolved
#         max_seq_length: ${model.seq_length}
#         emb_batch_size: ${model.micro_batch_size}
#       dwnstr_task_validation:
#         enabled: false
#         dataset:
#           class: bionemo.model.core.dwnstr_task_callbacks.PerTokenPredictionCallback
#           task_type: token-level-classification
#           infer_target: bionemo.model.protein.esm1nv.infer.ESM1nvInference
#           max_seq_length: ${model.seq_length}
#           emb_batch_size: 128
#           batch_size: 128
#           num_epochs: 10
#           shuffle: true
#           num_workers: 8
#           task_name: secondary_structure
#           dataset_path: ${oc.env:BIONEMO_HOME}/data/FLIP/${model.dwnstr_task_validation.dataset.task_name}
#           dataset:
#             train: x000
#             test: x000
#           sequence_column: sequence
#           target_column:
#           - 3state
#           target_sizes:
#           - 3
#           mask_column:
#           - resolved
#           random_seed: 1234
#           optim:
#             name: adam
#             lr: 0.0001
#             betas:
#             - 0.9
#             - 0.999
#             eps: 1.0e-08
#             weight_decay: 0.01
#             sched:
#               name: WarmupAnnealing
#               min_lr: 1.0e-05
#               last_epoch: -1
#               warmup_ratio: 0.01
#               max_steps: 1000
#       restore_encoder_path: ${oc.env:BIONEMO_HOME}/models/protein/esm2nv/esm2nv_650M_converted.nemo
#       encoder_frozen: false
#       global_batch_size: 2
#       cnn_dim: 32
#       dropout_rate: 0.25
#       megatron_amp_O2: false
#       peft:
#         enabled: true
#         peft_scheme: lora
#         restore_from_path: null
#         lora_tuning:
#           adapter_dim: 32
#           adapter_dropout: 0.0
#           column_init_method: xavier
#           row_init_method: zero
#           layer_selection: null
#           weight_tying: false
#           position_embedding_strategy: null
#       finetuning_optim:
#         name: adam
#         lr: 0.0001
#         betas:
#         - 0.9
#         - 0.999
#         eps: 1.0e-08
#         weight_decay: 0.01
#         sched:
#           name: WarmupAnnealing
#           min_lr: 1.0e-05
#           last_epoch: -1
#           warmup_ratio: 10
#       encoder_cfg:
#         name: esm2nv_flip
#         do_training: true
#         do_testing: true
#         restore_from_path: null
#         trainer:
#           devices: 1
#           num_nodes: 1
#           accelerator: gpu
#           precision: 32
#           logger: false
#           enable_checkpointing: false
#           use_distributed_sampler: false
#           max_epochs: 20
#           log_every_n_steps: 10
#           val_check_interval: 20
#           limit_val_batches: 1000
#           limit_test_batches: 1000
#           accumulate_grad_batches: 1
#           gradient_clip_val: 1.0
#           benchmark: false
#           max_steps: 500000
#         exp_manager:
#           name: ${name}
#           exp_dir: ${oc.env:BIONEMO_HOME}/results/nemo_experiments/${.name}/${.wandb_logger_kwargs.name}
#           explicit_log_dir: ${.exp_dir}
#           create_wandb_logger: true
#           create_tensorboard_logger: true
#           wandb_logger_kwargs:
#             project: ${name}_${model.data.task_name}_finetuning
#             name: ${name}_${model.data.task_name}_finetuning_encoder_frozen_${model.encoder_frozen}_${model.peft.peft_scheme}
#             group: ${name}
#             job_type: Localhost_nodes_${trainer.num_nodes}_gpus_${trainer.devices}
#             notes: 'date: ${now:%y%m%d-%H%M%S}'
#             tags:
#             - ${name}
#             offline: true
#           resume_if_exists: true
#           resume_ignore_no_checkpoint: true
#           create_checkpoint_callback: true
#           checkpoint_callback_params:
#             monitor: val_loss
#             save_top_k: 10
#             mode: min
#             always_save_nemo: false
#             filename: megatron_bert--{val_loss:.2f}-{step}-{consumed_samples}
#             model_parallel_size: ${multiply:${model.tensor_model_parallel_size}, ${model.pipeline_model_parallel_size}}
#         model:
#           drop_last: true
#           micro_batch_size: 2
#           seq_length: 1024
#           num_layers: 33
#           hidden_size: 1280
#           ffn_hidden_size: ${multiply:${model.hidden_size}, 4}
#           num_attention_heads: 20
#           megatron_legacy: false
#           position_embedding_type: rope
#           hidden_dropout: 0
#           embedding_use_attention_mask: true
#           embedding_token_dropout: true
#           mask_token_id: ${.tokenizer.mask_id}
#           attention_dropout: 0.0
#           normalize_attention_scores: false
#           tensor_model_parallel_size: 1
#           pipeline_model_parallel_size: 1
#           bias_gelu_fusion: false
#           use_esm_attention: true
#           esm_gelu: true
#           use_pt_layernorm: false
#           use_pt_mlp_out: false
#           max_position_embeddings: ${.seq_length}
#           encoder_seq_length: ${.seq_length}
#           optim:
#             name: fused_adam
#             lr: 0.0004
#             weight_decay: 0.01
#             betas:
#             - 0.9
#             - 0.98
#             sched:
#               name: WarmupAnnealDecayHold
#               warmup_steps: 2000
#               min_lr: 4.0e-05
#               max_lr: 0.0004
#               max_steps: 500000
#               anneal_percentage: 0.1
#           init_method_std: 0.02
#           kv_channels: null
#           apply_query_key_layer_scaling: true
#           layernorm_epsilon: 1.0e-05
#           make_vocab_size_divisible_by: 128
#           pre_process: true
#           post_process: false
#           bert_binary_head: false
#           resume_from_checkpoint: null
#           masked_softmax_fusion: true
#           tokenizer:
#             library: huggingface
#             type: BertWordPieceLowerCase
#             model_name: facebook/esm2_t33_650M_UR50D
#             mask_id: 32
#             model: null
#             vocab_file: null
#             merge_file: null
#           native_amp_init_scale: 4294967296
#           native_amp_growth_interval: 1000
#           fp32_residual_connection: false
#           fp16_lm_cross_entropy: false
#           seed: 1234
#           use_cpu_initialization: false
#           onnx_safe: false
#           activations_checkpoint_method: null
#           activations_checkpoint_num_layers: 1
#           data:
#             ngc_registry_target: uniref50_2022_05
#             ngc_registry_version: v23.06
#             data_prefix: ''
#             num_workers: 8
#             dataloader_type: single
#             reset_position_ids: false
#             reset_attention_mask: false
#             eod_mask_loss: false
#             masked_lm_prob: 0.15
#             short_seq_prob: 0.1
#             skip_lines: 0
#             drop_last: false
#             pin_memory: false
#             dynamic_padding: false
#             force_regen_sample_mapping: false
#             dataset_path: /workspace/bionemo/examples/tests/test_data/protein/downstream/
#             index_mapping_dir: ${model.data.dataset_path}
#             preprocessing:
#               num_preprocess_workers: 16
#             train:
#               data_impl: csv_mmap
#               data_impl_kwargs:
#                 csv_mmap:
#                   data_col: 1
#                   header_lines: 1
#               use_upsampling: true
#               range: x[000..049]
#               sample_from_map: true
#               uf50_datapath: ${model.data.dataset_path}/uniref50_train_filt.fasta
#               uf90_datapath: ${model.data.dataset_path}/uniref90membersandreps_ur50trainfiltreps.fasta
#               cluster_mapping_tsv: ${model.data.dataset_path}/uniref50_mapper_to_uniref90clustermembers_andselfuniref50.tsv
#               dataset_path: ${model.data.dataset_path}/uf50
#               sort_fastas: true
#               num_workers: ${model.data.num_workers}
#               uf90:
#                 uniref90_path: ${model.data.dataset_path}/uf90
#                 dataset:
#                   uf90_csvs: x[000..049]
#                 data_impl: csv_fields_mmap
#                 data_impl_kwargs:
#                   csv_fields_mmap:
#                     header_lines: 1
#                     newline_int: 10
#                     workers: ${model.data.train.num_workers}
#                     sort_dataset_paths: true
#                     data_sep: ','
#                     data_fields:
#                       sequence: 3
#                       sequence_id: 1
#                 index_mapping_dir: ${model.data.index_mapping_dir}
#               index_mapping_dir: ${model.data.index_mapping_dir}
#               max_seq_length: ${model.seq_length}
#               seed: ${model.seed}
#             val:
#               use_upsampling: false
#               range: x[000..049]
#               uf50_datapath: ${model.data.dataset_path}/uniref50_train_filt.fasta
#               dataset_path: ${model.data.dataset_path}/uf50
#               data_impl: csv_fields_mmap
#               num_workers: ${model.data.num_workers}
#               data_impl_kwargs:
#                 csv_fields_mmap:
#                   header_lines: 1
#                   newline_int: 10
#                   workers: ${model.data.val.num_workers}
#                   sort_dataset_paths: true
#                   data_sep: ','
#                   data_fields:
#                     sequence: 3
#                     sequence_id: 1
#               index_mapping_dir: ${model.data.index_mapping_dir}
#               max_seq_length: ${model.seq_length}
#               seed: ${model.seed}
#             test:
#               use_upsampling: false
#               range: x[000..049]
#               uf50_datapath: ${model.data.dataset_path}/uniref50_train_filt.fasta
#               dataset_path: ${model.data.dataset_path}/uf50
#               data_impl: csv_fields_mmap
#               num_workers: ${model.data.num_workers}
#               data_impl_kwargs:
#                 csv_fields_mmap:
#                   header_lines: 1
#                   newline_int: 10
#                   workers: ${model.data.test.num_workers}
#                   sort_dataset_paths: true
#                   data_sep: ','
#                   data_fields:
#                     sequence: 3
#                     sequence_id: 1
#               index_mapping_dir: ${model.data.index_mapping_dir}
#               max_seq_length: ${model.seq_length}
#               seed: ${model.seed}
#             modify_percent: 0.1
#             perturb_percent: 0.5
#             task_name: secondary_structure
#             task_type: token-level-classification
#             preprocessed_data_path: ${oc.env:BIONEMO_HOME}/data/FLIP
#             dataset:
#               train: x000
#               val: x000
#               test: x000
#             sequence_column: sequence
#             target_column:
#             - 3state
#             target_sizes:
#             - 3
#             mask_column:
#             - resolved
#             max_seq_length: ${model.seq_length}
#             emb_batch_size: ${model.micro_batch_size}
#           dwnstr_task_validation:
#             enabled: false
#             dataset:
#               class: bionemo.model.core.dwnstr_task_callbacks.PerTokenPredictionCallback
#               task_type: token-level-classification
#               infer_target: bionemo.model.protein.esm1nv.infer.ESM1nvInference
#               max_seq_length: ${model.seq_length}
#               emb_batch_size: 128
#               batch_size: 128
#               num_epochs: 10
#               shuffle: true
#               num_workers: 8
#               task_name: secondary_structure
#               dataset_path: ${oc.env:BIONEMO_HOME}/data/FLIP/${model.dwnstr_task_validation.dataset.task_name}
#               dataset:
#                 train: x000
#                 test: x000
#               sequence_column: sequence
#               target_column:
#               - 3state
#               target_sizes:
#               - 3
#               mask_column:
#               - resolved
#               random_seed: 1234
#               optim:
#                 name: adam
#                 lr: 0.0001
#                 betas:
#                 - 0.9
#                 - 0.999
#                 eps: 1.0e-08
#                 weight_decay: 0.01
#                 sched:
#                   name: WarmupAnnealing
#                   min_lr: 1.0e-05
#                   last_epoch: -1
#                   warmup_ratio: 0.01
#                   max_steps: 1000
#           restore_encoder_path: ${oc.env:BIONEMO_HOME}/models/protein/esm2nv/esm2nv_650M_converted.nemo
#           encoder_frozen: false
#           global_batch_size: null
#           cnn_dim: 32
#           dropout_rate: 0.25
#           megatron_amp_O2: false
#           peft:
#             enabled: true
#             peft_scheme: lora
#             restore_from_path: null
#             lora_tuning:
#               adapter_dim: 32
#               adapter_dropout: 0.0
#               column_init_method: xavier
#               row_init_method: zero
#               layer_selection: null
#               weight_tying: false
#               position_embedding_strategy: null
#           finetuning_optim:
#             name: adam
#             lr: 0.0001
#             betas:
#             - 0.9
#             - 0.999
#             eps: 1.0e-08
#             weight_decay: 0.01
#             sched:
#               name: WarmupAnnealing
#               min_lr: 1.0e-05
#               last_epoch: -1
#               warmup_ratio: 10
#         do_preprocessing: false
#         target: bionemo.model.protein.esm1nv.ESM2nvLoRAModel
#         infer_target: bionemo.model.protein.esm1nv.infer.ESM1nvInference
#       precision: 32
#     do_preprocessing: false
#     target: bionemo.model.protein.esm1nv.ESM2nvLoRAModel
#     infer_target: bionemo.model.protein.esm1nv.infer.ESM1nvInference
#
# [NeMo I 2024-05-14 16:12:17 utils:333] Restoring model from /workspace/bionemo/models/protein/esm2nv/esm2nv_650M_converted.nemo
# [NeMo I 2024-05-14 16:12:17 utils:337] Loading model class: bionemo.model.protein.esm1nv.ESM2nvLoRAModel
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# [NeMo E 2024-05-14 16:12:17 exp_manager:684] exp_manager received explicit_log_dir: /workspace/bionemo/results/nemo_experiments/esm2nv_flip/esm2nv_flip_secondary_structure_finetuning_encoder_frozen_False_lora and at least one of exp_dir: /workspace/bionemo/results/nemo_experiments/esm2nv_flip/esm2nv_flip_secondary_structure_finetuning_encoder_frozen_False_lora, or version: None. Please note that exp_dir, name, and version will be ignored.
# [NeMo W 2024-05-14 16:12:17 exp_manager:689] Exp_manager is logging to /workspace/bionemo/results/nemo_experiments/esm2nv_flip/esm2nv_flip_secondary_structure_finetuning_encoder_frozen_False_lora, but it already exists.
# [NeMo W 2024-05-14 16:12:17 exp_manager:611] There were no checkpoints found in checkpoint_dir or no checkpoint folder at checkpoint_dir :/workspace/bionemo/results/nemo_experiments/esm2nv_flip/esm2nv_flip_secondary_structure_finetuning_encoder_frozen_False_lora/checkpoints. Training from scratch.
# [NeMo I 2024-05-14 16:12:17 exp_manager:394] Experiments will be logged at /workspace/bionemo/results/nemo_experiments/esm2nv_flip/esm2nv_flip_secondary_structure_finetuning_encoder_frozen_False_lora
# [NeMo I 2024-05-14 16:12:17 exp_manager:835] TensorboardLogger has been set up
# [NeMo W 2024-05-14 16:12:17 nemo_logging:349] /usr/local/lib/python3.10/dist-packages/pytorch_lightning/loggers/wandb.py:397: UserWarning: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#       rank_zero_warn(
#
# [NeMo I 2024-05-14 16:12:17 exp_manager:850] WandBLogger has been set up
# [NeMo W 2024-05-14 16:12:17 exp_manager:931] The checkpoint callback was told to monitor a validation value and trainer's max_steps was set to 500000. Please ensure that max_steps will run for at least 1 epochs to ensure that checkpointing will not error out.
# [NeMo I 2024-05-14 16:12:17 utils:306]
#
#     ************** Trainer configuration ***********
# [NeMo I 2024-05-14 16:12:17 utils:307]
#     name: esm2nv_flip
#     do_training: true
#     do_testing: true
#     restore_from_path: null
#     trainer:
#       devices: 1
#       num_nodes: 1
#       accelerator: gpu
#       precision: 32
#       logger: false
#       enable_checkpointing: false
#       use_distributed_sampler: false
#       max_epochs: 20
#       log_every_n_steps: 10
#       val_check_interval: 20
#       limit_val_batches: 1000
#       limit_test_batches: 1000
#       accumulate_grad_batches: 1
#       gradient_clip_val: 1.0
#       benchmark: false
#       max_steps: 500000
#     exp_manager:
#       name: ${name}
#       exp_dir: ${oc.env:BIONEMO_HOME}/results/nemo_experiments/${.name}/${.wandb_logger_kwargs.name}
#       explicit_log_dir: ${.exp_dir}
#       create_wandb_logger: true
#       create_tensorboard_logger: true
#       wandb_logger_kwargs:
#         project: ${name}_${model.data.task_name}_finetuning
#         name: ${name}_${model.data.task_name}_finetuning_encoder_frozen_${model.encoder_frozen}_${model.peft.peft_scheme}
#         group: ${name}
#         job_type: Localhost_nodes_${trainer.num_nodes}_gpus_${trainer.devices}
#         notes: 'date: ${now:%y%m%d-%H%M%S}'
#         tags:
#         - ${name}
#         offline: true
#       resume_if_exists: true
#       resume_ignore_no_checkpoint: true
#       create_checkpoint_callback: true
#       checkpoint_callback_params:
#         monitor: val_loss
#         save_top_k: 10
#         mode: min
#         always_save_nemo: false
#         filename: megatron_bert--{val_loss:.2f}-{step}-{consumed_samples}
#         model_parallel_size: ${multiply:${model.tensor_model_parallel_size}, ${model.pipeline_model_parallel_size}}
#     model:
#       micro_batch_size: 2
#       tensor_model_parallel_size: 1
#       pipeline_model_parallel_size: 1
#       seq_length: 1024
#       max_position_embeddings: ${.seq_length}
#       encoder_seq_length: ${.seq_length}
#       num_layers: 33
#       hidden_size: 1280
#       ffn_hidden_size: ${multiply:${model.hidden_size}, 4}
#       num_attention_heads: 20
#       init_method_std: 0.02
#       hidden_dropout: 0
#       kv_channels: null
#       apply_query_key_layer_scaling: true
#       layernorm_epsilon: 1.0e-05
#       make_vocab_size_divisible_by: 128
#       pre_process: true
#       post_process: false
#       bert_binary_head: false
#       resume_from_checkpoint: null
#       masked_softmax_fusion: true
#       tokenizer:
#         library: huggingface
#         type: BertWordPieceLowerCase
#         model: null
#         vocab_file: null
#         merge_file: null
#         mask_id: 32
#         model_name: facebook/esm2_t33_650M_UR50D
#       native_amp_init_scale: 4294967296
#       native_amp_growth_interval: 1000
#       fp32_residual_connection: false
#       fp16_lm_cross_entropy: false
#       seed: 1234
#       use_cpu_initialization: false
#       onnx_safe: false
#       activations_checkpoint_method: null
#       activations_checkpoint_num_layers: 1
#       data:
#         ngc_registry_target: uniref50_2022_05
#         ngc_registry_version: v23.06
#         data_prefix: ''
#         num_workers: 8
#         dataloader_type: single
#         reset_position_ids: false
#         reset_attention_mask: false
#         eod_mask_loss: false
#         masked_lm_prob: 0.15
#         short_seq_prob: 0.1
#         skip_lines: 0
#         drop_last: false
#         pin_memory: false
#         index_mapping_dir: ${model.data.dataset_path}
#         data_impl: csv_mmap
#         data_impl_kwargs:
#           csv_mmap:
#             header_lines: 1
#             newline_int: 10
#             workers: 10
#             sort_dataset_paths: true
#             data_sep: ','
#             data_col: 3
#         use_upsampling: true
#         seed: 1234
#         max_seq_length: ${model.seq_length}
#         dataset_path: /workspace/bionemo/examples/tests/test_data/protein/downstream/
#         dataset:
#           train: x000
#           test: x000
#           val: x000
#         micro_batch_size: 32
#         global_batch_size: null
#         modify_percent: 0.1
#         perturb_percent: 0.5
#         dynamic_padding: false
#         force_regen_sample_mapping: false
#         preprocessing:
#           num_preprocess_workers: 16
#         train:
#           data_impl: csv_mmap
#           data_impl_kwargs:
#             csv_mmap:
#               data_col: 1
#               header_lines: 1
#           use_upsampling: true
#           range: x[000..049]
#           sample_from_map: true
#           uf50_datapath: ${model.data.dataset_path}/uniref50_train_filt.fasta
#           uf90_datapath: ${model.data.dataset_path}/uniref90membersandreps_ur50trainfiltreps.fasta
#           cluster_mapping_tsv: ${model.data.dataset_path}/uniref50_mapper_to_uniref90clustermembers_andselfuniref50.tsv
#           dataset_path: ${model.data.dataset_path}/uf50
#           sort_fastas: true
#           num_workers: ${model.data.num_workers}
#           uf90:
#             uniref90_path: ${model.data.dataset_path}/uf90
#             dataset:
#               uf90_csvs: x[000..049]
#             data_impl: csv_fields_mmap
#             data_impl_kwargs:
#               csv_fields_mmap:
#                 header_lines: 1
#                 newline_int: 10
#                 workers: ${model.data.train.num_workers}
#                 sort_dataset_paths: true
#                 data_sep: ','
#                 data_fields:
#                   sequence: 3
#                   sequence_id: 1
#             index_mapping_dir: ${model.data.index_mapping_dir}
#           index_mapping_dir: ${model.data.index_mapping_dir}
#           max_seq_length: ${model.seq_length}
#           seed: ${model.seed}
#         val:
#           use_upsampling: false
#           range: x[000..049]
#           uf50_datapath: ${model.data.dataset_path}/uniref50_train_filt.fasta
#           dataset_path: ${model.data.dataset_path}/uf50
#           data_impl: csv_fields_mmap
#           num_workers: ${model.data.num_workers}
#           data_impl_kwargs:
#             csv_fields_mmap:
#               header_lines: 1
#               newline_int: 10
#               workers: ${model.data.val.num_workers}
#               sort_dataset_paths: true
#               data_sep: ','
#               data_fields:
#                 sequence: 3
#                 sequence_id: 1
#           index_mapping_dir: ${model.data.index_mapping_dir}
#           max_seq_length: ${model.seq_length}
#           seed: ${model.seed}
#         test:
#           use_upsampling: false
#           range: x[000..049]
#           uf50_datapath: ${model.data.dataset_path}/uniref50_train_filt.fasta
#           dataset_path: ${model.data.dataset_path}/uf50
#           data_impl: csv_fields_mmap
#           num_workers: ${model.data.num_workers}
#           data_impl_kwargs:
#             csv_fields_mmap:
#               header_lines: 1
#               newline_int: 10
#               workers: ${model.data.test.num_workers}
#               sort_dataset_paths: true
#               data_sep: ','
#               data_fields:
#                 sequence: 3
#                 sequence_id: 1
#           index_mapping_dir: ${model.data.index_mapping_dir}
#           max_seq_length: ${model.seq_length}
#           seed: ${model.seed}
#         task_name: secondary_structure
#         task_type: token-level-classification
#         preprocessed_data_path: ${oc.env:BIONEMO_HOME}/data/FLIP
#         sequence_column: sequence
#         target_column:
#         - 3state
#         target_sizes:
#         - 3
#         mask_column:
#         - resolved
#         emb_batch_size: ${model.micro_batch_size}
#       optim:
#         name: fused_adam
#         lr: 0.0004
#         weight_decay: 0.01
#         betas:
#         - 0.9
#         - 0.98
#         sched:
#           name: WarmupAnnealDecayHold
#           warmup_steps: 2000
#           constant_steps: 50000
#           min_lr: 4.0e-05
#           max_lr: 0.0004
#           max_steps: 500000
#           anneal_percentage: 0.1
#       dwnstr_task_validation:
#         enabled: false
#         dataset:
#           class: bionemo.model.core.dwnstr_task_callbacks.PerTokenPredictionCallback
#           task_type: token-level-classification
#           infer_target: bionemo.model.protein.esm1nv.infer.ESM1nvInference
#           max_seq_length: ${model.seq_length}
#           emb_batch_size: 128
#           batch_size: 128
#           num_epochs: 10
#           shuffle: true
#           num_workers: 8
#           task_name: secondary_structure
#           dataset_path: ${oc.env:BIONEMO_HOME}/data/FLIP/${model.dwnstr_task_validation.dataset.task_name}
#           dataset:
#             train: x000
#             test: x000
#           sequence_column: sequence
#           target_column:
#           - 3state
#           target_sizes:
#           - 3
#           mask_column:
#           - resolved
#           random_seed: 1234
#           optim:
#             name: adam
#             lr: 0.0001
#             betas:
#             - 0.9
#             - 0.999
#             eps: 1.0e-08
#             weight_decay: 0.01
#             sched:
#               name: WarmupAnnealing
#               min_lr: 1.0e-05
#               last_epoch: -1
#               warmup_ratio: 0.01
#               max_steps: 1000
#       precision: 16
#       megatron_legacy: false
#       position_embedding_type: rope
#       embedding_use_attention_mask: true
#       embedding_token_dropout: true
#       mask_token_id: ${.tokenizer.mask_id}
#       attention_dropout: 0.0
#       use_esm_attention: true
#       normalize_attention_scores: false
#       esm_gelu: true
#       bias_gelu_fusion: false
#       use_pt_layernorm: false
#       use_pt_mlp_out: false
#       target: bionemo.model.protein.esm1nv.esm1nv_model.ESM2nvModel
#       nemo_version: 1.20.0
#       drop_last: true
#       restore_encoder_path: ${oc.env:BIONEMO_HOME}/models/protein/esm2nv/esm2nv_650M_converted.nemo
#       encoder_frozen: false
#       global_batch_size: null
#       cnn_dim: 32
#       dropout_rate: 0.25
#       megatron_amp_O2: false
#       peft:
#         enabled: true
#         peft_scheme: lora
#         restore_from_path: null
#         lora_tuning:
#           adapter_dim: 32
#           adapter_dropout: 0.0
#           column_init_method: xavier
#           row_init_method: zero
#           layer_selection: null
#           weight_tying: false
#           position_embedding_strategy: null
#       finetuning_optim:
#         name: adam
#         lr: 0.0001
#         betas:
#         - 0.9
#         - 0.999
#         eps: 1.0e-08
#         weight_decay: 0.01
#         sched:
#           name: WarmupAnnealing
#           min_lr: 1.0e-05
#           last_epoch: -1
#           warmup_ratio: 10
#     do_preprocessing: false
#     target: bionemo.model.protein.esm1nv.ESM2nvLoRAModel
#     infer_target: bionemo.model.protein.esm1nv.infer.ESM1nvInference
#
# [NeMo W 2024-05-14 16:12:21 megatron_base_model:821] The model: ESM2nvLoRAModel() does not have field.name: context_parallel_size in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-05-14 16:12:21 megatron_base_model:821] The model: ESM2nvLoRAModel() does not have field.name: virtual_pipeline_model_parallel_size in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# [NeMo W 2024-05-14 16:12:21 megatron_base_model:821] The model: ESM2nvLoRAModel() does not have field.name: sequence_parallel in its cfg. Add this key to cfg or config_mapping to make to make it configurable.
# ...
# Validation DataLoader 0:  80%|██████████████▍   | 40/50 [00:03<00:00, 11.53it/s]
# Validation DataLoader 0:  82%|██████████████▊   | 41/50 [00:03<00:00, 11.54it/s]
# Validation DataLoader 0:  84%|███████████████   | 42/50 [00:03<00:00, 11.54it/s]
# Validation DataLoader 0:  86%|███████████████▍  | 43/50 [00:03<00:00, 11.55it/s]
# Validation DataLoader 0:  88%|███████████████▊  | 44/50 [00:03<00:00, 11.55it/s]
# Validation DataLoader 0:  90%|████████████████▏ | 45/50 [00:03<00:00, 11.54it/s]
# Validation DataLoader 0:  92%|████████████████▌ | 46/50 [00:03<00:00, 11.55it/s]
# Validation DataLoader 0:  94%|████████████████▉ | 47/50 [00:04<00:00, 11.55it/s]
# Validation DataLoader 0:  96%|█████████████████▎| 48/50 [00:04<00:00, 11.56it/s]
# Validation DataLoader 0:  98%|█████████████████▋| 49/50 [00:04<00:00, 11.56it/s]
# Epoch 10:   8%| | 20/250 [00:09<01:44,  2.21it/s, v_num=b4v1, reduced_train_loss
#                                                                                 Epoch 10, global step 2510: 'val_loss' reached 0.22385 (best 0.22385), saving model to '/workspace/bionemo/results/nemo_experiments/esm2nv_flip/esm2nv_flip_secondary_structure_finetuning_encoder_frozen_False_lora/checkpoints/megatron_bert--val_loss=0.22-step=2510-consumed_samples=5020.0.ckpt' as top 10
# [NeMo I 2024-05-14 16:31:14 nlp_overrides:412] Removing checkpoint: /workspace/bionemo/results/nemo_experiments/esm2nv_flip/esm2nv_flip_secondary_structure_finetuning_encoder_frozen_False_lora/checkpoints/megatron_bert--val_loss=0.22-step=2301-consumed_samples=4602.0.ckpt
# [NeMo I 2024-05-14 16:31:14 nlp_overrides:412] Removing checkpoint: /workspace/bionemo/results/nemo_experiments/esm2nv_flip/esm2nv_flip_secondary_structure_finetuning_encoder_frozen_False_lora/checkpoints/megatron_bert--val_loss=0.22-step=2481-consumed_samples=4962.0-last.ckpt
# Epoch 10:  16%|▏| 40/250 [00:13<01:09,  3.00it/s, v_num=b4v1, reduced_train_loss
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/50 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/50 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▍                  | 1/50 [00:00<00:04, 11.12it/s]
# Validation DataLoader 0:   4%|▊                  | 2/50 [00:00<00:04, 11.20it/s]
# Validation DataLoader 0:   6%|█▏                 | 3/50 [00:00<00:04, 11.30it/s]
# Validation DataLoader 0:   8%|█▌                 | 4/50 [00:00<00:04, 11.32it/s]
# Validation DataLoader 0:  10%|█▉                 | 5/50 [00:00<00:03, 11.37it/s]
# Validation DataLoader 0:  12%|██▎                | 6/50 [00:00<00:03, 11.39it/s]
# Validation DataLoader 0:  14%|██▋                | 7/50 [00:00<00:03, 11.39it/s]
# Validation DataLoader 0:  16%|███                | 8/50 [00:00<00:03, 11.43it/s]
# Validation DataLoader 0:  18%|███▍               | 9/50 [00:00<00:03, 11.45it/s]
# Validation DataLoader 0:  20%|███▌              | 10/50 [00:00<00:03, 11.47it/s]
# Validation DataLoader 0:  22%|███▉              | 11/50 [00:00<00:03, 11.46it/s]
# Validation DataLoader 0:  24%|████▎             | 12/50 [00:01<00:03, 11.46it/s]
# Validation DataLoader 0:  26%|████▋             | 13/50 [00:01<00:03, 11.47it/s]
# Validation DataLoader 0:  28%|█████             | 14/50 [00:01<00:03, 11.47it/s]
# Validation DataLoader 0:  30%|█████▍            | 15/50 [00:01<00:03, 11.48it/s]
# Validation DataLoader 0:  32%|█████▊            | 16/50 [00:01<00:02, 11.50it/s]
# Validation DataLoader 0:  34%|██████            | 17/50 [00:01<00:02, 11.51it/s]
# Validation DataLoader 0:  36%|██████▍           | 18/50 [00:01<00:02, 11.51it/s]
# Validation DataLoader 0:  38%|██████▊           | 19/50 [00:01<00:02, 11.52it/s]
# Validation DataLoader 0:  40%|███████▏          | 20/50 [00:01<00:02, 11.52it/s]
# Validation DataLoader 0:  42%|███████▌          | 21/50 [00:01<00:02, 11.53it/s]
# Validation DataLoader 0:  44%|███████▉          | 22/50 [00:01<00:02, 11.53it/s]
# Validation DataLoader 0:  46%|████████▎         | 23/50 [00:01<00:02, 11.53it/s]
# Validation DataLoader 0:  48%|████████▋         | 24/50 [00:02<00:02, 11.53it/s]
# Validation DataLoader 0:  50%|█████████         | 25/50 [00:02<00:02, 11.53it/s]
# Validation DataLoader 0:  52%|█████████▎        | 26/50 [00:02<00:02, 11.52it/s]
# Validation DataLoader 0:  54%|█████████▋        | 27/50 [00:02<00:01, 11.52it/s]
# Validation DataLoader 0:  56%|██████████        | 28/50 [00:02<00:01, 11.52it/s]
# Validation DataLoader 0:  58%|██████████▍       | 29/50 [00:02<00:01, 11.52it/s]
# Validation DataLoader 0:  60%|██████████▊       | 30/50 [00:02<00:01, 11.52it/s]
# Validation DataLoader 0:  62%|███████████▏      | 31/50 [00:02<00:01, 11.52it/s]
# Validation DataLoader 0:  64%|███████████▌      | 32/50 [00:02<00:01, 11.52it/s]
# Validation DataLoader 0:  66%|███████████▉      | 33/50 [00:02<00:01, 11.51it/s]
# Validation DataLoader 0:  68%|████████████▏     | 34/50 [00:02<00:01, 11.51it/s]
# Validation DataLoader 0:  70%|████████████▌     | 35/50 [00:03<00:01, 11.52it/s]
# Validation DataLoader 0:  72%|████████████▉     | 36/50 [00:03<00:01, 11.52it/s]
# Validation DataLoader 0:  74%|█████████████▎    | 37/50 [00:03<00:01, 11.53it/s]
# Validation DataLoader 0:  76%|█████████████▋    | 38/50 [00:03<00:01, 11.52it/s]
# Validation DataLoader 0:  78%|██████████████    | 39/50 [00:03<00:00, 11.53it/s]
# Validation DataLoader 0:  80%|██████████████▍   | 40/50 [00:03<00:00, 11.52it/s]
# Validation DataLoader 0:  82%|██████████████▊   | 41/50 [00:03<00:00, 11.53it/s]
# Validation DataLoader 0:  84%|███████████████   | 42/50 [00:03<00:00, 11.53it/s]
# Validation DataLoader 0:  86%|███████████████▍  | 43/50 [00:03<00:00, 11.54it/s]
# Validation DataLoader 0:  88%|███████████████▊  | 44/50 [00:03<00:00, 11.54it/s]
# Validation DataLoader 0:  90%|████████████████▏ | 45/50 [00:03<00:00, 11.53it/s]
# Validation DataLoader 0:  92%|████████████████▌ | 46/50 [00:03<00:00, 11.54it/s]
# Validation DataLoader 0:  94%|████████████████▉ | 47/50 [00:04<00:00, 11.54it/s]
# Validation DataLoader 0:  96%|█████████████████▎| 48/50 [00:04<00:00, 11.55it/s]
# Validation DataLoader 0:  98%|█████████████████▋| 49/50 [00:04<00:00, 11.55it/s]
# Epoch 10:  16%|▏| 40/250 [00:18<01:35,  2.19it/s, v_num=b4v1, reduced_train_loss
#                                                                                 Epoch 10, global step 2530: 'val_loss' reached 0.22384 (best 0.22384), saving model to '/workspace/bionemo/results/nemo_experiments/esm2nv_flip/esm2nv_flip_secondary_structure_finetuning_encoder_frozen_False_lora/checkpoints/megatron_bert--val_loss=0.22-step=2530-consumed_samples=5060.0.ckpt' as top 10
# [NeMo I 2024-05-14 16:31:23 nlp_overrides:412] Removing checkpoint: /workspace/bionemo/results/nemo_experiments/esm2nv_flip/esm2nv_flip_secondary_structure_finetuning_encoder_frozen_False_lora/checkpoints/megatron_bert--val_loss=0.22-step=2321-consumed_samples=4642.0.ckpt
# [NeMo I 2024-05-14 16:31:23 nlp_overrides:412] Removing checkpoint: /workspace/bionemo/results/nemo_experiments/esm2nv_flip/esm2nv_flip_secondary_structure_finetuning_encoder_frozen_False_lora/checkpoints/megatron_bert--val_loss=0.22-step=2510-consumed_samples=5020.0-last.ckpt
# Epoch 10:  24%|▏| 60/250 [00:22<01:11,  2.65it/s, v_num=b4v1, reduced_train_loss
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/50 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/50 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▍                  | 1/50 [00:00<00:04, 11.23it/s]
# Validation DataLoader 0:   4%|▊                  | 2/50 [00:00<00:04, 11.23it/s]
# Validation DataLoader 0:   6%|█▏                 | 3/50 [00:00<00:04, 11.30it/s]
# Validation DataLoader 0:   8%|█▌                 | 4/50 [00:00<00:04, 11.32it/s]
# Validation DataLoader 0:  10%|█▉                 | 5/50 [00:00<00:03, 11.38it/s]
# Validation DataLoader 0:  12%|██▎                | 6/50 [00:00<00:03, 11.38it/s]
# Validation DataLoader 0:  14%|██▋                | 7/50 [00:00<00:03, 11.39it/s]
# Validation DataLoader 0:  16%|███                | 8/50 [00:00<00:03, 11.42it/s]
# Validation DataLoader 0:  18%|███▍               | 9/50 [00:00<00:03, 11.44it/s]
# Validation DataLoader 0:  20%|███▌              | 10/50 [00:00<00:03, 11.45it/s]
# Validation DataLoader 0:  22%|███▉              | 11/50 [00:00<00:03, 11.45it/s]
# Validation DataLoader 0:  24%|████▎             | 12/50 [00:01<00:03, 11.44it/s]
# Validation DataLoader 0:  26%|████▋             | 13/50 [00:01<00:03, 11.45it/s]
# Validation DataLoader 0:  28%|█████             | 14/50 [00:01<00:03, 11.45it/s]
# Validation DataLoader 0:  30%|█████▍            | 15/50 [00:01<00:03, 11.46it/s]
# Validation DataLoader 0:  32%|█████▊            | 16/50 [00:01<00:02, 11.48it/s]
# Validation DataLoader 0:  34%|██████            | 17/50 [00:01<00:02, 11.49it/s]
# Validation DataLoader 0:  36%|██████▍           | 18/50 [00:01<00:02, 11.49it/s]
# Validation DataLoader 0:  38%|██████▊           | 19/50 [00:01<00:02, 11.50it/s]
# Validation DataLoader 0:  40%|███████▏          | 20/50 [00:01<00:02, 11.51it/s]
# Validation DataLoader 0:  42%|███████▌          | 21/50 [00:01<00:02, 11.52it/s]
# Validation DataLoader 0:  44%|███████▉          | 22/50 [00:01<00:02, 11.52it/s]
# Validation DataLoader 0:  46%|████████▎         | 23/50 [00:01<00:02, 11.53it/s]
# Validation DataLoader 0:  48%|████████▋         | 24/50 [00:02<00:02, 11.53it/s]
# Validation DataLoader 0:  50%|█████████         | 25/50 [00:02<00:02, 11.53it/s]
# Validation DataLoader 0:  52%|█████████▎        | 26/50 [00:02<00:02, 11.51it/s]
# Validation DataLoader 0:  54%|█████████▋        | 27/50 [00:02<00:01, 11.51it/s]
# Validation DataLoader 0:  56%|██████████        | 28/50 [00:02<00:01, 11.51it/s]
# Validation DataLoader 0:  58%|██████████▍       | 29/50 [00:02<00:01, 11.51it/s]
# Validation DataLoader 0:  60%|██████████▊       | 30/50 [00:02<00:01, 11.52it/s]
# Validation DataLoader 0:  62%|███████████▏      | 31/50 [00:02<00:01, 11.47it/s]
# Validation DataLoader 0:  64%|███████████▌      | 32/50 [00:02<00:01, 11.47it/s]
# Validation DataLoader 0:  66%|███████████▉      | 33/50 [00:02<00:01, 11.47it/s]
# Validation DataLoader 0:  68%|████████████▏     | 34/50 [00:02<00:01, 11.47it/s]
# Validation DataLoader 0:  70%|████████████▌     | 35/50 [00:03<00:01, 11.48it/s]
# Validation DataLoader 0:  72%|████████████▉     | 36/50 [00:03<00:01, 11.48it/s]
# Validation DataLoader 0:  74%|█████████████▎    | 37/50 [00:03<00:01, 11.49it/s]
# Validation DataLoader 0:  76%|█████████████▋    | 38/50 [00:03<00:01, 11.49it/s]
# Validation DataLoader 0:  78%|██████████████    | 39/50 [00:03<00:00, 11.49it/s]
# Validation DataLoader 0:  80%|██████████████▍   | 40/50 [00:03<00:00, 11.49it/s]
# Validation DataLoader 0:  82%|██████████████▊   | 41/50 [00:03<00:00, 11.49it/s]
# Validation DataLoader 0:  84%|███████████████   | 42/50 [00:03<00:00, 11.50it/s]
# Validation DataLoader 0:  86%|███████████████▍  | 43/50 [00:03<00:00, 11.50it/s]
# Validation DataLoader 0:  88%|███████████████▊  | 44/50 [00:03<00:00, 11.50it/s]
# Validation DataLoader 0:  90%|████████████████▏ | 45/50 [00:03<00:00, 11.50it/s]
# Validation DataLoader 0:  92%|████████████████▌ | 46/50 [00:03<00:00, 11.51it/s]
# Validation DataLoader 0:  94%|████████████████▉ | 47/50 [00:04<00:00, 11.51it/s]
# Validation DataLoader 0:  96%|█████████████████▎| 48/50 [00:04<00:00, 11.52it/s]
# Validation DataLoader 0:  98%|█████████████████▋| 49/50 [00:04<00:00, 11.52it/s]
# Epoch 10:  24%|▏| 60/250 [00:27<01:27,  2.18it/s, v_num=b4v1, reduced_train_loss
#                                                                                 Epoch 10, global step 2550: 'val_loss' reached 0.22383 (best 0.22383), saving model to '/workspace/bionemo/results/nemo_experiments/esm2nv_flip/esm2nv_flip_secondary_structure_finetuning_encoder_frozen_False_lora/checkpoints/megatron_bert--val_loss=0.22-step=2550-consumed_samples=5100.0.ckpt' as top 10
# [NeMo I 2024-05-14 16:31:32 nlp_overrides:412] Removing checkpoint: /workspace/bionemo/results/nemo_experiments/esm2nv_flip/esm2nv_flip_secondary_structure_finetuning_encoder_frozen_False_lora/checkpoints/megatron_bert--val_loss=0.22-step=2341-consumed_samples=4682.0.ckpt
# [NeMo I 2024-05-14 16:31:32 nlp_overrides:412] Removing checkpoint: /workspace/bionemo/results/nemo_experiments/esm2nv_flip/esm2nv_flip_secondary_structure_finetuning_encoder_frozen_False_lora/checkpoints/megatron_bert--val_loss=0.22-step=2530-consumed_samples=5060.0-last.ckpt
# Epoch 10:  32%|▎| 80/250 [00:31<01:07,  2.52it/s, v_num=b4v1, reduced_train_loss
# Validation: 0it [00:00, ?it/s]
# Validation:   0%|                                        | 0/50 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|                           | 0/50 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▍                  | 1/50 [00:00<00:04, 11.15it/s]
# Validation DataLoader 0:   4%|▊                  | 2/50 [00:00<00:04, 11.22it/s]
# Validation DataLoader 0:   6%|█▏                 | 3/50 [00:00<00:04, 11.29it/s]
# Validation DataLoader 0:   8%|█▌                 | 4/50 [00:00<00:04, 11.32it/s]
# Validation DataLoader 0:  10%|█▉                 | 5/50 [00:00<00:03, 11.37it/s]
# Validation DataLoader 0:  12%|██▎                | 6/50 [00:00<00:03, 11.38it/s]
# Validation DataLoader 0:  14%|██▋                | 7/50 [00:00<00:03, 11.39it/s]
# Validation DataLoader 0:  16%|███                | 8/50 [00:00<00:03, 11.42it/s]
# Validation DataLoader 0:  18%|███▍               | 9/50 [00:00<00:03, 11.44it/s]
# Validation DataLoader 0:  20%|███▌              | 10/50 [00:00<00:03, 11.46it/s]
# Validation DataLoader 0:  22%|███▉              | 11/50 [00:00<00:03, 11.46it/s]
# Validation DataLoader 0:  24%|████▎             | 12/50 [00:01<00:03, 11.46it/s]
# Validation DataLoader 0:  26%|████▋             | 13/50 [00:01<00:03, 11.47it/s]
# Validation DataLoader 0:  28%|█████             | 14/50 [00:01<00:03, 11.47it/s]
# Validation DataLoader 0:  30%|█████▍            | 15/50 [00:01<00:03, 11.48it/s]
# Validation DataLoader 0:  32%|█████▊            | 16/50 [00:01<00:02, 11.50it/s]
# Validation DataLoader 0:  34%|██████            | 17/50 [00:01<00:02, 11.51it/s]
# Validation DataLoader 0:  36%|██████▍           | 18/50 [00:01<00:02, 11.52it/s]
# Validation DataLoader 0:  38%|██████▊           | 19/50 [00:01<00:02, 11.53it/s]
# Validation DataLoader 0:  40%|███████▏          | 20/50 [00:01<00:02, 11.54it/s]
# Validation DataLoader 0:  42%|███████▌          | 21/50 [00:01<00:02, 11.54it/s]
# Validation DataLoader 0:  44%|███████▉          | 22/50 [00:01<00:02, 11.55it/s]
# Validation DataLoader 0:  46%|████████▎         | 23/50 [00:01<00:02, 11.55it/s]
# Validation DataLoader 0:  48%|████████▋         | 24/50 [00:02<00:02, 11.55it/s]
# Validation DataLoader 0:  50%|█████████         | 25/50 [00:02<00:02, 11.55it/s]
# Validation DataLoader 0:  52%|█████████▎        | 26/50 [00:02<00:02, 11.54it/s]
# Validation DataLoader 0:  54%|█████████▋        | 27/50 [00:02<00:01, 11.54it/s]
# Validation DataLoader 0:  56%|██████████        | 28/50 [00:02<00:01, 11.53it/s]
# Validation DataLoader 0:  58%|██████████▍       | 29/50 [00:02<00:01, 11.53it/s]
# Validation DataLoader 0:  60%|██████████▊       | 30/50 [00:02<00:01, 11.54it/s]
# Validation DataLoader 0:  62%|███████████▏      | 31/50 [00:02<00:01, 11.54it/s]
# Validation DataLoader 0:  64%|███████████▌      | 32/50 [00:02<00:01, 11.54it/s]
# Validation DataLoader 0:  66%|███████████▉      | 33/50 [00:02<00:01, 11.53it/s]
# Validation DataLoader 0:  68%|████████████▏     | 34/50 [00:02<00:01, 11.53it/s]
# Validation DataLoader 0:  70%|████████████▌     | 35/50 [00:03<00:01, 11.54it/s]
# Validation DataLoader 0:  72%|████████████▉     | 36/50 [00:03<00:01, 11.54it/s]
# Validation DataLoader 0:  74%|█████████████▎    | 37/50 [00:03<00:01, 11.55it/s]
# Validation DataLoader 0:  76%|█████████████▋    | 38/50 [00:03<00:01, 11.54it/s]
# Validation DataLoader 0:  78%|██████████████    | 39/50 [00:03<00:00, 11.55it/s]
# Validation DataLoader 0:  80%|██████████████▍   | 40/50 [00:03<00:00, 11.55it/s]
# Validation DataLoader 0:  82%|██████████████▊   | 41/50 [00:03<00:00, 11.55it/s]

# %% [markdown]
# # 推論

# %% [markdown]
# 下記の YAML ファイルを開いて、
#
# /workspace/bionemo/examples/protein/esm2nv/conf/infer.yaml

# %% [markdown]
# 以下の情報を更新してください。提供する事前学習済みモデルを使用するか、自分でトレーニングしたモデルを使用することができます。

# %%
downstream_task:
 restore_from_path: "${oc.env:BIONEMO_HOME}/models/protein/esm2nv/esm2nv_650M_converted.nemo" # 事前学習済みモデルのパス

# %% [markdown]
# 下記の Jupyter Notebook を開いて、
#
# /workspace/bionemo/examples/protein/esm2nv/nbs/inference_interactive.ipynb
#
#
# セルを順次実行してください。

# %% [markdown]
# # 独自データの準備（オプション）

# %% [markdown]
# ローカルマシンのディレクトリ /home/bionemo/ に、train、val、testというフォルダを準備してください。それぞれのフォルダの中に、x000.csv, x001.csv,… という名前のファイルを準備してください。
# ## 事前学習データの準備
# 事前学習データのフォーマットについては、下記のファイルを参考にしてください。
#
# /workspace/bionemo/examples/tests/test_data/uniref202104_esm2_qc_test200_val200/uf50/train/x000.csv
#
# recode_id と sequence 列が必須で、他の列は任意です。
# また、下記の YAML ファイルの data の部分についてもデータの数やパスなどを変更する必要があります。
#
# /workspace/bionemo/examples/protein/esm2nv/conf/base_config.yaml
#
# ## ファインチューニングデータの準備
# ファインチューニングデータのフォーマットについては、下記のファイルを参考にしてください。
#
# /workspace/bionemo/examples/tests/test_data/protein/downstream/train/x000.csv
#
# id、sequence と target(3state か 8state) 列が必須で、他の列は任意です。
# また、下記の YAML ファイルの data の部分についてもデータの数、パス、ターゲット情報などを変更する必要があります。
#
# /workspace/bionemo/examples/protein/esm2nv/conf/downstream_sec_str_LORA.yaml
